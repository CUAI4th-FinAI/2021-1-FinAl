# %% [markdown]
# # 4장 word2vec 속도 개선

# %%
class Embedding:
    
    def __init__(self, W):
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.idx = None

    def forward(self, idx):
        W, = self.params
        self.idx = idx
        out = W[idx]
        return out

    def backward(self, dout):
        dW, = self.grads
        dW[...] = 0 # dW의 원소를 0으로 덮어쓴다
        np.add.at(dW, self.idx, dout) # dout를 dW의 idx번째 행에 더해줌 # 중복 인덱스가 있더라도 덮여쓰이지 않고 잘 처리 됨 
        return None

# %%
import sys
sys.path.append('/content/drive/MyDrive/Cola/')

# %%
from common.layers import Embedding, SigmoidWithLoss
import collections


class EmbeddingDot:
    
    def __init__(self, W):
        self.embed = Embedding(W)
        self.params = self.embed.params
        self.grads = self.embed.grads
        self.cache = None

    def forward(self, h, idx):
        target_W = self.embed.forward(idx)
        out = np.sum(target_W * h, axis=1)

        self.cache = (h, target_W)
        return out
    
    def backward(self, dout):
        h, target_W = self.cache
        dout = dout.reshape(dout.shape[0], 1)

        dtarget_W = dout * h
        self.embed.backward(dtarget_W)
        dh = dout * target_W
        return dh
        return None

# %%
class UnigramSampler:
    def __init__(self, corpus, power, sample_size):
        self.sample_size = sample_size
        self.vocab_size = None
        self.word_p = None

        counts = collections.Counter()
        for word_id in corpus:
            counts[word_id] += 1

        vocab_size = len(counts)
        self.vocab_size = vocab_size

        self.word_p = np.zeros(vocab_size)
        for i in range(vocab_size):
            self.word_p[i] = counts[i]

        self.word_p = np.power(self.word_p, power)
        self.word_p /= np.sum(self.word_p)

    def get_negative_sample(self, target):
        batch_size = target.shape[0]

        if not GPU:
            negative_sample = np.zeros((batch_size, self.sample_size), dtype=np.int32)

            for i in range(batch_size):
                p = self.word_p.copy()
                target_idx = target[i]
                p[target_idx] = 0
                p /= p.sum()
                negative_sample[i, :] = np.random.choice(self.vocab_size, size=self.sample_size, replace=False, p=p)
        else:
            # GPU(cupy）로 계산할 때는 속도를 우선한다.
            # 부정적 예에 타깃이 포함될 수 있다.
            negative_sample = np.random.choice(self.vocab_size, size=(batch_size, self.sample_size),
                                               replace=True, p=self.word_p)

        return negative_sample

# %%
class NegativeSamplingLoss:
    
    def __init__(self, W, corpus, power=0.75, sample_size=5):
        self.sample_size = sample_size
        self.sampler = UnigramSampler(corpus, power, sample_size)
        self.loss_layers = [SigmoidWithLoss() for _ in range(sample_size + 1)]
        self.embed_dot_layers = [EmbeddingDot(W) for _ in range(sample_size + 1)]

        self.params, self.grads = [], []
        for layer in self.embed_dot_layers:
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, h, target):
        batch_size = target.shape[0]
        negative_sample = self.sampler.get_negative_sample(target)

        # 긍정적 예 순전파
        score = self.embed_dot_layers[0].forward(h, target)
        correct_label = np.ones(batch_size, dtype=np.int32)
        loss = self.loss_layers[0].forward(score, correct_label)

        # 부정적 예 순전파
        negative_label = np.zeros(batch_size, dtype=np.int32)
        for i in range(self.sample_size):
            negative_target = negative_sample[:, i]
            score = self.embed_dot_layers[1 + i].forward(h, negative_target)
            loss += self.loss_layers[1 + i].forward(score, negative_label)

        return loss

    def backward(self, dout=1):
        dh = 0
        for l0, l1 in zip(self.loss_layers, self.embed_dot_layers):
            dscore = l0.backward(dout)
            dh += l1.backward(dscore)

        return dh

# %%
from common.np import *  # import numpy as np
from common.layers import Embedding


class CBOW:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size

        # 가중치 초기화
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(V, H).astype('f')

        # 계층 생성
        self.in_layers = []
        for i in range(2 * window_size):
            layer = Embedding(W_in)  # Embedding 계층 사용
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)

        # 모든 가중치와 기울기를 배열에 모은다.
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 인스턴스 변수에 단어의 분산 표현을 저장한다.
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = 0
        for i, layer in enumerate(self.in_layers):
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        return loss

    def backward(self, dout=1):
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self.in_layers:
            layer.backward(dout)
        return None

# %%
import numpy as np
from common import config
# GPU에서 실행하려면 아래 주석을 해제하세요(CuPy 필요).
# ===============================================
# config.GPU = True
# ===============================================
import pickle
from common.dataset import ptb
from common.util import create_contexts_target, to_cpu, to_gpu
#from cbow import CBOW
#from skip_gram import SkipGram

# 하이퍼파라미터 설정
window_size = 5
hidden_size = 100
batch_size = 100
max_epoch = 10

# 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)
if config.GPU:
    contexts, target = to_gpu(contexts), to_gpu(target)

# 모델 등 생성
model = CBOW(vocab_size, hidden_size, window_size, corpus)
# model = SkipGram(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 나중에 사용할 수 있도록 필요한 데이터 저장
word_vecs = model.word_vecs
if config.GPU:
    word_vecs = to_cpu(word_vecs)
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'  # or 'skipgram_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# Downloading ptb.train.txt ...
# Done
# | 에폭 1 |  반복 1 / 9295 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 21 / 9295 | 시간 1[s] | 손실 4.16
# | 에폭 1 |  반복 41 / 9295 | 시간 3[s] | 손실 4.15
# | 에폭 1 |  반복 61 / 9295 | 시간 5[s] | 손실 4.12
# | 에폭 1 |  반복 81 / 9295 | 시간 6[s] | 손실 4.05
# | 에폭 1 |  반복 101 / 9295 | 시간 8[s] | 손실 3.92
# | 에폭 1 |  반복 121 / 9295 | 시간 10[s] | 손실 3.78
# | 에폭 1 |  반복 141 / 9295 | 시간 11[s] | 손실 3.63
# | 에폭 1 |  반복 161 / 9295 | 시간 12[s] | 손실 3.48
# | 에폭 1 |  반복 181 / 9295 | 시간 14[s] | 손실 3.37
# | 에폭 1 |  반복 201 / 9295 | 시간 16[s] | 손실 3.26
# | 에폭 1 |  반복 221 / 9295 | 시간 17[s] | 손실 3.17
# | 에폭 1 |  반복 241 / 9295 | 시간 19[s] | 손실 3.10
# | 에폭 1 |  반복 261 / 9295 | 시간 21[s] | 손실 3.02
# | 에폭 1 |  반복 281 / 9295 | 시간 22[s] | 손실 2.95
# | 에폭 1 |  반복 301 / 9295 | 시간 24[s] | 손실 2.90
# | 에폭 1 |  반복 321 / 9295 | 시간 25[s] | 손실 2.88
# | 에폭 1 |  반복 341 / 9295 | 시간 27[s] | 손실 2.84
# | 에폭 1 |  반복 361 / 9295 | 시간 29[s] | 손실 2.80
# | 에폭 1 |  반복 381 / 9295 | 시간 30[s] | 손실 2.76
# | 에폭 1 |  반복 401 / 9295 | 시간 32[s] | 손실 2.77
# | 에폭 1 |  반복 421 / 9295 | 시간 33[s] | 손실 2.74
# | 에폭 1 |  반복 441 / 9295 | 시간 35[s] | 손실 2.74
# | 에폭 1 |  반복 461 / 9295 | 시간 37[s] | 손실 2.72
# | 에폭 1 |  반복 481 / 9295 | 시간 38[s] | 손실 2.69
# | 에폭 1 |  반복 501 / 9295 | 시간 40[s] | 손실 2.70
# | 에폭 1 |  반복 521 / 9295 | 시간 41[s] | 손실 2.67
# | 에폭 1 |  반복 541 / 9295 | 시간 43[s] | 손실 2.68
# | 에폭 1 |  반복 561 / 9295 | 시간 45[s] | 손실 2.65
# | 에폭 1 |  반복 581 / 9295 | 시간 47[s] | 손실 2.67
# | 에폭 1 |  반복 601 / 9295 | 시간 49[s] | 손실 2.66
# | 에폭 1 |  반복 621 / 9295 | 시간 51[s] | 손실 2.65
# | 에폭 1 |  반복 641 / 9295 | 시간 53[s] | 손실 2.65
# | 에폭 1 |  반복 661 / 9295 | 시간 54[s] | 손실 2.63
# | 에폭 1 |  반복 681 / 9295 | 시간 56[s] | 손실 2.63
# | 에폭 1 |  반복 701 / 9295 | 시간 58[s] | 손실 2.62
# | 에폭 1 |  반복 721 / 9295 | 시간 59[s] | 손실 2.62
# | 에폭 1 |  반복 741 / 9295 | 시간 61[s] | 손실 2.60
# | 에폭 1 |  반복 761 / 9295 | 시간 62[s] | 손실 2.59
# | 에폭 1 |  반복 781 / 9295 | 시간 64[s] | 손실 2.60
# | 에폭 1 |  반복 801 / 9295 | 시간 66[s] | 손실 2.58
# | 에폭 1 |  반복 821 / 9295 | 시간 67[s] | 손실 2.58
# | 에폭 1 |  반복 841 / 9295 | 시간 69[s] | 손실 2.60
# | 에폭 1 |  반복 861 / 9295 | 시간 71[s] | 손실 2.59
# | 에폭 1 |  반복 881 / 9295 | 시간 73[s] | 손실 2.56
# | 에폭 1 |  반복 901 / 9295 | 시간 74[s] | 손실 2.57
# | 에폭 1 |  반복 921 / 9295 | 시간 76[s] | 손실 2.60
# | 에폭 1 |  반복 941 / 9295 | 시간 77[s] | 손실 2.58
# | 에폭 1 |  반복 961 / 9295 | 시간 79[s] | 손실 2.56
# | 에폭 1 |  반복 981 / 9295 | 시간 81[s] | 손실 2.59
# | 에폭 1 |  반복 1001 / 9295 | 시간 82[s] | 손실 2.57
# | 에폭 1 |  반복 1021 / 9295 | 시간 84[s] | 손실 2.53
# | 에폭 1 |  반복 1041 / 9295 | 시간 85[s] | 손실 2.57
# | 에폭 1 |  반복 1061 / 9295 | 시간 87[s] | 손실 2.59
# | 에폭 1 |  반복 1081 / 9295 | 시간 88[s] | 손실 2.52
# | 에폭 1 |  반복 1101 / 9295 | 시간 90[s] | 손실 2.56
# | 에폭 1 |  반복 1121 / 9295 | 시간 92[s] | 손실 2.51
# | 에폭 1 |  반복 1141 / 9295 | 시간 93[s] | 손실 2.56
# | 에폭 1 |  반복 1161 / 9295 | 시간 95[s] | 손실 2.56
# | 에폭 1 |  반복 1181 / 9295 | 시간 96[s] | 손실 2.53
# | 에폭 1 |  반복 1201 / 9295 | 시간 98[s] | 손실 2.53
# | 에폭 1 |  반복 1221 / 9295 | 시간 99[s] | 손실 2.54
# | 에폭 1 |  반복 1241 / 9295 | 시간 101[s] | 손실 2.50
# | 에폭 1 |  반복 1261 / 9295 | 시간 103[s] | 손실 2.53
# | 에폭 1 |  반복 1281 / 9295 | 시간 104[s] | 손실 2.51
# | 에폭 1 |  반복 1301 / 9295 | 시간 106[s] | 손실 2.50
# | 에폭 1 |  반복 1321 / 9295 | 시간 108[s] | 손실 2.49
# | 에폭 1 |  반복 1341 / 9295 | 시간 109[s] | 손실 2.55
# | 에폭 1 |  반복 1361 / 9295 | 시간 111[s] | 손실 2.53
# | 에폭 1 |  반복 1381 / 9295 | 시간 113[s] | 손실 2.50
# | 에폭 1 |  반복 1401 / 9295 | 시간 114[s] | 손실 2.54
# | 에폭 1 |  반복 1421 / 9295 | 시간 116[s] | 손실 2.51
# | 에폭 1 |  반복 1441 / 9295 | 시간 117[s] | 손실 2.53
# | 에폭 1 |  반복 1461 / 9295 | 시간 119[s] | 손실 2.50
# | 에폭 1 |  반복 1481 / 9295 | 시간 121[s] | 손실 2.51
# | 에폭 1 |  반복 1501 / 9295 | 시간 122[s] | 손실 2.51
# | 에폭 1 |  반복 1521 / 9295 | 시간 124[s] | 손실 2.51
# | 에폭 1 |  반복 1541 / 9295 | 시간 125[s] | 손실 2.51
# | 에폭 1 |  반복 1561 / 9295 | 시간 127[s] | 손실 2.52
# | 에폭 1 |  반복 1581 / 9295 | 시간 128[s] | 손실 2.49
# | 에폭 1 |  반복 1601 / 9295 | 시간 130[s] | 손실 2.54
# | 에폭 1 |  반복 1621 / 9295 | 시간 132[s] | 손실 2.50
# | 에폭 1 |  반복 1641 / 9295 | 시간 133[s] | 손실 2.49
# | 에폭 1 |  반복 1661 / 9295 | 시간 135[s] | 손실 2.51
# | 에폭 1 |  반복 1681 / 9295 | 시간 137[s] | 손실 2.50
# | 에폭 1 |  반복 1701 / 9295 | 시간 138[s] | 손실 2.49
# | 에폭 1 |  반복 1721 / 9295 | 시간 140[s] | 손실 2.49
# | 에폭 1 |  반복 1741 / 9295 | 시간 142[s] | 손실 2.50
# | 에폭 1 |  반복 1761 / 9295 | 시간 143[s] | 손실 2.52
# | 에폭 1 |  반복 1781 / 9295 | 시간 145[s] | 손실 2.47
# | 에폭 1 |  반복 1801 / 9295 | 시간 146[s] | 손실 2.48
# | 에폭 1 |  반복 1821 / 9295 | 시간 148[s] | 손실 2.49
# | 에폭 1 |  반복 1841 / 9295 | 시간 149[s] | 손실 2.47
# | 에폭 1 |  반복 1861 / 9295 | 시간 151[s] | 손실 2.48
# | 에폭 1 |  반복 1881 / 9295 | 시간 153[s] | 손실 2.49
# | 에폭 1 |  반복 1901 / 9295 | 시간 154[s] | 손실 2.48
# | 에폭 1 |  반복 1921 / 9295 | 시간 156[s] | 손실 2.48
# | 에폭 1 |  반복 1941 / 9295 | 시간 157[s] | 손실 2.48
# | 에폭 1 |  반복 1961 / 9295 | 시간 159[s] | 손실 2.50
# | 에폭 1 |  반복 1981 / 9295 | 시간 161[s] | 손실 2.50
# | 에폭 1 |  반복 2001 / 9295 | 시간 162[s] | 손실 2.50
# | 에폭 1 |  반복 2021 / 9295 | 시간 164[s] | 손실 2.47
# | 에폭 1 |  반복 2041 / 9295 | 시간 166[s] | 손실 2.51
# | 에폭 1 |  반복 2061 / 9295 | 시간 167[s] | 손실 2.48
# | 에폭 1 |  반복 2081 / 9295 | 시간 169[s] | 손실 2.48
# | 에폭 1 |  반복 2101 / 9295 | 시간 170[s] | 손실 2.50
# | 에폭 1 |  반복 2121 / 9295 | 시간 172[s] | 손실 2.47
# | 에폭 1 |  반복 2141 / 9295 | 시간 174[s] | 손실 2.48
# | 에폭 1 |  반복 2161 / 9295 | 시간 175[s] | 손실 2.48
# | 에폭 1 |  반복 2181 / 9295 | 시간 177[s] | 손실 2.47
# | 에폭 1 |  반복 2201 / 9295 | 시간 178[s] | 손실 2.49
# | 에폭 1 |  반복 2221 / 9295 | 시간 180[s] | 손실 2.48
# | 에폭 1 |  반복 2241 / 9295 | 시간 182[s] | 손실 2.50
# | 에폭 1 |  반복 2261 / 9295 | 시간 183[s] | 손실 2.48
# | 에폭 1 |  반복 2281 / 9295 | 시간 185[s] | 손실 2.46
# | 에폭 1 |  반복 2301 / 9295 | 시간 186[s] | 손실 2.46
# | 에폭 1 |  반복 2321 / 9295 | 시간 188[s] | 손실 2.49
# | 에폭 1 |  반복 2341 / 9295 | 시간 189[s] | 손실 2.49
# | 에폭 1 |  반복 2361 / 9295 | 시간 191[s] | 손실 2.47
# | 에폭 1 |  반복 2381 / 9295 | 시간 193[s] | 손실 2.49
# | 에폭 1 |  반복 2401 / 9295 | 시간 194[s] | 손실 2.48
# | 에폭 1 |  반복 2421 / 9295 | 시간 196[s] | 손실 2.47
# | 에폭 1 |  반복 2441 / 9295 | 시간 197[s] | 손실 2.47
# | 에폭 1 |  반복 2461 / 9295 | 시간 199[s] | 손실 2.44
# | 에폭 1 |  반복 2481 / 9295 | 시간 200[s] | 손실 2.47
# | 에폭 1 |  반복 2501 / 9295 | 시간 202[s] | 손실 2.47
# | 에폭 1 |  반복 2521 / 9295 | 시간 204[s] | 손실 2.45
# | 에폭 1 |  반복 2541 / 9295 | 시간 205[s] | 손실 2.49
# | 에폭 1 |  반복 2561 / 9295 | 시간 207[s] | 손실 2.45
# | 에폭 1 |  반복 2581 / 9295 | 시간 208[s] | 손실 2.47
# | 에폭 1 |  반복 2601 / 9295 | 시간 210[s] | 손실 2.46
# | 에폭 1 |  반복 2621 / 9295 | 시간 211[s] | 손실 2.47
# | 에폭 1 |  반복 2641 / 9295 | 시간 213[s] | 손실 2.44
# | 에폭 1 |  반복 2661 / 9295 | 시간 215[s] | 손실 2.44
# | 에폭 1 |  반복 2681 / 9295 | 시간 216[s] | 손실 2.48
# | 에폭 1 |  반복 2701 / 9295 | 시간 218[s] | 손실 2.45
# | 에폭 1 |  반복 2721 / 9295 | 시간 219[s] | 손실 2.48
# | 에폭 1 |  반복 2741 / 9295 | 시간 221[s] | 손실 2.48
# | 에폭 1 |  반복 2761 / 9295 | 시간 223[s] | 손실 2.44
# | 에폭 1 |  반복 2781 / 9295 | 시간 224[s] | 손실 2.47
# | 에폭 1 |  반복 2801 / 9295 | 시간 226[s] | 손실 2.46
# | 에폭 1 |  반복 2821 / 9295 | 시간 227[s] | 손실 2.45
# | 에폭 1 |  반복 2841 / 9295 | 시간 229[s] | 손실 2.45
# | 에폭 1 |  반복 2861 / 9295 | 시간 231[s] | 손실 2.46
# | 에폭 1 |  반복 2881 / 9295 | 시간 232[s] | 손실 2.46
# | 에폭 1 |  반복 2901 / 9295 | 시간 234[s] | 손실 2.43
# | 에폭 1 |  반복 2921 / 9295 | 시간 236[s] | 손실 2.46
# | 에폭 1 |  반복 2941 / 9295 | 시간 237[s] | 손실 2.42
# | 에폭 1 |  반복 2961 / 9295 | 시간 239[s] | 손실 2.48
# | 에폭 1 |  반복 2981 / 9295 | 시간 240[s] | 손실 2.47
# | 에폭 1 |  반복 3001 / 9295 | 시간 242[s] | 손실 2.45
# | 에폭 1 |  반복 3021 / 9295 | 시간 243[s] | 손실 2.40
# | 에폭 1 |  반복 3041 / 9295 | 시간 245[s] | 손실 2.43
# | 에폭 1 |  반복 3061 / 9295 | 시간 246[s] | 손실 2.46
# | 에폭 1 |  반복 3081 / 9295 | 시간 248[s] | 손실 2.41
# | 에폭 1 |  반복 3101 / 9295 | 시간 250[s] | 손실 2.44
# | 에폭 1 |  반복 3121 / 9295 | 시간 252[s] | 손실 2.43
# | 에폭 1 |  반복 3141 / 9295 | 시간 253[s] | 손실 2.45
# | 에폭 1 |  반복 3161 / 9295 | 시간 255[s] | 손실 2.46
# | 에폭 1 |  반복 3181 / 9295 | 시간 257[s] | 손실 2.44
# | 에폭 1 |  반복 3201 / 9295 | 시간 258[s] | 손실 2.45
# | 에폭 1 |  반복 3221 / 9295 | 시간 260[s] | 손실 2.42
# | 에폭 1 |  반복 3241 / 9295 | 시간 262[s] | 손실 2.44
# | 에폭 1 |  반복 3261 / 9295 | 시간 263[s] | 손실 2.44
# | 에폭 1 |  반복 3281 / 9295 | 시간 265[s] | 손실 2.44
# | 에폭 1 |  반복 3301 / 9295 | 시간 266[s] | 손실 2.44
# | 에폭 1 |  반복 3321 / 9295 | 시간 268[s] | 손실 2.39
# | 에폭 1 |  반복 3341 / 9295 | 시간 270[s] | 손실 2.45
# | 에폭 1 |  반복 3361 / 9295 | 시간 271[s] | 손실 2.42
# | 에폭 1 |  반복 3381 / 9295 | 시간 273[s] | 손실 2.40
# | 에폭 1 |  반복 3401 / 9295 | 시간 275[s] | 손실 2.43
# | 에폭 1 |  반복 3421 / 9295 | 시간 276[s] | 손실 2.42
# | 에폭 1 |  반복 3441 / 9295 | 시간 278[s] | 손실 2.44
# | 에폭 1 |  반복 3461 / 9295 | 시간 279[s] | 손실 2.41
# | 에폭 1 |  반복 3481 / 9295 | 시간 281[s] | 손실 2.42
# | 에폭 1 |  반복 3501 / 9295 | 시간 283[s] | 손실 2.45
# | 에폭 1 |  반복 3521 / 9295 | 시간 284[s] | 손실 2.41
# | 에폭 1 |  반복 3541 / 9295 | 시간 286[s] | 손실 2.42
# | 에폭 1 |  반복 3561 / 9295 | 시간 287[s] | 손실 2.42
# | 에폭 1 |  반복 3581 / 9295 | 시간 289[s] | 손실 2.44
# | 에폭 1 |  반복 3601 / 9295 | 시간 291[s] | 손실 2.44
# | 에폭 1 |  반복 3621 / 9295 | 시간 293[s] | 손실 2.44
# | 에폭 1 |  반복 3641 / 9295 | 시간 294[s] | 손실 2.42
# | 에폭 1 |  반복 3661 / 9295 | 시간 296[s] | 손실 2.42
# | 에폭 1 |  반복 3681 / 9295 | 시간 297[s] | 손실 2.41
# | 에폭 1 |  반복 3701 / 9295 | 시간 299[s] | 손실 2.42
# | 에폭 1 |  반복 3721 / 9295 | 시간 301[s] | 손실 2.43
# | 에폭 1 |  반복 3741 / 9295 | 시간 302[s] | 손실 2.40
# | 에폭 1 |  반복 3761 / 9295 | 시간 304[s] | 손실 2.40
# | 에폭 1 |  반복 3781 / 9295 | 시간 305[s] | 손실 2.44
# | 에폭 1 |  반복 3801 / 9295 | 시간 307[s] | 손실 2.41
# | 에폭 1 |  반복 3821 / 9295 | 시간 309[s] | 손실 2.41
# | 에폭 1 |  반복 3841 / 9295 | 시간 310[s] | 손실 2.40
# | 에폭 1 |  반복 3861 / 9295 | 시간 312[s] | 손실 2.40
# | 에폭 1 |  반복 3881 / 9295 | 시간 314[s] | 손실 2.39
# | 에폭 1 |  반복 3901 / 9295 | 시간 315[s] | 손실 2.39
# | 에폭 1 |  반복 3921 / 9295 | 시간 317[s] | 손실 2.41
# | 에폭 1 |  반복 3941 / 9295 | 시간 318[s] | 손실 2.41
# | 에폭 1 |  반복 3961 / 9295 | 시간 320[s] | 손실 2.41
# | 에폭 1 |  반복 3981 / 9295 | 시간 321[s] | 손실 2.38
# | 에폭 1 |  반복 4001 / 9295 | 시간 323[s] | 손실 2.40
# | 에폭 1 |  반복 4021 / 9295 | 시간 325[s] | 손실 2.39
# | 에폭 1 |  반복 4041 / 9295 | 시간 326[s] | 손실 2.39
# | 에폭 1 |  반복 4061 / 9295 | 시간 328[s] | 손실 2.40
# | 에폭 1 |  반복 4081 / 9295 | 시간 329[s] | 손실 2.41
# | 에폭 1 |  반복 4101 / 9295 | 시간 331[s] | 손실 2.40
# | 에폭 1 |  반복 4121 / 9295 | 시간 332[s] | 손실 2.41
# | 에폭 1 |  반복 4141 / 9295 | 시간 334[s] | 손실 2.39
# | 에폭 1 |  반복 4161 / 9295 | 시간 336[s] | 손실 2.40
# | 에폭 1 |  반복 4181 / 9295 | 시간 337[s] | 손실 2.39
# | 에폭 1 |  반복 4201 / 9295 | 시간 339[s] | 손실 2.39
# | 에폭 1 |  반복 4221 / 9295 | 시간 341[s] | 손실 2.40
# | 에폭 1 |  반복 4241 / 9295 | 시간 342[s] | 손실 2.39
# | 에폭 1 |  반복 4261 / 9295 | 시간 344[s] | 손실 2.40
# | 에폭 1 |  반복 4281 / 9295 | 시간 345[s] | 손실 2.38
# | 에폭 1 |  반복 4301 / 9295 | 시간 347[s] | 손실 2.42
# | 에폭 1 |  반복 4321 / 9295 | 시간 349[s] | 손실 2.38
# | 에폭 1 |  반복 4341 / 9295 | 시간 350[s] | 손실 2.38
# | 에폭 1 |  반복 4361 / 9295 | 시간 352[s] | 손실 2.36
# | 에폭 1 |  반복 4381 / 9295 | 시간 353[s] | 손실 2.39
# | 에폭 1 |  반복 4401 / 9295 | 시간 355[s] | 손실 2.39
# | 에폭 1 |  반복 4421 / 9295 | 시간 357[s] | 손실 2.37
# | 에폭 1 |  반복 4441 / 9295 | 시간 358[s] | 손실 2.37
# | 에폭 1 |  반복 4461 / 9295 | 시간 360[s] | 손실 2.35
# | 에폭 1 |  반복 4481 / 9295 | 시간 361[s] | 손실 2.38
# | 에폭 1 |  반복 4501 / 9295 | 시간 363[s] | 손실 2.37
# | 에폭 1 |  반복 4521 / 9295 | 시간 365[s] | 손실 2.39
# | 에폭 1 |  반복 4541 / 9295 | 시간 366[s] | 손실 2.36
# | 에폭 1 |  반복 4561 / 9295 | 시간 368[s] | 손실 2.38
# | 에폭 1 |  반복 4581 / 9295 | 시간 369[s] | 손실 2.36
# | 에폭 1 |  반복 4601 / 9295 | 시간 371[s] | 손실 2.37
# | 에폭 1 |  반복 4621 / 9295 | 시간 373[s] | 손실 2.36
# | 에폭 1 |  반복 4641 / 9295 | 시간 374[s] | 손실 2.38
# | 에폭 1 |  반복 4661 / 9295 | 시간 376[s] | 손실 2.38
# | 에폭 1 |  반복 4681 / 9295 | 시간 377[s] | 손실 2.37
# | 에폭 1 |  반복 4701 / 9295 | 시간 379[s] | 손실 2.36
# | 에폭 1 |  반복 4721 / 9295 | 시간 381[s] | 손실 2.37
# | 에폭 1 |  반복 4741 / 9295 | 시간 382[s] | 손실 2.39
# | 에폭 1 |  반복 4761 / 9295 | 시간 384[s] | 손실 2.38
# | 에폭 1 |  반복 4781 / 9295 | 시간 386[s] | 손실 2.36
# | 에폭 1 |  반복 4801 / 9295 | 시간 387[s] | 손실 2.36
# | 에폭 1 |  반복 4821 / 9295 | 시간 389[s] | 손실 2.36
# | 에폭 1 |  반복 4841 / 9295 | 시간 390[s] | 손실 2.34
# | 에폭 1 |  반복 4861 / 9295 | 시간 392[s] | 손실 2.37
# | 에폭 1 |  반복 4881 / 9295 | 시간 393[s] | 손실 2.37
# | 에폭 1 |  반복 4901 / 9295 | 시간 395[s] | 손실 2.36
# | 에폭 1 |  반복 4921 / 9295 | 시간 396[s] | 손실 2.35
# | 에폭 1 |  반복 4941 / 9295 | 시간 398[s] | 손실 2.36
# | 에폭 1 |  반복 4961 / 9295 | 시간 400[s] | 손실 2.35
# | 에폭 1 |  반복 4981 / 9295 | 시간 401[s] | 손실 2.36
# | 에폭 1 |  반복 5001 / 9295 | 시간 403[s] | 손실 2.37
# | 에폭 1 |  반복 5021 / 9295 | 시간 405[s] | 손실 2.34
# | 에폭 1 |  반복 5041 / 9295 | 시간 406[s] | 손실 2.34
# | 에폭 1 |  반복 5061 / 9295 | 시간 408[s] | 손실 2.38
# | 에폭 1 |  반복 5081 / 9295 | 시간 409[s] | 손실 2.29
# | 에폭 1 |  반복 5101 / 9295 | 시간 411[s] | 손실 2.34
# | 에폭 1 |  반복 5121 / 9295 | 시간 413[s] | 손실 2.37
# | 에폭 1 |  반복 5141 / 9295 | 시간 414[s] | 손실 2.33
# | 에폭 1 |  반복 5161 / 9295 | 시간 416[s] | 손실 2.35
# | 에폭 1 |  반복 5181 / 9295 | 시간 417[s] | 손실 2.38
# | 에폭 1 |  반복 5201 / 9295 | 시간 419[s] | 손실 2.31
# | 에폭 1 |  반복 5221 / 9295 | 시간 421[s] | 손실 2.35
# | 에폭 1 |  반복 5241 / 9295 | 시간 422[s] | 손실 2.37
# | 에폭 1 |  반복 5261 / 9295 | 시간 424[s] | 손실 2.33
# | 에폭 1 |  반복 5281 / 9295 | 시간 425[s] | 손실 2.33
# | 에폭 1 |  반복 5301 / 9295 | 시간 427[s] | 손실 2.37
# | 에폭 1 |  반복 5321 / 9295 | 시간 428[s] | 손실 2.35
# | 에폭 1 |  반복 5341 / 9295 | 시간 430[s] | 손실 2.32
# | 에폭 1 |  반복 5361 / 9295 | 시간 432[s] | 손실 2.37
# | 에폭 1 |  반복 5381 / 9295 | 시간 433[s] | 손실 2.35
# | 에폭 1 |  반복 5401 / 9295 | 시간 435[s] | 손실 2.36
# | 에폭 1 |  반복 5421 / 9295 | 시간 437[s] | 손실 2.35
# | 에폭 1 |  반복 5441 / 9295 | 시간 439[s] | 손실 2.35
# | 에폭 1 |  반복 5461 / 9295 | 시간 440[s] | 손실 2.36
# | 에폭 1 |  반복 5481 / 9295 | 시간 442[s] | 손실 2.34
# | 에폭 1 |  반복 5501 / 9295 | 시간 443[s] | 손실 2.31
# | 에폭 1 |  반복 5521 / 9295 | 시간 445[s] | 손실 2.34
# | 에폭 1 |  반복 5541 / 9295 | 시간 446[s] | 손실 2.35
# | 에폭 1 |  반복 5561 / 9295 | 시간 448[s] | 손실 2.36
# | 에폭 1 |  반복 5581 / 9295 | 시간 449[s] | 손실 2.34
# | 에폭 1 |  반복 5601 / 9295 | 시간 451[s] | 손실 2.35
# | 에폭 1 |  반복 5621 / 9295 | 시간 453[s] | 손실 2.34
# | 에폭 1 |  반복 5641 / 9295 | 시간 454[s] | 손실 2.37
# | 에폭 1 |  반복 5661 / 9295 | 시간 456[s] | 손실 2.31
# | 에폭 1 |  반복 5681 / 9295 | 시간 458[s] | 손실 2.37
# | 에폭 1 |  반복 5701 / 9295 | 시간 459[s] | 손실 2.36
# | 에폭 1 |  반복 5721 / 9295 | 시간 461[s] | 손실 2.35
# | 에폭 1 |  반복 5741 / 9295 | 시간 462[s] | 손실 2.36
# | 에폭 1 |  반복 5761 / 9295 | 시간 464[s] | 손실 2.34
# | 에폭 1 |  반복 5781 / 9295 | 시간 465[s] | 손실 2.32
# | 에폭 1 |  반복 5801 / 9295 | 시간 467[s] | 손실 2.34
# | 에폭 1 |  반복 5821 / 9295 | 시간 468[s] | 손실 2.38
# | 에폭 1 |  반복 5841 / 9295 | 시간 470[s] | 손실 2.32
# | 에폭 1 |  반복 5861 / 9295 | 시간 472[s] | 손실 2.28
# | 에폭 1 |  반복 5881 / 9295 | 시간 473[s] | 손실 2.31
# | 에폭 1 |  반복 5901 / 9295 | 시간 475[s] | 손실 2.30
# | 에폭 1 |  반복 5921 / 9295 | 시간 477[s] | 손실 2.35
# | 에폭 1 |  반복 5941 / 9295 | 시간 478[s] | 손실 2.31
# | 에폭 1 |  반복 5961 / 9295 | 시간 480[s] | 손실 2.37
# | 에폭 1 |  반복 5981 / 9295 | 시간 481[s] | 손실 2.33
# | 에폭 1 |  반복 6001 / 9295 | 시간 483[s] | 손실 2.32
# | 에폭 1 |  반복 6021 / 9295 | 시간 484[s] | 손실 2.30
# | 에폭 1 |  반복 6041 / 9295 | 시간 486[s] | 손실 2.35
# | 에폭 1 |  반복 6061 / 9295 | 시간 487[s] | 손실 2.30
# | 에폭 1 |  반복 6081 / 9295 | 시간 489[s] | 손실 2.29
# | 에폭 1 |  반복 6101 / 9295 | 시간 491[s] | 손실 2.33
# | 에폭 1 |  반복 6121 / 9295 | 시간 492[s] | 손실 2.32
# | 에폭 1 |  반복 6141 / 9295 | 시간 494[s] | 손실 2.32
# | 에폭 1 |  반복 6161 / 9295 | 시간 495[s] | 손실 2.31
# | 에폭 1 |  반복 6181 / 9295 | 시간 497[s] | 손실 2.35
# | 에폭 1 |  반복 6201 / 9295 | 시간 499[s] | 손실 2.32
# | 에폭 1 |  반복 6221 / 9295 | 시간 500[s] | 손실 2.34
# | 에폭 1 |  반복 6241 / 9295 | 시간 502[s] | 손실 2.29
# | 에폭 1 |  반복 6261 / 9295 | 시간 504[s] | 손실 2.33
# | 에폭 1 |  반복 6281 / 9295 | 시간 505[s] | 손실 2.31
# | 에폭 1 |  반복 6301 / 9295 | 시간 507[s] | 손실 2.32
# | 에폭 1 |  반복 6321 / 9295 | 시간 509[s] | 손실 2.29
# | 에폭 1 |  반복 6341 / 9295 | 시간 510[s] | 손실 2.32
# | 에폭 1 |  반복 6361 / 9295 | 시간 512[s] | 손실 2.31
# | 에폭 1 |  반복 6381 / 9295 | 시간 513[s] | 손실 2.31
# | 에폭 1 |  반복 6401 / 9295 | 시간 515[s] | 손실 2.30
# | 에폭 1 |  반복 6421 / 9295 | 시간 517[s] | 손실 2.29
# | 에폭 1 |  반복 6441 / 9295 | 시간 518[s] | 손실 2.31
# | 에폭 1 |  반복 6461 / 9295 | 시간 520[s] | 손실 2.33
# | 에폭 1 |  반복 6481 / 9295 | 시간 521[s] | 손실 2.31
# | 에폭 1 |  반복 6501 / 9295 | 시간 523[s] | 손실 2.33
# | 에폭 1 |  반복 6521 / 9295 | 시간 525[s] | 손실 2.31
# | 에폭 1 |  반복 6541 / 9295 | 시간 526[s] | 손실 2.29
# | 에폭 1 |  반복 6561 / 9295 | 시간 528[s] | 손실 2.35
# | 에폭 1 |  반복 6581 / 9295 | 시간 530[s] | 손실 2.32
# | 에폭 1 |  반복 6601 / 9295 | 시간 531[s] | 손실 2.28
# | 에폭 1 |  반복 6621 / 9295 | 시간 533[s] | 손실 2.30
# | 에폭 1 |  반복 6641 / 9295 | 시간 534[s] | 손실 2.29
# | 에폭 1 |  반복 6661 / 9295 | 시간 536[s] | 손실 2.28
# | 에폭 1 |  반복 6681 / 9295 | 시간 538[s] | 손실 2.32
# | 에폭 1 |  반복 6701 / 9295 | 시간 539[s] | 손실 2.29
# | 에폭 1 |  반복 6721 / 9295 | 시간 541[s] | 손실 2.30
# | 에폭 1 |  반복 6741 / 9295 | 시간 543[s] | 손실 2.29
# | 에폭 1 |  반복 6761 / 9295 | 시간 544[s] | 손실 2.31
# | 에폭 1 |  반복 6781 / 9295 | 시간 546[s] | 손실 2.28
# | 에폭 1 |  반복 6801 / 9295 | 시간 548[s] | 손실 2.31
# | 에폭 1 |  반복 6821 / 9295 | 시간 550[s] | 손실 2.30
# | 에폭 1 |  반복 6841 / 9295 | 시간 551[s] | 손실 2.29
# | 에폭 1 |  반복 6861 / 9295 | 시간 553[s] | 손실 2.30
# | 에폭 1 |  반복 6881 / 9295 | 시간 555[s] | 손실 2.30
# | 에폭 1 |  반복 6901 / 9295 | 시간 556[s] | 손실 2.31
# | 에폭 1 |  반복 6921 / 9295 | 시간 558[s] | 손실 2.27
# | 에폭 1 |  반복 6941 / 9295 | 시간 560[s] | 손실 2.32
# | 에폭 1 |  반복 6961 / 9295 | 시간 561[s] | 손실 2.28
# | 에폭 1 |  반복 6981 / 9295 | 시간 563[s] | 손실 2.29
# | 에폭 1 |  반복 7001 / 9295 | 시간 565[s] | 손실 2.29
# | 에폭 1 |  반복 7021 / 9295 | 시간 567[s] | 손실 2.28
# | 에폭 1 |  반복 7041 / 9295 | 시간 568[s] | 손실 2.28
# | 에폭 1 |  반복 7061 / 9295 | 시간 570[s] | 손실 2.28
# | 에폭 1 |  반복 7081 / 9295 | 시간 572[s] | 손실 2.32
# | 에폭 1 |  반복 7101 / 9295 | 시간 573[s] | 손실 2.30
# | 에폭 1 |  반복 7121 / 9295 | 시간 575[s] | 손실 2.32
# | 에폭 1 |  반복 7141 / 9295 | 시간 577[s] | 손실 2.27
# | 에폭 1 |  반복 7161 / 9295 | 시간 578[s] | 손실 2.29
# | 에폭 1 |  반복 7181 / 9295 | 시간 580[s] | 손실 2.29
# | 에폭 1 |  반복 7201 / 9295 | 시간 582[s] | 손실 2.27
# | 에폭 1 |  반복 7221 / 9295 | 시간 583[s] | 손실 2.28
# | 에폭 1 |  반복 7241 / 9295 | 시간 585[s] | 손실 2.26
# | 에폭 1 |  반복 7261 / 9295 | 시간 587[s] | 손실 2.26
# | 에폭 1 |  반복 7281 / 9295 | 시간 588[s] | 손실 2.29
# | 에폭 1 |  반복 7301 / 9295 | 시간 590[s] | 손실 2.31
# | 에폭 1 |  반복 7321 / 9295 | 시간 591[s] | 손실 2.28
# | 에폭 1 |  반복 7341 / 9295 | 시간 593[s] | 손실 2.28
# | 에폭 1 |  반복 7361 / 9295 | 시간 594[s] | 손실 2.24
# | 에폭 1 |  반복 7381 / 9295 | 시간 596[s] | 손실 2.27
# | 에폭 1 |  반복 7401 / 9295 | 시간 598[s] | 손실 2.28
# | 에폭 1 |  반복 7421 / 9295 | 시간 599[s] | 손실 2.30
# | 에폭 1 |  반복 7441 / 9295 | 시간 601[s] | 손실 2.27
# | 에폭 1 |  반복 7461 / 9295 | 시간 603[s] | 손실 2.29
# | 에폭 1 |  반복 7481 / 9295 | 시간 604[s] | 손실 2.27
# | 에폭 1 |  반복 7501 / 9295 | 시간 606[s] | 손실 2.28
# | 에폭 1 |  반복 7521 / 9295 | 시간 608[s] | 손실 2.29
# | 에폭 1 |  반복 7541 / 9295 | 시간 609[s] | 손실 2.29
# | 에폭 1 |  반복 7561 / 9295 | 시간 611[s] | 손실 2.29
# | 에폭 1 |  반복 7581 / 9295 | 시간 612[s] | 손실 2.26
# | 에폭 1 |  반복 7601 / 9295 | 시간 614[s] | 손실 2.30
# | 에폭 1 |  반복 7621 / 9295 | 시간 616[s] | 손실 2.25
# | 에폭 1 |  반복 7641 / 9295 | 시간 617[s] | 손실 2.26
# | 에폭 1 |  반복 7661 / 9295 | 시간 619[s] | 손실 2.26
# | 에폭 1 |  반복 7681 / 9295 | 시간 621[s] | 손실 2.27
# | 에폭 1 |  반복 7701 / 9295 | 시간 622[s] | 손실 2.28
# | 에폭 1 |  반복 7721 / 9295 | 시간 624[s] | 손실 2.26
# | 에폭 1 |  반복 7741 / 9295 | 시간 625[s] | 손실 2.28
# | 에폭 1 |  반복 7761 / 9295 | 시간 627[s] | 손실 2.28
# | 에폭 1 |  반복 7781 / 9295 | 시간 629[s] | 손실 2.27
# | 에폭 1 |  반복 7801 / 9295 | 시간 630[s] | 손실 2.29
# | 에폭 1 |  반복 7821 / 9295 | 시간 632[s] | 손실 2.27
# | 에폭 1 |  반복 7841 / 9295 | 시간 633[s] | 손실 2.25
# | 에폭 1 |  반복 7861 / 9295 | 시간 635[s] | 손실 2.26
# | 에폭 1 |  반복 7881 / 9295 | 시간 637[s] | 손실 2.23
# | 에폭 1 |  반복 7901 / 9295 | 시간 638[s] | 손실 2.27
# | 에폭 1 |  반복 7921 / 9295 | 시간 640[s] | 손실 2.24
# | 에폭 1 |  반복 7941 / 9295 | 시간 642[s] | 손실 2.26
# | 에폭 1 |  반복 7961 / 9295 | 시간 643[s] | 손실 2.29
# | 에폭 1 |  반복 7981 / 9295 | 시간 645[s] | 손실 2.32
# | 에폭 1 |  반복 8001 / 9295 | 시간 646[s] | 손실 2.23
# | 에폭 1 |  반복 8021 / 9295 | 시간 648[s] | 손실 2.22
# | 에폭 1 |  반복 8041 / 9295 | 시간 649[s] | 손실 2.28
# | 에폭 1 |  반복 8061 / 9295 | 시간 651[s] | 손실 2.25
# | 에폭 1 |  반복 8081 / 9295 | 시간 653[s] | 손실 2.24
# | 에폭 1 |  반복 8101 / 9295 | 시간 655[s] | 손실 2.25
# | 에폭 1 |  반복 8121 / 9295 | 시간 657[s] | 손실 2.26
# | 에폭 1 |  반복 8141 / 9295 | 시간 659[s] | 손실 2.23
# | 에폭 1 |  반복 8161 / 9295 | 시간 661[s] | 손실 2.24
# | 에폭 1 |  반복 8181 / 9295 | 시간 663[s] | 손실 2.23
# | 에폭 1 |  반복 8201 / 9295 | 시간 665[s] | 손실 2.22
# | 에폭 1 |  반복 8221 / 9295 | 시간 666[s] | 손실 2.26
# | 에폭 1 |  반복 8241 / 9295 | 시간 668[s] | 손실 2.27
# | 에폭 1 |  반복 8261 / 9295 | 시간 669[s] | 손실 2.22
# | 에폭 1 |  반복 8281 / 9295 | 시간 671[s] | 손실 2.27
# | 에폭 1 |  반복 8301 / 9295 | 시간 672[s] | 손실 2.21
# | 에폭 1 |  반복 8321 / 9295 | 시간 674[s] | 손실 2.20
# | 에폭 1 |  반복 8341 / 9295 | 시간 676[s] | 손실 2.22
# | 에폭 1 |  반복 8361 / 9295 | 시간 677[s] | 손실 2.27
# | 에폭 1 |  반복 8381 / 9295 | 시간 679[s] | 손실 2.25
# | 에폭 1 |  반복 8401 / 9295 | 시간 681[s] | 손실 2.22
# | 에폭 1 |  반복 8421 / 9295 | 시간 682[s] | 손실 2.24
# | 에폭 1 |  반복 8441 / 9295 | 시간 684[s] | 손실 2.23
# | 에폭 1 |  반복 8461 / 9295 | 시간 686[s] | 손실 2.25
# | 에폭 1 |  반복 8481 / 9295 | 시간 687[s] | 손실 2.23
# | 에폭 1 |  반복 8501 / 9295 | 시간 689[s] | 손실 2.21
# | 에폭 1 |  반복 8521 / 9295 | 시간 691[s] | 손실 2.26
# | 에폭 1 |  반복 8541 / 9295 | 시간 692[s] | 손실 2.26
# | 에폭 1 |  반복 8561 / 9295 | 시간 694[s] | 손실 2.25
# | 에폭 1 |  반복 8581 / 9295 | 시간 696[s] | 손실 2.26
# | 에폭 1 |  반복 8601 / 9295 | 시간 697[s] | 손실 2.24
# | 에폭 1 |  반복 8621 / 9295 | 시간 699[s] | 손실 2.23
# | 에폭 1 |  반복 8641 / 9295 | 시간 701[s] | 손실 2.21
# | 에폭 1 |  반복 8661 / 9295 | 시간 702[s] | 손실 2.24
# | 에폭 1 |  반복 8681 / 9295 | 시간 704[s] | 손실 2.25
# | 에폭 1 |  반복 8701 / 9295 | 시간 706[s] | 손실 2.21
# | 에폭 1 |  반복 8721 / 9295 | 시간 707[s] | 손실 2.25
# | 에폭 1 |  반복 8741 / 9295 | 시간 709[s] | 손실 2.23
# | 에폭 1 |  반복 8761 / 9295 | 시간 710[s] | 손실 2.26
# | 에폭 1 |  반복 8781 / 9295 | 시간 712[s] | 손실 2.22
# | 에폭 1 |  반복 8801 / 9295 | 시간 713[s] | 손실 2.22
# | 에폭 1 |  반복 8821 / 9295 | 시간 715[s] | 손실 2.23
# | 에폭 1 |  반복 8841 / 9295 | 시간 717[s] | 손실 2.24
# | 에폭 1 |  반복 8861 / 9295 | 시간 718[s] | 손실 2.25
# | 에폭 1 |  반복 8881 / 9295 | 시간 720[s] | 손실 2.22
# | 에폭 1 |  반복 8901 / 9295 | 시간 721[s] | 손실 2.23
# | 에폭 1 |  반복 8921 / 9295 | 시간 723[s] | 손실 2.24
# | 에폭 1 |  반복 8941 / 9295 | 시간 725[s] | 손실 2.23
# | 에폭 1 |  반복 8961 / 9295 | 시간 726[s] | 손실 2.24
# | 에폭 1 |  반복 8981 / 9295 | 시간 728[s] | 손실 2.21
# | 에폭 1 |  반복 9001 / 9295 | 시간 729[s] | 손실 2.21
# | 에폭 1 |  반복 9021 / 9295 | 시간 731[s] | 손실 2.22
# | 에폭 1 |  반복 9041 / 9295 | 시간 732[s] | 손실 2.21
# | 에폭 1 |  반복 9061 / 9295 | 시간 734[s] | 손실 2.22
# | 에폭 1 |  반복 9081 / 9295 | 시간 736[s] | 손실 2.24
# | 에폭 1 |  반복 9101 / 9295 | 시간 737[s] | 손실 2.20
# | 에폭 1 |  반복 9121 / 9295 | 시간 739[s] | 손실 2.22
# | 에폭 1 |  반복 9141 / 9295 | 시간 741[s] | 손실 2.22
# | 에폭 1 |  반복 9161 / 9295 | 시간 742[s] | 손실 2.21
# | 에폭 1 |  반복 9181 / 9295 | 시간 744[s] | 손실 2.21
# | 에폭 1 |  반복 9201 / 9295 | 시간 746[s] | 손실 2.21
# | 에폭 1 |  반복 9221 / 9295 | 시간 747[s] | 손실 2.23
# | 에폭 1 |  반복 9241 / 9295 | 시간 749[s] | 손실 2.20
# | 에폭 1 |  반복 9261 / 9295 | 시간 751[s] | 손실 2.20
# | 에폭 1 |  반복 9281 / 9295 | 시간 752[s] | 손실 2.21
# | 에폭 2 |  반복 1 / 9295 | 시간 754[s] | 손실 2.20
# | 에폭 2 |  반복 21 / 9295 | 시간 755[s] | 손실 2.20
# | 에폭 2 |  반복 41 / 9295 | 시간 757[s] | 손실 2.16
# | 에폭 2 |  반복 61 / 9295 | 시간 758[s] | 손실 2.19
# | 에폭 2 |  반복 81 / 9295 | 시간 760[s] | 손실 2.18
# | 에폭 2 |  반복 101 / 9295 | 시간 762[s] | 손실 2.19
# | 에폭 2 |  반복 121 / 9295 | 시간 763[s] | 손실 2.16
# | 에폭 2 |  반복 141 / 9295 | 시간 765[s] | 손실 2.15
# | 에폭 2 |  반복 161 / 9295 | 시간 766[s] | 손실 2.18
# | 에폭 2 |  반복 181 / 9295 | 시간 768[s] | 손실 2.15
# | 에폭 2 |  반복 201 / 9295 | 시간 770[s] | 손실 2.16
# | 에폭 2 |  반복 221 / 9295 | 시간 771[s] | 손실 2.19
# | 에폭 2 |  반복 241 / 9295 | 시간 773[s] | 손실 2.18
# | 에폭 2 |  반복 261 / 9295 | 시간 774[s] | 손실 2.18
# | 에폭 2 |  반복 281 / 9295 | 시간 776[s] | 손실 2.18
# | 에폭 2 |  반복 301 / 9295 | 시간 777[s] | 손실 2.16
# | 에폭 2 |  반복 321 / 9295 | 시간 779[s] | 손실 2.19
# | 에폭 2 |  반복 341 / 9295 | 시간 781[s] | 손실 2.19
# | 에폭 2 |  반복 361 / 9295 | 시간 782[s] | 손실 2.15
# | 에폭 2 |  반복 381 / 9295 | 시간 784[s] | 손실 2.15
# | 에폭 2 |  반복 401 / 9295 | 시간 785[s] | 손실 2.20
# | 에폭 2 |  반복 421 / 9295 | 시간 787[s] | 손실 2.19
# | 에폭 2 |  반복 441 / 9295 | 시간 789[s] | 손실 2.17
# | 에폭 2 |  반복 461 / 9295 | 시간 790[s] | 손실 2.21
# | 에폭 2 |  반복 481 / 9295 | 시간 792[s] | 손실 2.18
# | 에폭 2 |  반복 501 / 9295 | 시간 793[s] | 손실 2.16
# | 에폭 2 |  반복 521 / 9295 | 시간 795[s] | 손실 2.18
# | 에폭 2 |  반복 541 / 9295 | 시간 797[s] | 손실 2.14
# | 에폭 2 |  반복 561 / 9295 | 시간 798[s] | 손실 2.17
# | 에폭 2 |  반복 581 / 9295 | 시간 800[s] | 손실 2.17
# | 에폭 2 |  반복 601 / 9295 | 시간 801[s] | 손실 2.19
# | 에폭 2 |  반복 621 / 9295 | 시간 803[s] | 손실 2.14
# | 에폭 2 |  반복 641 / 9295 | 시간 804[s] | 손실 2.20
# | 에폭 2 |  반복 661 / 9295 | 시간 806[s] | 손실 2.14
# | 에폭 2 |  반복 681 / 9295 | 시간 808[s] | 손실 2.18
# | 에폭 2 |  반복 701 / 9295 | 시간 809[s] | 손실 2.18
# | 에폭 2 |  반복 721 / 9295 | 시간 811[s] | 손실 2.18
# | 에폭 2 |  반복 741 / 9295 | 시간 812[s] | 손실 2.18
# | 에폭 2 |  반복 761 / 9295 | 시간 814[s] | 손실 2.17
# | 에폭 2 |  반복 781 / 9295 | 시간 815[s] | 손실 2.17
# | 에폭 2 |  반복 801 / 9295 | 시간 817[s] | 손실 2.17
# | 에폭 2 |  반복 821 / 9295 | 시간 819[s] | 손실 2.15
# | 에폭 2 |  반복 841 / 9295 | 시간 820[s] | 손실 2.16
# | 에폭 2 |  반복 861 / 9295 | 시간 822[s] | 손실 2.19
# | 에폭 2 |  반복 881 / 9295 | 시간 823[s] | 손실 2.13
# | 에폭 2 |  반복 901 / 9295 | 시간 825[s] | 손실 2.18
# | 에폭 2 |  반복 921 / 9295 | 시간 827[s] | 손실 2.16
# | 에폭 2 |  반복 941 / 9295 | 시간 828[s] | 손실 2.11
# | 에폭 2 |  반복 961 / 9295 | 시간 830[s] | 손실 2.15
# | 에폭 2 |  반복 981 / 9295 | 시간 831[s] | 손실 2.13
# | 에폭 2 |  반복 1001 / 9295 | 시간 833[s] | 손실 2.14
# | 에폭 2 |  반복 1021 / 9295 | 시간 835[s] | 손실 2.17
# | 에폭 2 |  반복 1041 / 9295 | 시간 836[s] | 손실 2.14
# | 에폭 2 |  반복 1061 / 9295 | 시간 838[s] | 손실 2.13
# | 에폭 2 |  반복 1081 / 9295 | 시간 839[s] | 손실 2.18
# | 에폭 2 |  반복 1101 / 9295 | 시간 841[s] | 손실 2.19
# | 에폭 2 |  반복 1121 / 9295 | 시간 842[s] | 손실 2.15
# | 에폭 2 |  반복 1141 / 9295 | 시간 844[s] | 손실 2.16
# | 에폭 2 |  반복 1161 / 9295 | 시간 845[s] | 손실 2.18
# | 에폭 2 |  반복 1181 / 9295 | 시간 847[s] | 손실 2.13
# | 에폭 2 |  반복 1201 / 9295 | 시간 849[s] | 손실 2.15
# | 에폭 2 |  반복 1221 / 9295 | 시간 850[s] | 손실 2.19
# | 에폭 2 |  반복 1241 / 9295 | 시간 852[s] | 손실 2.16
# | 에폭 2 |  반복 1261 / 9295 | 시간 853[s] | 손실 2.10
# | 에폭 2 |  반복 1281 / 9295 | 시간 855[s] | 손실 2.15
# | 에폭 2 |  반복 1301 / 9295 | 시간 857[s] | 손실 2.14
# | 에폭 2 |  반복 1321 / 9295 | 시간 858[s] | 손실 2.14
# | 에폭 2 |  반복 1341 / 9295 | 시간 860[s] | 손실 2.13
# | 에폭 2 |  반복 1361 / 9295 | 시간 861[s] | 손실 2.14
# | 에폭 2 |  반복 1381 / 9295 | 시간 863[s] | 손실 2.15
# | 에폭 2 |  반복 1401 / 9295 | 시간 865[s] | 손실 2.16
# | 에폭 2 |  반복 1421 / 9295 | 시간 866[s] | 손실 2.18
# | 에폭 2 |  반복 1441 / 9295 | 시간 868[s] | 손실 2.10
# | 에폭 2 |  반복 1461 / 9295 | 시간 870[s] | 손실 2.15
# | 에폭 2 |  반복 1481 / 9295 | 시간 871[s] | 손실 2.16
# | 에폭 2 |  반복 1501 / 9295 | 시간 872[s] | 손실 2.14
# | 에폭 2 |  반복 1521 / 9295 | 시간 874[s] | 손실 2.12
# | 에폭 2 |  반복 1541 / 9295 | 시간 876[s] | 손실 2.15
# | 에폭 2 |  반복 1561 / 9295 | 시간 877[s] | 손실 2.17
# | 에폭 2 |  반복 1581 / 9295 | 시간 879[s] | 손실 2.13
# | 에폭 2 |  반복 1601 / 9295 | 시간 880[s] | 손실 2.15
# | 에폭 2 |  반복 1621 / 9295 | 시간 882[s] | 손실 2.17
# | 에폭 2 |  반복 1641 / 9295 | 시간 884[s] | 손실 2.19
# | 에폭 2 |  반복 1661 / 9295 | 시간 885[s] | 손실 2.14
# | 에폭 2 |  반복 1681 / 9295 | 시간 887[s] | 손실 2.15
# | 에폭 2 |  반복 1701 / 9295 | 시간 888[s] | 손실 2.16
# | 에폭 2 |  반복 1721 / 9295 | 시간 890[s] | 손실 2.14
# | 에폭 2 |  반복 1741 / 9295 | 시간 891[s] | 손실 2.14
# | 에폭 2 |  반복 1761 / 9295 | 시간 893[s] | 손실 2.10
# | 에폭 2 |  반복 1781 / 9295 | 시간 894[s] | 손실 2.12
# | 에폭 2 |  반복 1801 / 9295 | 시간 896[s] | 손실 2.13
# | 에폭 2 |  반복 1821 / 9295 | 시간 898[s] | 손실 2.15
# | 에폭 2 |  반복 1841 / 9295 | 시간 899[s] | 손실 2.13
# | 에폭 2 |  반복 1861 / 9295 | 시간 901[s] | 손실 2.16
# | 에폭 2 |  반복 1881 / 9295 | 시간 902[s] | 손실 2.12
# | 에폭 2 |  반복 1901 / 9295 | 시간 904[s] | 손실 2.12
# | 에폭 2 |  반복 1921 / 9295 | 시간 905[s] | 손실 2.12
# | 에폭 2 |  반복 1941 / 9295 | 시간 907[s] | 손실 2.13
# | 에폭 2 |  반복 1961 / 9295 | 시간 908[s] | 손실 2.12
# | 에폭 2 |  반복 1981 / 9295 | 시간 910[s] | 손실 2.17
# | 에폭 2 |  반복 2001 / 9295 | 시간 912[s] | 손실 2.15
# | 에폭 2 |  반복 2021 / 9295 | 시간 913[s] | 손실 2.15
# | 에폭 2 |  반복 2041 / 9295 | 시간 915[s] | 손실 2.16
# | 에폭 2 |  반복 2061 / 9295 | 시간 916[s] | 손실 2.18
# | 에폭 2 |  반복 2081 / 9295 | 시간 918[s] | 손실 2.12
# | 에폭 2 |  반복 2101 / 9295 | 시간 919[s] | 손실 2.16
# | 에폭 2 |  반복 2121 / 9295 | 시간 921[s] | 손실 2.15
# | 에폭 2 |  반복 2141 / 9295 | 시간 923[s] | 손실 2.14
# | 에폭 2 |  반복 2161 / 9295 | 시간 924[s] | 손실 2.14
# | 에폭 2 |  반복 2181 / 9295 | 시간 926[s] | 손실 2.16
# | 에폭 2 |  반복 2201 / 9295 | 시간 928[s] | 손실 2.17
# | 에폭 2 |  반복 2221 / 9295 | 시간 930[s] | 손실 2.11
# | 에폭 2 |  반복 2241 / 9295 | 시간 931[s] | 손실 2.15
# | 에폭 2 |  반복 2261 / 9295 | 시간 933[s] | 손실 2.14
# | 에폭 2 |  반복 2281 / 9295 | 시간 934[s] | 손실 2.11
# | 에폭 2 |  반복 2301 / 9295 | 시간 936[s] | 손실 2.14
# | 에폭 2 |  반복 2321 / 9295 | 시간 937[s] | 손실 2.11
# | 에폭 2 |  반복 2341 / 9295 | 시간 939[s] | 손실 2.16
# | 에폭 2 |  반복 2361 / 9295 | 시간 940[s] | 손실 2.15
# | 에폭 2 |  반복 2381 / 9295 | 시간 942[s] | 손실 2.14
# | 에폭 2 |  반복 2401 / 9295 | 시간 943[s] | 손실 2.13
# | 에폭 2 |  반복 2421 / 9295 | 시간 945[s] | 손실 2.13
# | 에폭 2 |  반복 2441 / 9295 | 시간 947[s] | 손실 2.14
# | 에폭 2 |  반복 2461 / 9295 | 시간 948[s] | 손실 2.16
# | 에폭 2 |  반복 2481 / 9295 | 시간 950[s] | 손실 2.11
# | 에폭 2 |  반복 2501 / 9295 | 시간 951[s] | 손실 2.12
# | 에폭 2 |  반복 2521 / 9295 | 시간 953[s] | 손실 2.18
# | 에폭 2 |  반복 2541 / 9295 | 시간 955[s] | 손실 2.10
# | 에폭 2 |  반복 2561 / 9295 | 시간 956[s] | 손실 2.12
# | 에폭 2 |  반복 2581 / 9295 | 시간 958[s] | 손실 2.11
# | 에폭 2 |  반복 2601 / 9295 | 시간 959[s] | 손실 2.17
# | 에폭 2 |  반복 2621 / 9295 | 시간 961[s] | 손실 2.16
# | 에폭 2 |  반복 2641 / 9295 | 시간 963[s] | 손실 2.13
# | 에폭 2 |  반복 2661 / 9295 | 시간 965[s] | 손실 2.12
# | 에폭 2 |  반복 2681 / 9295 | 시간 966[s] | 손실 2.14
# | 에폭 2 |  반복 2701 / 9295 | 시간 968[s] | 손실 2.12
# | 에폭 2 |  반복 2721 / 9295 | 시간 969[s] | 손실 2.09
# | 에폭 2 |  반복 2741 / 9295 | 시간 971[s] | 손실 2.13
# | 에폭 2 |  반복 2761 / 9295 | 시간 972[s] | 손실 2.14
# | 에폭 2 |  반복 2781 / 9295 | 시간 974[s] | 손실 2.15
# | 에폭 2 |  반복 2801 / 9295 | 시간 976[s] | 손실 2.13
# | 에폭 2 |  반복 2821 / 9295 | 시간 977[s] | 손실 2.09
# | 에폭 2 |  반복 2841 / 9295 | 시간 979[s] | 손실 2.09
# | 에폭 2 |  반복 2861 / 9295 | 시간 980[s] | 손실 2.09
# | 에폭 2 |  반복 2881 / 9295 | 시간 982[s] | 손실 2.15
# | 에폭 2 |  반복 2901 / 9295 | 시간 984[s] | 손실 2.14
# | 에폭 2 |  반복 2921 / 9295 | 시간 985[s] | 손실 2.16
# | 에폭 2 |  반복 2941 / 9295 | 시간 987[s] | 손실 2.10
# | 에폭 2 |  반복 2961 / 9295 | 시간 988[s] | 손실 2.13
# | 에폭 2 |  반복 2981 / 9295 | 시간 990[s] | 손실 2.12
# | 에폭 2 |  반복 3001 / 9295 | 시간 991[s] | 손실 2.13
# | 에폭 2 |  반복 3021 / 9295 | 시간 993[s] | 손실 2.10
# | 에폭 2 |  반복 3041 / 9295 | 시간 995[s] | 손실 2.13
# | 에폭 2 |  반복 3061 / 9295 | 시간 996[s] | 손실 2.11
# | 에폭 2 |  반복 3081 / 9295 | 시간 998[s] | 손실 2.13
# | 에폭 2 |  반복 3101 / 9295 | 시간 1000[s] | 손실 2.13
# | 에폭 2 |  반복 3121 / 9295 | 시간 1001[s] | 손실 2.13
# | 에폭 2 |  반복 3141 / 9295 | 시간 1003[s] | 손실 2.13
# | 에폭 2 |  반복 3161 / 9295 | 시간 1004[s] | 손실 2.09
# | 에폭 2 |  반복 3181 / 9295 | 시간 1006[s] | 손실 2.13
# | 에폭 2 |  반복 3201 / 9295 | 시간 1008[s] | 손실 2.12
# | 에폭 2 |  반복 3221 / 9295 | 시간 1009[s] | 손실 2.10
# | 에폭 2 |  반복 3241 / 9295 | 시간 1011[s] | 손실 2.10
# | 에폭 2 |  반복 3261 / 9295 | 시간 1012[s] | 손실 2.13
# | 에폭 2 |  반복 3281 / 9295 | 시간 1014[s] | 손실 2.12
# | 에폭 2 |  반복 3301 / 9295 | 시간 1015[s] | 손실 2.11
# | 에폭 2 |  반복 3321 / 9295 | 시간 1017[s] | 손실 2.09
# | 에폭 2 |  반복 3341 / 9295 | 시간 1019[s] | 손실 2.13
# | 에폭 2 |  반복 3361 / 9295 | 시간 1020[s] | 손실 2.18
# | 에폭 2 |  반복 3381 / 9295 | 시간 1022[s] | 손실 2.12
# | 에폭 2 |  반복 3401 / 9295 | 시간 1023[s] | 손실 2.09
# | 에폭 2 |  반복 3421 / 9295 | 시간 1025[s] | 손실 2.08
# | 에폭 2 |  반복 3441 / 9295 | 시간 1027[s] | 손실 2.11
# | 에폭 2 |  반복 3461 / 9295 | 시간 1028[s] | 손실 2.11
# | 에폭 2 |  반복 3481 / 9295 | 시간 1030[s] | 손실 2.13
# | 에폭 2 |  반복 3501 / 9295 | 시간 1031[s] | 손실 2.05
# | 에폭 2 |  반복 3521 / 9295 | 시간 1033[s] | 손실 2.10
# | 에폭 2 |  반복 3541 / 9295 | 시간 1034[s] | 손실 2.06
# | 에폭 2 |  반복 3561 / 9295 | 시간 1036[s] | 손실 2.12
# | 에폭 2 |  반복 3581 / 9295 | 시간 1037[s] | 손실 2.07
# | 에폭 2 |  반복 3601 / 9295 | 시간 1039[s] | 손실 2.09
# | 에폭 2 |  반복 3621 / 9295 | 시간 1041[s] | 손실 2.11
# | 에폭 2 |  반복 3641 / 9295 | 시간 1043[s] | 손실 2.11
# | 에폭 2 |  반복 3661 / 9295 | 시간 1044[s] | 손실 2.13
# | 에폭 2 |  반복 3681 / 9295 | 시간 1046[s] | 손실 2.12
# | 에폭 2 |  반복 3701 / 9295 | 시간 1047[s] | 손실 2.07
# | 에폭 2 |  반복 3721 / 9295 | 시간 1049[s] | 손실 2.10
# | 에폭 2 |  반복 3741 / 9295 | 시간 1051[s] | 손실 2.13
# | 에폭 2 |  반복 3761 / 9295 | 시간 1052[s] | 손실 2.12
# | 에폭 2 |  반복 3781 / 9295 | 시간 1054[s] | 손실 2.12
# | 에폭 2 |  반복 3801 / 9295 | 시간 1055[s] | 손실 2.08
# | 에폭 2 |  반복 3821 / 9295 | 시간 1057[s] | 손실 2.10
# | 에폭 2 |  반복 3841 / 9295 | 시간 1059[s] | 손실 2.13
# | 에폭 2 |  반복 3861 / 9295 | 시간 1060[s] | 손실 2.10
# | 에폭 2 |  반복 3881 / 9295 | 시간 1062[s] | 손실 2.13
# | 에폭 2 |  반복 3901 / 9295 | 시간 1063[s] | 손실 2.08
# | 에폭 2 |  반복 3921 / 9295 | 시간 1065[s] | 손실 2.10
# | 에폭 2 |  반복 3941 / 9295 | 시간 1067[s] | 손실 2.09
# | 에폭 2 |  반복 3961 / 9295 | 시간 1068[s] | 손실 2.12
# | 에폭 2 |  반복 3981 / 9295 | 시간 1070[s] | 손실 2.11
# | 에폭 2 |  반복 4001 / 9295 | 시간 1071[s] | 손실 2.13
# | 에폭 2 |  반복 4021 / 9295 | 시간 1073[s] | 손실 2.09
# | 에폭 2 |  반복 4041 / 9295 | 시간 1074[s] | 손실 2.09
# | 에폭 2 |  반복 4061 / 9295 | 시간 1076[s] | 손실 2.09
# | 에폭 2 |  반복 4081 / 9295 | 시간 1078[s] | 손실 2.09
# | 에폭 2 |  반복 4101 / 9295 | 시간 1079[s] | 손실 2.08
# | 에폭 2 |  반복 4121 / 9295 | 시간 1081[s] | 손실 2.09
# | 에폭 2 |  반복 4141 / 9295 | 시간 1082[s] | 손실 2.11
# | 에폭 2 |  반복 4161 / 9295 | 시간 1084[s] | 손실 2.11
# | 에폭 2 |  반복 4181 / 9295 | 시간 1085[s] | 손실 2.11
# | 에폭 2 |  반복 4201 / 9295 | 시간 1087[s] | 손실 2.06
# | 에폭 2 |  반복 4221 / 9295 | 시간 1088[s] | 손실 2.08
# | 에폭 2 |  반복 4241 / 9295 | 시간 1090[s] | 손실 2.11
# | 에폭 2 |  반복 4261 / 9295 | 시간 1092[s] | 손실 2.10
# | 에폭 2 |  반복 4281 / 9295 | 시간 1093[s] | 손실 2.10
# | 에폭 2 |  반복 4301 / 9295 | 시간 1095[s] | 손실 2.10
# | 에폭 2 |  반복 4321 / 9295 | 시간 1096[s] | 손실 2.08
# | 에폭 2 |  반복 4341 / 9295 | 시간 1098[s] | 손실 2.08
# | 에폭 2 |  반복 4361 / 9295 | 시간 1100[s] | 손실 2.09
# | 에폭 2 |  반복 4381 / 9295 | 시간 1101[s] | 손실 2.06
# | 에폭 2 |  반복 4401 / 9295 | 시간 1103[s] | 손실 2.13
# | 에폭 2 |  반복 4421 / 9295 | 시간 1104[s] | 손실 2.07
# | 에폭 2 |  반복 4441 / 9295 | 시간 1106[s] | 손실 2.08
# | 에폭 2 |  반복 4461 / 9295 | 시간 1108[s] | 손실 2.10
# | 에폭 2 |  반복 4481 / 9295 | 시간 1109[s] | 손실 2.13
# | 에폭 2 |  반복 4501 / 9295 | 시간 1111[s] | 손실 2.10
# | 에폭 2 |  반복 4521 / 9295 | 시간 1112[s] | 손실 2.07
# | 에폭 2 |  반복 4541 / 9295 | 시간 1114[s] | 손실 2.08
# | 에폭 2 |  반복 4561 / 9295 | 시간 1116[s] | 손실 2.07
# | 에폭 2 |  반복 4581 / 9295 | 시간 1117[s] | 손실 2.09
# | 에폭 2 |  반복 4601 / 9295 | 시간 1119[s] | 손실 2.07
# | 에폭 2 |  반복 4621 / 9295 | 시간 1121[s] | 손실 2.08
# | 에폭 2 |  반복 4641 / 9295 | 시간 1122[s] | 손실 2.09
# | 에폭 2 |  반복 4661 / 9295 | 시간 1124[s] | 손실 2.07
# | 에폭 2 |  반복 4681 / 9295 | 시간 1125[s] | 손실 2.11
# | 에폭 2 |  반복 4701 / 9295 | 시간 1127[s] | 손실 2.07
# | 에폭 2 |  반복 4721 / 9295 | 시간 1129[s] | 손실 2.07
# | 에폭 2 |  반복 4741 / 9295 | 시간 1130[s] | 손실 2.09
# | 에폭 2 |  반복 4761 / 9295 | 시간 1132[s] | 손실 2.05
# | 에폭 2 |  반복 4781 / 9295 | 시간 1134[s] | 손실 2.09
# | 에폭 2 |  반복 4801 / 9295 | 시간 1135[s] | 손실 2.08
# | 에폭 2 |  반복 4821 / 9295 | 시간 1137[s] | 손실 2.07
# | 에폭 2 |  반복 4841 / 9295 | 시간 1139[s] | 손실 2.09
# | 에폭 2 |  반복 4861 / 9295 | 시간 1140[s] | 손실 2.06
# | 에폭 2 |  반복 4881 / 9295 | 시간 1142[s] | 손실 2.08
# | 에폭 2 |  반복 4901 / 9295 | 시간 1143[s] | 손실 2.11
# | 에폭 2 |  반복 4921 / 9295 | 시간 1145[s] | 손실 2.12
# | 에폭 2 |  반복 4941 / 9295 | 시간 1147[s] | 손실 2.09
# | 에폭 2 |  반복 4961 / 9295 | 시간 1148[s] | 손실 2.09
# | 에폭 2 |  반복 4981 / 9295 | 시간 1150[s] | 손실 2.09
# | 에폭 2 |  반복 5001 / 9295 | 시간 1152[s] | 손실 2.08
# | 에폭 2 |  반복 5021 / 9295 | 시간 1153[s] | 손실 2.08
# | 에폭 2 |  반복 5041 / 9295 | 시간 1155[s] | 손실 2.10
# | 에폭 2 |  반복 5061 / 9295 | 시간 1156[s] | 손실 2.08
# | 에폭 2 |  반복 5081 / 9295 | 시간 1158[s] | 손실 2.08
# | 에폭 2 |  반복 5101 / 9295 | 시간 1160[s] | 손실 2.06
# | 에폭 2 |  반복 5121 / 9295 | 시간 1162[s] | 손실 2.08
# | 에폭 2 |  반복 5141 / 9295 | 시간 1163[s] | 손실 2.11
# | 에폭 2 |  반복 5161 / 9295 | 시간 1165[s] | 손실 2.09
# | 에폭 2 |  반복 5181 / 9295 | 시간 1167[s] | 손실 2.12
# | 에폭 2 |  반복 5201 / 9295 | 시간 1168[s] | 손실 2.09
# | 에폭 2 |  반복 5221 / 9295 | 시간 1170[s] | 손실 2.09
# | 에폭 2 |  반복 5241 / 9295 | 시간 1171[s] | 손실 2.06
# | 에폭 2 |  반복 5261 / 9295 | 시간 1173[s] | 손실 2.06
# | 에폭 2 |  반복 5281 / 9295 | 시간 1175[s] | 손실 2.08
# | 에폭 2 |  반복 5301 / 9295 | 시간 1177[s] | 손실 2.08
# | 에폭 2 |  반복 5321 / 9295 | 시간 1178[s] | 손실 2.10
# | 에폭 2 |  반복 5341 / 9295 | 시간 1180[s] | 손실 2.09
# | 에폭 2 |  반복 5361 / 9295 | 시간 1181[s] | 손실 2.07
# | 에폭 2 |  반복 5381 / 9295 | 시간 1183[s] | 손실 2.08
# | 에폭 2 |  반복 5401 / 9295 | 시간 1185[s] | 손실 2.07
# | 에폭 2 |  반복 5421 / 9295 | 시간 1186[s] | 손실 2.06
# | 에폭 2 |  반복 5441 / 9295 | 시간 1188[s] | 손실 2.06
# | 에폭 2 |  반복 5461 / 9295 | 시간 1190[s] | 손실 2.07
# | 에폭 2 |  반복 5481 / 9295 | 시간 1191[s] | 손실 2.08
# | 에폭 2 |  반복 5501 / 9295 | 시간 1193[s] | 손실 2.09
# | 에폭 2 |  반복 5521 / 9295 | 시간 1194[s] | 손실 2.06
# | 에폭 2 |  반복 5541 / 9295 | 시간 1196[s] | 손실 2.01
# | 에폭 2 |  반복 5561 / 9295 | 시간 1198[s] | 손실 2.05
# | 에폭 2 |  반복 5581 / 9295 | 시간 1199[s] | 손실 2.07
# | 에폭 2 |  반복 5601 / 9295 | 시간 1201[s] | 손실 2.03
# | 에폭 2 |  반복 5621 / 9295 | 시간 1202[s] | 손실 2.06
# | 에폭 2 |  반복 5641 / 9295 | 시간 1204[s] | 손실 2.07
# | 에폭 2 |  반복 5661 / 9295 | 시간 1205[s] | 손실 2.05
# | 에폭 2 |  반복 5681 / 9295 | 시간 1207[s] | 손실 2.06
# | 에폭 2 |  반복 5701 / 9295 | 시간 1209[s] | 손실 2.08
# | 에폭 2 |  반복 5721 / 9295 | 시간 1210[s] | 손실 2.10
# | 에폭 2 |  반복 5741 / 9295 | 시간 1212[s] | 손실 2.09
# | 에폭 2 |  반복 5761 / 9295 | 시간 1213[s] | 손실 2.09
# | 에폭 2 |  반복 5781 / 9295 | 시간 1215[s] | 손실 2.07
# | 에폭 2 |  반복 5801 / 9295 | 시간 1217[s] | 손실 2.09
# | 에폭 2 |  반복 5821 / 9295 | 시간 1219[s] | 손실 2.07
# | 에폭 2 |  반복 5841 / 9295 | 시간 1220[s] | 손실 2.09
# | 에폭 2 |  반복 5861 / 9295 | 시간 1222[s] | 손실 2.06
# | 에폭 2 |  반복 5881 / 9295 | 시간 1223[s] | 손실 2.09
# | 에폭 2 |  반복 5901 / 9295 | 시간 1225[s] | 손실 2.07
# | 에폭 2 |  반복 5921 / 9295 | 시간 1227[s] | 손실 2.06
# | 에폭 2 |  반복 5941 / 9295 | 시간 1228[s] | 손실 2.06
# | 에폭 2 |  반복 5961 / 9295 | 시간 1230[s] | 손실 2.03
# | 에폭 2 |  반복 5981 / 9295 | 시간 1231[s] | 손실 2.08
# | 에폭 2 |  반복 6001 / 9295 | 시간 1233[s] | 손실 2.08
# | 에폭 2 |  반복 6021 / 9295 | 시간 1235[s] | 손실 2.05
# | 에폭 2 |  반복 6041 / 9295 | 시간 1236[s] | 손실 2.06
# | 에폭 2 |  반복 6061 / 9295 | 시간 1238[s] | 손실 2.08
# | 에폭 2 |  반복 6081 / 9295 | 시간 1240[s] | 손실 2.08
# | 에폭 2 |  반복 6101 / 9295 | 시간 1241[s] | 손실 2.09
# | 에폭 2 |  반복 6121 / 9295 | 시간 1243[s] | 손실 2.09
# | 에폭 2 |  반복 6141 / 9295 | 시간 1244[s] | 손실 2.07
# | 에폭 2 |  반복 6161 / 9295 | 시간 1246[s] | 손실 2.06
# | 에폭 2 |  반복 6181 / 9295 | 시간 1247[s] | 손실 2.04
# | 에폭 2 |  반복 6201 / 9295 | 시간 1249[s] | 손실 2.07
# | 에폭 2 |  반복 6221 / 9295 | 시간 1251[s] | 손실 2.07
# | 에폭 2 |  반복 6241 / 9295 | 시간 1252[s] | 손실 2.03
# | 에폭 2 |  반복 6261 / 9295 | 시간 1254[s] | 손실 2.04
# | 에폭 2 |  반복 6281 / 9295 | 시간 1256[s] | 손실 2.03
# | 에폭 2 |  반복 6301 / 9295 | 시간 1257[s] | 손실 2.07
# | 에폭 2 |  반복 6321 / 9295 | 시간 1259[s] | 손실 2.06
# | 에폭 2 |  반복 6341 / 9295 | 시간 1260[s] | 손실 2.08
# | 에폭 2 |  반복 6361 / 9295 | 시간 1262[s] | 손실 2.07
# | 에폭 2 |  반복 6381 / 9295 | 시간 1264[s] | 손실 2.03
# | 에폭 2 |  반복 6401 / 9295 | 시간 1265[s] | 손실 2.08
# | 에폭 2 |  반복 6421 / 9295 | 시간 1267[s] | 손실 2.07
# | 에폭 2 |  반복 6441 / 9295 | 시간 1268[s] | 손실 2.05
# | 에폭 2 |  반복 6461 / 9295 | 시간 1270[s] | 손실 2.02
# | 에폭 2 |  반복 6481 / 9295 | 시간 1272[s] | 손실 2.08
# | 에폭 2 |  반복 6501 / 9295 | 시간 1273[s] | 손실 2.04
# | 에폭 2 |  반복 6521 / 9295 | 시간 1275[s] | 손실 2.07
# | 에폭 2 |  반복 6541 / 9295 | 시간 1276[s] | 손실 2.08
# | 에폭 2 |  반복 6561 / 9295 | 시간 1278[s] | 손실 2.07
# | 에폭 2 |  반복 6581 / 9295 | 시간 1280[s] | 손실 2.05
# | 에폭 2 |  반복 6601 / 9295 | 시간 1281[s] | 손실 2.06
# | 에폭 2 |  반복 6621 / 9295 | 시간 1283[s] | 손실 2.10
# | 에폭 2 |  반복 6641 / 9295 | 시간 1284[s] | 손실 2.04
# | 에폭 2 |  반복 6661 / 9295 | 시간 1286[s] | 손실 2.04
# | 에폭 2 |  반복 6681 / 9295 | 시간 1287[s] | 손실 2.04
# | 에폭 2 |  반복 6701 / 9295 | 시간 1289[s] | 손실 2.05
# | 에폭 2 |  반복 6721 / 9295 | 시간 1291[s] | 손실 2.03
# | 에폭 2 |  반복 6741 / 9295 | 시간 1292[s] | 손실 2.04
# | 에폭 2 |  반복 6761 / 9295 | 시간 1294[s] | 손실 2.08
# | 에폭 2 |  반복 6781 / 9295 | 시간 1296[s] | 손실 2.03
# | 에폭 2 |  반복 6801 / 9295 | 시간 1297[s] | 손실 2.07
# | 에폭 2 |  반복 6821 / 9295 | 시간 1299[s] | 손실 2.06
# | 에폭 2 |  반복 6841 / 9295 | 시간 1300[s] | 손실 2.04
# | 에폭 2 |  반복 6861 / 9295 | 시간 1302[s] | 손실 2.04
# | 에폭 2 |  반복 6881 / 9295 | 시간 1304[s] | 손실 2.07
# | 에폭 2 |  반복 6901 / 9295 | 시간 1305[s] | 손실 2.03
# | 에폭 2 |  반복 6921 / 9295 | 시간 1307[s] | 손실 2.05
# | 에폭 2 |  반복 6941 / 9295 | 시간 1308[s] | 손실 2.04
# | 에폭 2 |  반복 6961 / 9295 | 시간 1310[s] | 손실 2.01
# | 에폭 2 |  반복 6981 / 9295 | 시간 1312[s] | 손실 2.08
# | 에폭 2 |  반복 7001 / 9295 | 시간 1313[s] | 손실 2.02
# | 에폭 2 |  반복 7021 / 9295 | 시간 1315[s] | 손실 2.07
# | 에폭 2 |  반복 7041 / 9295 | 시간 1317[s] | 손실 2.04
# | 에폭 2 |  반복 7061 / 9295 | 시간 1318[s] | 손실 2.06
# | 에폭 2 |  반복 7081 / 9295 | 시간 1320[s] | 손실 2.04
# | 에폭 2 |  반복 7101 / 9295 | 시간 1322[s] | 손실 2.03
# | 에폭 2 |  반복 7121 / 9295 | 시간 1323[s] | 손실 2.04
# | 에폭 2 |  반복 7141 / 9295 | 시간 1325[s] | 손실 2.05
# | 에폭 2 |  반복 7161 / 9295 | 시간 1326[s] | 손실 2.05
# | 에폭 2 |  반복 7181 / 9295 | 시간 1328[s] | 손실 2.08
# | 에폭 2 |  반복 7201 / 9295 | 시간 1330[s] | 손실 2.06
# | 에폭 2 |  반복 7221 / 9295 | 시간 1331[s] | 손실 2.06
# | 에폭 2 |  반복 7241 / 9295 | 시간 1333[s] | 손실 2.02
# | 에폭 2 |  반복 7261 / 9295 | 시간 1334[s] | 손실 2.03
# | 에폭 2 |  반복 7281 / 9295 | 시간 1336[s] | 손실 2.03
# | 에폭 2 |  반복 7301 / 9295 | 시간 1337[s] | 손실 2.03
# | 에폭 2 |  반복 7321 / 9295 | 시간 1339[s] | 손실 2.01
# | 에폭 2 |  반복 7341 / 9295 | 시간 1341[s] | 손실 2.07
# | 에폭 2 |  반복 7361 / 9295 | 시간 1342[s] | 손실 2.06
# | 에폭 2 |  반복 7381 / 9295 | 시간 1344[s] | 손실 2.06
# | 에폭 2 |  반복 7401 / 9295 | 시간 1345[s] | 손실 2.03
# | 에폭 2 |  반복 7421 / 9295 | 시간 1347[s] | 손실 2.08
# | 에폭 2 |  반복 7441 / 9295 | 시간 1348[s] | 손실 2.03
# | 에폭 2 |  반복 7461 / 9295 | 시간 1350[s] | 손실 2.06
# | 에폭 2 |  반복 7481 / 9295 | 시간 1351[s] | 손실 2.06
# | 에폭 2 |  반복 7501 / 9295 | 시간 1353[s] | 손실 2.03
# | 에폭 2 |  반복 7521 / 9295 | 시간 1355[s] | 손실 2.10
# | 에폭 2 |  반복 7541 / 9295 | 시간 1356[s] | 손실 2.06
# | 에폭 2 |  반복 7561 / 9295 | 시간 1358[s] | 손실 2.06
# | 에폭 2 |  반복 7581 / 9295 | 시간 1359[s] | 손실 2.00
# | 에폭 2 |  반복 7601 / 9295 | 시간 1361[s] | 손실 2.06
# | 에폭 2 |  반복 7621 / 9295 | 시간 1363[s] | 손실 2.01
# | 에폭 2 |  반복 7641 / 9295 | 시간 1364[s] | 손실 2.02
# | 에폭 2 |  반복 7661 / 9295 | 시간 1366[s] | 손실 2.05
# | 에폭 2 |  반복 7681 / 9295 | 시간 1367[s] | 손실 2.05
# | 에폭 2 |  반복 7701 / 9295 | 시간 1369[s] | 손실 2.03
# | 에폭 2 |  반복 7721 / 9295 | 시간 1371[s] | 손실 2.02
# | 에폭 2 |  반복 7741 / 9295 | 시간 1372[s] | 손실 2.06
# | 에폭 2 |  반복 7761 / 9295 | 시간 1374[s] | 손실 2.02
# | 에폭 2 |  반복 7781 / 9295 | 시간 1376[s] | 손실 2.03
# | 에폭 2 |  반복 7801 / 9295 | 시간 1377[s] | 손실 2.02
# | 에폭 2 |  반복 7821 / 9295 | 시간 1379[s] | 손실 2.04
# | 에폭 2 |  반복 7841 / 9295 | 시간 1380[s] | 손실 2.05
# | 에폭 2 |  반복 7861 / 9295 | 시간 1382[s] | 손실 2.05
# | 에폭 2 |  반복 7881 / 9295 | 시간 1384[s] | 손실 2.04
# | 에폭 2 |  반복 7901 / 9295 | 시간 1385[s] | 손실 2.06
# | 에폭 2 |  반복 7921 / 9295 | 시간 1387[s] | 손실 2.05
# | 에폭 2 |  반복 7941 / 9295 | 시간 1388[s] | 손실 2.03
# | 에폭 2 |  반복 7961 / 9295 | 시간 1390[s] | 손실 2.05
# | 에폭 2 |  반복 7981 / 9295 | 시간 1391[s] | 손실 1.99
# | 에폭 2 |  반복 8001 / 9295 | 시간 1393[s] | 손실 2.01
# | 에폭 2 |  반복 8021 / 9295 | 시간 1394[s] | 손실 2.06
# | 에폭 2 |  반복 8041 / 9295 | 시간 1396[s] | 손실 2.00
# | 에폭 2 |  반복 8061 / 9295 | 시간 1397[s] | 손실 2.04
# | 에폭 2 |  반복 8081 / 9295 | 시간 1399[s] | 손실 2.01
# | 에폭 2 |  반복 8101 / 9295 | 시간 1401[s] | 손실 2.04
# | 에폭 2 |  반복 8121 / 9295 | 시간 1402[s] | 손실 2.01
# | 에폭 2 |  반복 8141 / 9295 | 시간 1404[s] | 손실 2.06
# | 에폭 2 |  반복 8161 / 9295 | 시간 1405[s] | 손실 2.04
# | 에폭 2 |  반복 8181 / 9295 | 시간 1407[s] | 손실 2.04
# | 에폭 2 |  반복 8201 / 9295 | 시간 1409[s] | 손실 2.03
# | 에폭 2 |  반복 8221 / 9295 | 시간 1410[s] | 손실 1.99
# | 에폭 2 |  반복 8241 / 9295 | 시간 1412[s] | 손실 2.05
# | 에폭 2 |  반복 8261 / 9295 | 시간 1413[s] | 손실 2.04
# | 에폭 2 |  반복 8281 / 9295 | 시간 1415[s] | 손실 2.06
# | 에폭 2 |  반복 8301 / 9295 | 시간 1417[s] | 손실 2.00
# | 에폭 2 |  반복 8321 / 9295 | 시간 1418[s] | 손실 2.05
# | 에폭 2 |  반복 8341 / 9295 | 시간 1420[s] | 손실 2.02
# | 에폭 2 |  반복 8361 / 9295 | 시간 1422[s] | 손실 2.01
# | 에폭 2 |  반복 8381 / 9295 | 시간 1423[s] | 손실 2.04
# | 에폭 2 |  반복 8401 / 9295 | 시간 1425[s] | 손실 2.00
# | 에폭 2 |  반복 8421 / 9295 | 시간 1426[s] | 손실 2.02
# | 에폭 2 |  반복 8441 / 9295 | 시간 1428[s] | 손실 2.00
# | 에폭 2 |  반복 8461 / 9295 | 시간 1430[s] | 손실 2.02
# | 에폭 2 |  반복 8481 / 9295 | 시간 1431[s] | 손실 1.99
# | 에폭 2 |  반복 8501 / 9295 | 시간 1433[s] | 손실 2.01
# | 에폭 2 |  반복 8521 / 9295 | 시간 1434[s] | 손실 2.04
# | 에폭 2 |  반복 8541 / 9295 | 시간 1436[s] | 손실 2.01
# | 에폭 2 |  반복 8561 / 9295 | 시간 1437[s] | 손실 2.01
# | 에폭 2 |  반복 8581 / 9295 | 시간 1439[s] | 손실 2.04
# | 에폭 2 |  반복 8601 / 9295 | 시간 1441[s] | 손실 2.03
# | 에폭 2 |  반복 8621 / 9295 | 시간 1442[s] | 손실 1.99
# | 에폭 2 |  반복 8641 / 9295 | 시간 1444[s] | 손실 2.04
# | 에폭 2 |  반복 8661 / 9295 | 시간 1445[s] | 손실 2.02
# | 에폭 2 |  반복 8681 / 9295 | 시간 1447[s] | 손실 2.00
# | 에폭 2 |  반복 8701 / 9295 | 시간 1449[s] | 손실 2.02
# | 에폭 2 |  반복 8721 / 9295 | 시간 1450[s] | 손실 2.06
# | 에폭 2 |  반복 8741 / 9295 | 시간 1452[s] | 손실 2.01
# | 에폭 2 |  반복 8761 / 9295 | 시간 1454[s] | 손실 2.03
# | 에폭 2 |  반복 8781 / 9295 | 시간 1455[s] | 손실 2.02
# | 에폭 2 |  반복 8801 / 9295 | 시간 1457[s] | 손실 2.04
# | 에폭 2 |  반복 8821 / 9295 | 시간 1458[s] | 손실 2.01
# | 에폭 2 |  반복 8841 / 9295 | 시간 1460[s] | 손실 1.98
# | 에폭 2 |  반복 8861 / 9295 | 시간 1461[s] | 손실 2.04
# | 에폭 2 |  반복 8881 / 9295 | 시간 1463[s] | 손실 2.00
# | 에폭 2 |  반복 8901 / 9295 | 시간 1465[s] | 손실 2.03
# | 에폭 2 |  반복 8921 / 9295 | 시간 1466[s] | 손실 2.03
# | 에폭 2 |  반복 8941 / 9295 | 시간 1468[s] | 손실 2.00
# | 에폭 2 |  반복 8961 / 9295 | 시간 1469[s] | 손실 2.02
# | 에폭 2 |  반복 8981 / 9295 | 시간 1471[s] | 손실 2.01
# | 에폭 2 |  반복 9001 / 9295 | 시간 1473[s] | 손실 1.99
# | 에폭 2 |  반복 9021 / 9295 | 시간 1474[s] | 손실 2.04
# | 에폭 2 |  반복 9041 / 9295 | 시간 1476[s] | 손실 2.01
# | 에폭 2 |  반복 9061 / 9295 | 시간 1477[s] | 손실 2.02
# | 에폭 2 |  반복 9081 / 9295 | 시간 1479[s] | 손실 2.00
# | 에폭 2 |  반복 9101 / 9295 | 시간 1480[s] | 손실 2.01
# | 에폭 2 |  반복 9121 / 9295 | 시간 1482[s] | 손실 2.05
# | 에폭 2 |  반복 9141 / 9295 | 시간 1484[s] | 손실 2.03
# | 에폭 2 |  반복 9161 / 9295 | 시간 1485[s] | 손실 2.02
# | 에폭 2 |  반복 9181 / 9295 | 시간 1487[s] | 손실 2.00
# | 에폭 2 |  반복 9201 / 9295 | 시간 1488[s] | 손실 2.05
# | 에폭 2 |  반복 9221 / 9295 | 시간 1490[s] | 손실 2.01
# | 에폭 2 |  반복 9241 / 9295 | 시간 1492[s] | 손실 2.03
# | 에폭 2 |  반복 9261 / 9295 | 시간 1493[s] | 손실 2.00
# | 에폭 2 |  반복 9281 / 9295 | 시간 1495[s] | 손실 2.04
# | 에폭 3 |  반복 1 / 9295 | 시간 1496[s] | 손실 2.01
# | 에폭 3 |  반복 21 / 9295 | 시간 1497[s] | 손실 1.94
# | 에폭 3 |  반복 41 / 9295 | 시간 1499[s] | 손실 1.95
# | 에폭 3 |  반복 61 / 9295 | 시간 1500[s] | 손실 1.93
# | 에폭 3 |  반복 81 / 9295 | 시간 1502[s] | 손실 1.95
# | 에폭 3 |  반복 101 / 9295 | 시간 1504[s] | 손실 1.98
# | 에폭 3 |  반복 121 / 9295 | 시간 1505[s] | 손실 1.93
# | 에폭 3 |  반복 141 / 9295 | 시간 1507[s] | 손실 1.96
# | 에폭 3 |  반복 161 / 9295 | 시간 1508[s] | 손실 1.95
# | 에폭 3 |  반복 181 / 9295 | 시간 1510[s] | 손실 1.94
# | 에폭 3 |  반복 201 / 9295 | 시간 1511[s] | 손실 1.93
# | 에폭 3 |  반복 221 / 9295 | 시간 1513[s] | 손실 1.96
# | 에폭 3 |  반복 241 / 9295 | 시간 1514[s] | 손실 1.91
# | 에폭 3 |  반복 261 / 9295 | 시간 1516[s] | 손실 1.96
# | 에폭 3 |  반복 281 / 9295 | 시간 1518[s] | 손실 1.95
# | 에폭 3 |  반복 301 / 9295 | 시간 1519[s] | 손실 1.99
# | 에폭 3 |  반복 321 / 9295 | 시간 1521[s] | 손실 1.91
# | 에폭 3 |  반복 341 / 9295 | 시간 1523[s] | 손실 1.96
# | 에폭 3 |  반복 361 / 9295 | 시간 1524[s] | 손실 1.96
# | 에폭 3 |  반복 381 / 9295 | 시간 1526[s] | 손실 1.95
# | 에폭 3 |  반복 401 / 9295 | 시간 1527[s] | 손실 1.92
# | 에폭 3 |  반복 421 / 9295 | 시간 1529[s] | 손실 1.96
# | 에폭 3 |  반복 441 / 9295 | 시간 1530[s] | 손실 1.93
# | 에폭 3 |  반복 461 / 9295 | 시간 1532[s] | 손실 1.98
# | 에폭 3 |  반복 481 / 9295 | 시간 1533[s] | 손실 1.95
# | 에폭 3 |  반복 501 / 9295 | 시간 1535[s] | 손실 1.92
# | 에폭 3 |  반복 521 / 9295 | 시간 1537[s] | 손실 1.92
# | 에폭 3 |  반복 541 / 9295 | 시간 1538[s] | 손실 1.94
# | 에폭 3 |  반복 561 / 9295 | 시간 1540[s] | 손실 1.95
# | 에폭 3 |  반복 581 / 9295 | 시간 1541[s] | 손실 1.95
# | 에폭 3 |  반복 601 / 9295 | 시간 1543[s] | 손실 1.96
# | 에폭 3 |  반복 621 / 9295 | 시간 1544[s] | 손실 1.97
# | 에폭 3 |  반복 641 / 9295 | 시간 1546[s] | 손실 1.96
# | 에폭 3 |  반복 661 / 9295 | 시간 1548[s] | 손실 1.94
# | 에폭 3 |  반복 681 / 9295 | 시간 1549[s] | 손실 1.97
# | 에폭 3 |  반복 701 / 9295 | 시간 1551[s] | 손실 1.93
# | 에폭 3 |  반복 721 / 9295 | 시간 1552[s] | 손실 1.96
# | 에폭 3 |  반복 741 / 9295 | 시간 1554[s] | 손실 1.93
# | 에폭 3 |  반복 761 / 9295 | 시간 1555[s] | 손실 1.96
# | 에폭 3 |  반복 781 / 9295 | 시간 1557[s] | 손실 1.95
# | 에폭 3 |  반복 801 / 9295 | 시간 1559[s] | 손실 2.00
# | 에폭 3 |  반복 821 / 9295 | 시간 1560[s] | 손실 1.96
# | 에폭 3 |  반복 841 / 9295 | 시간 1562[s] | 손실 1.95
# | 에폭 3 |  반복 861 / 9295 | 시간 1563[s] | 손실 1.95
# | 에폭 3 |  반복 881 / 9295 | 시간 1565[s] | 손실 1.94
# | 에폭 3 |  반복 901 / 9295 | 시간 1567[s] | 손실 1.94
# | 에폭 3 |  반복 921 / 9295 | 시간 1568[s] | 손실 1.96
# | 에폭 3 |  반복 941 / 9295 | 시간 1569[s] | 손실 1.92
# | 에폭 3 |  반복 961 / 9295 | 시간 1571[s] | 손실 1.97
# | 에폭 3 |  반복 981 / 9295 | 시간 1573[s] | 손실 1.95
# | 에폭 3 |  반복 1001 / 9295 | 시간 1574[s] | 손실 1.96
# | 에폭 3 |  반복 1021 / 9295 | 시간 1576[s] | 손실 1.97
# | 에폭 3 |  반복 1041 / 9295 | 시간 1578[s] | 손실 1.98
# | 에폭 3 |  반복 1061 / 9295 | 시간 1579[s] | 손실 1.94
# | 에폭 3 |  반복 1081 / 9295 | 시간 1581[s] | 손실 1.96
# | 에폭 3 |  반복 1101 / 9295 | 시간 1582[s] | 손실 1.94
# | 에폭 3 |  반복 1121 / 9295 | 시간 1584[s] | 손실 1.93
# | 에폭 3 |  반복 1141 / 9295 | 시간 1585[s] | 손실 1.94
# | 에폭 3 |  반복 1161 / 9295 | 시간 1587[s] | 손실 1.96
# | 에폭 3 |  반복 1181 / 9295 | 시간 1589[s] | 손실 1.93
# | 에폭 3 |  반복 1201 / 9295 | 시간 1590[s] | 손실 1.95
# | 에폭 3 |  반복 1221 / 9295 | 시간 1592[s] | 손실 1.96
# | 에폭 3 |  반복 1241 / 9295 | 시간 1593[s] | 손실 1.98
# | 에폭 3 |  반복 1261 / 9295 | 시간 1595[s] | 손실 1.93
# | 에폭 3 |  반복 1281 / 9295 | 시간 1596[s] | 손실 1.98
# | 에폭 3 |  반복 1301 / 9295 | 시간 1598[s] | 손실 1.95
# | 에폭 3 |  반복 1321 / 9295 | 시간 1600[s] | 손실 1.96
# | 에폭 3 |  반복 1341 / 9295 | 시간 1601[s] | 손실 1.96
# | 에폭 3 |  반복 1361 / 9295 | 시간 1603[s] | 손실 1.95
# | 에폭 3 |  반복 1381 / 9295 | 시간 1604[s] | 손실 1.91
# | 에폭 3 |  반복 1401 / 9295 | 시간 1606[s] | 손실 1.94
# | 에폭 3 |  반복 1421 / 9295 | 시간 1608[s] | 손실 1.95
# | 에폭 3 |  반복 1441 / 9295 | 시간 1609[s] | 손실 1.98
# | 에폭 3 |  반복 1461 / 9295 | 시간 1611[s] | 손실 1.98
# | 에폭 3 |  반복 1481 / 9295 | 시간 1612[s] | 손실 1.96
# | 에폭 3 |  반복 1501 / 9295 | 시간 1614[s] | 손실 1.95
# | 에폭 3 |  반복 1521 / 9295 | 시간 1616[s] | 손실 1.95
# | 에폭 3 |  반복 1541 / 9295 | 시간 1617[s] | 손실 1.99
# | 에폭 3 |  반복 1561 / 9295 | 시간 1619[s] | 손실 1.96
# | 에폭 3 |  반복 1581 / 9295 | 시간 1620[s] | 손실 1.95
# | 에폭 3 |  반복 1601 / 9295 | 시간 1622[s] | 손실 1.95
# | 에폭 3 |  반복 1621 / 9295 | 시간 1624[s] | 손실 1.94
# | 에폭 3 |  반복 1641 / 9295 | 시간 1625[s] | 손실 1.95
# | 에폭 3 |  반복 1661 / 9295 | 시간 1627[s] | 손실 1.92
# | 에폭 3 |  반복 1681 / 9295 | 시간 1628[s] | 손실 1.97
# | 에폭 3 |  반복 1701 / 9295 | 시간 1630[s] | 손실 1.96
# | 에폭 3 |  반복 1721 / 9295 | 시간 1632[s] | 손실 1.92
# ...
# | 에폭 6 |  반복 6761 / 9295 | 시간 4236[s] | 손실 1.65
# | 에폭 6 |  반복 6781 / 9295 | 시간 4237[s] | 손실 1.62
# | 에폭 6 |  반복 6801 / 9295 | 시간 4239[s] | 손실 1.64
# | 에폭 6 |  반복 6821 / 9295 | 시간 4240[s] | 손실 1.64
# | 에폭 6 |  반복 6841 / 9295 | 시간 4242[s] | 손실 1.65
# | 에폭 6 |  반복 6861 / 9295 | 시간 4243[s] | 손실 1.62
# | 에폭 6 |  반복 6881 / 9295 | 시간 4245[s] | 손실 1.63
# | 에폭 6 |  반복 6901 / 9295 | 시간 4246[s] | 손실 1.65
# | 에폭 6 |  반복 6921 / 9295 | 시간 4248[s] | 손실 1.65
# | 에폭 6 |  반복 6941 / 9295 | 시간 4250[s] | 손실 1.62
# | 에폭 6 |  반복 6961 / 9295 | 시간 4251[s] | 손실 1.69
# | 에폭 6 |  반복 6981 / 9295 | 시간 4253[s] | 손실 1.66
# | 에폭 6 |  반복 7001 / 9295 | 시간 4254[s] | 손실 1.65
# | 에폭 6 |  반복 7021 / 9295 | 시간 4256[s] | 손실 1.63
# | 에폭 6 |  반복 7041 / 9295 | 시간 4258[s] | 손실 1.65
# | 에폭 6 |  반복 7061 / 9295 | 시간 4259[s] | 손실 1.68
# | 에폭 6 |  반복 7081 / 9295 | 시간 4261[s] | 손실 1.68
# | 에폭 6 |  반복 7101 / 9295 | 시간 4263[s] | 손실 1.65
# | 에폭 6 |  반복 7121 / 9295 | 시간 4264[s] | 손실 1.63
# | 에폭 6 |  반복 7141 / 9295 | 시간 4266[s] | 손실 1.64
# | 에폭 6 |  반복 7161 / 9295 | 시간 4267[s] | 손실 1.65
# | 에폭 6 |  반복 7181 / 9295 | 시간 4269[s] | 손실 1.65
# | 에폭 6 |  반복 7201 / 9295 | 시간 4271[s] | 손실 1.64
# | 에폭 6 |  반복 7221 / 9295 | 시간 4272[s] | 손실 1.66
# | 에폭 6 |  반복 7241 / 9295 | 시간 4274[s] | 손실 1.61
# | 에폭 6 |  반복 7261 / 9295 | 시간 4276[s] | 손실 1.67
# | 에폭 6 |  반복 7281 / 9295 | 시간 4277[s] | 손실 1.66
# | 에폭 6 |  반복 7301 / 9295 | 시간 4279[s] | 손실 1.64
# | 에폭 6 |  반복 7321 / 9295 | 시간 4280[s] | 손실 1.63
# | 에폭 6 |  반복 7341 / 9295 | 시간 4282[s] | 손실 1.68
# | 에폭 6 |  반복 7361 / 9295 | 시간 4283[s] | 손실 1.63
# | 에폭 6 |  반복 7381 / 9295 | 시간 4285[s] | 손실 1.64
# | 에폭 6 |  반복 7401 / 9295 | 시간 4287[s] | 손실 1.61
# | 에폭 6 |  반복 7421 / 9295 | 시간 4288[s] | 손실 1.63
# | 에폭 6 |  반복 7441 / 9295 | 시간 4290[s] | 손실 1.66
# | 에폭 6 |  반복 7461 / 9295 | 시간 4292[s] | 손실 1.64
# | 에폭 6 |  반복 7481 / 9295 | 시간 4293[s] | 손실 1.65
# | 에폭 6 |  반복 7501 / 9295 | 시간 4295[s] | 손실 1.68
# | 에폭 6 |  반복 7521 / 9295 | 시간 4296[s] | 손실 1.60
# | 에폭 6 |  반복 7541 / 9295 | 시간 4298[s] | 손실 1.67
# | 에폭 6 |  반복 7561 / 9295 | 시간 4299[s] | 손실 1.68
# | 에폭 6 |  반복 7581 / 9295 | 시간 4301[s] | 손실 1.62
# | 에폭 6 |  반복 7601 / 9295 | 시간 4303[s] | 손실 1.66
# | 에폭 6 |  반복 7621 / 9295 | 시간 4304[s] | 손실 1.67
# | 에폭 6 |  반복 7641 / 9295 | 시간 4306[s] | 손실 1.66
# | 에폭 6 |  반복 7661 / 9295 | 시간 4307[s] | 손실 1.64
# | 에폭 6 |  반복 7681 / 9295 | 시간 4309[s] | 손실 1.68
# | 에폭 6 |  반복 7701 / 9295 | 시간 4310[s] | 손실 1.66
# | 에폭 6 |  반복 7721 / 9295 | 시간 4312[s] | 손실 1.64
# | 에폭 6 |  반복 7741 / 9295 | 시간 4313[s] | 손실 1.65
# | 에폭 6 |  반복 7761 / 9295 | 시간 4315[s] | 손실 1.67
# | 에폭 6 |  반복 7781 / 9295 | 시간 4317[s] | 손실 1.63
# | 에폭 6 |  반복 7801 / 9295 | 시간 4318[s] | 손실 1.66
# | 에폭 6 |  반복 7821 / 9295 | 시간 4320[s] | 손실 1.68
# | 에폭 6 |  반복 7841 / 9295 | 시간 4321[s] | 손실 1.68
# | 에폭 6 |  반복 7861 / 9295 | 시간 4323[s] | 손실 1.62
# | 에폭 6 |  반복 7881 / 9295 | 시간 4324[s] | 손실 1.65
# | 에폭 6 |  반복 7901 / 9295 | 시간 4326[s] | 손실 1.67
# | 에폭 6 |  반복 7921 / 9295 | 시간 4327[s] | 손실 1.67
# | 에폭 6 |  반복 7941 / 9295 | 시간 4329[s] | 손실 1.75
# | 에폭 6 |  반복 7961 / 9295 | 시간 4330[s] | 손실 1.68
# | 에폭 6 |  반복 7981 / 9295 | 시간 4332[s] | 손실 1.68
# | 에폭 6 |  반복 8001 / 9295 | 시간 4334[s] | 손실 1.69
# | 에폭 6 |  반복 8021 / 9295 | 시간 4335[s] | 손실 1.67
# | 에폭 6 |  반복 8041 / 9295 | 시간 4337[s] | 손실 1.62
# | 에폭 6 |  반복 8061 / 9295 | 시간 4338[s] | 손실 1.64
# | 에폭 6 |  반복 8081 / 9295 | 시간 4340[s] | 손실 1.63
# | 에폭 6 |  반복 8101 / 9295 | 시간 4342[s] | 손실 1.67
# | 에폭 6 |  반복 8121 / 9295 | 시간 4343[s] | 손실 1.65
# | 에폭 6 |  반복 8141 / 9295 | 시간 4345[s] | 손실 1.65
# | 에폭 6 |  반복 8161 / 9295 | 시간 4346[s] | 손실 1.69
# | 에폭 6 |  반복 8181 / 9295 | 시간 4348[s] | 손실 1.62
# | 에폭 6 |  반복 8201 / 9295 | 시간 4349[s] | 손실 1.63
# | 에폭 6 |  반복 8221 / 9295 | 시간 4351[s] | 손실 1.66
# | 에폭 6 |  반복 8241 / 9295 | 시간 4352[s] | 손실 1.68
# | 에폭 6 |  반복 8261 / 9295 | 시간 4354[s] | 손실 1.65
# | 에폭 6 |  반복 8281 / 9295 | 시간 4355[s] | 손실 1.69
# | 에폭 6 |  반복 8301 / 9295 | 시간 4357[s] | 손실 1.71
# | 에폭 6 |  반복 8321 / 9295 | 시간 4358[s] | 손실 1.64
# | 에폭 6 |  반복 8341 / 9295 | 시간 4360[s] | 손실 1.66
# | 에폭 6 |  반복 8361 / 9295 | 시간 4361[s] | 손실 1.65
# | 에폭 6 |  반복 8381 / 9295 | 시간 4363[s] | 손실 1.70
# | 에폭 6 |  반복 8401 / 9295 | 시간 4365[s] | 손실 1.68
# | 에폭 6 |  반복 8421 / 9295 | 시간 4366[s] | 손실 1.62
# | 에폭 6 |  반복 8441 / 9295 | 시간 4368[s] | 손실 1.65
# | 에폭 6 |  반복 8461 / 9295 | 시간 4369[s] | 손실 1.63
# | 에폭 6 |  반복 8481 / 9295 | 시간 4371[s] | 손실 1.69
# | 에폭 6 |  반복 8501 / 9295 | 시간 4372[s] | 손실 1.69
# | 에폭 6 |  반복 8521 / 9295 | 시간 4374[s] | 손실 1.64
# | 에폭 6 |  반복 8541 / 9295 | 시간 4376[s] | 손실 1.63
# | 에폭 6 |  반복 8561 / 9295 | 시간 4377[s] | 손실 1.66
# | 에폭 6 |  반복 8581 / 9295 | 시간 4379[s] | 손실 1.66
# | 에폭 6 |  반복 8601 / 9295 | 시간 4380[s] | 손실 1.66
# | 에폭 6 |  반복 8621 / 9295 | 시간 4382[s] | 손실 1.66
# | 에폭 6 |  반복 8641 / 9295 | 시간 4384[s] | 손실 1.64
# | 에폭 6 |  반복 8661 / 9295 | 시간 4385[s] | 손실 1.60
# | 에폭 6 |  반복 8681 / 9295 | 시간 4387[s] | 손실 1.59
# | 에폭 6 |  반복 8701 / 9295 | 시간 4388[s] | 손실 1.62
# | 에폭 6 |  반복 8721 / 9295 | 시간 4390[s] | 손실 1.64
# | 에폭 6 |  반복 8741 / 9295 | 시간 4392[s] | 손실 1.67
# | 에폭 6 |  반복 8761 / 9295 | 시간 4393[s] | 손실 1.66
# | 에폭 6 |  반복 8781 / 9295 | 시간 4395[s] | 손실 1.62
# | 에폭 6 |  반복 8801 / 9295 | 시간 4397[s] | 손실 1.65
# | 에폭 6 |  반복 8821 / 9295 | 시간 4398[s] | 손실 1.66
# | 에폭 6 |  반복 8841 / 9295 | 시간 4400[s] | 손실 1.67
# | 에폭 6 |  반복 8861 / 9295 | 시간 4401[s] | 손실 1.66
# | 에폭 6 |  반복 8881 / 9295 | 시간 4403[s] | 손실 1.68
# | 에폭 6 |  반복 8901 / 9295 | 시간 4405[s] | 손실 1.64
# | 에폭 6 |  반복 8921 / 9295 | 시간 4406[s] | 손실 1.68
# | 에폭 6 |  반복 8941 / 9295 | 시간 4408[s] | 손실 1.63
# | 에폭 6 |  반복 8961 / 9295 | 시간 4410[s] | 손실 1.64
# | 에폭 6 |  반복 8981 / 9295 | 시간 4411[s] | 손실 1.61
# | 에폭 6 |  반복 9001 / 9295 | 시간 4412[s] | 손실 1.66
# | 에폭 6 |  반복 9021 / 9295 | 시간 4414[s] | 손실 1.70
# | 에폭 6 |  반복 9041 / 9295 | 시간 4416[s] | 손실 1.66
# | 에폭 6 |  반복 9061 / 9295 | 시간 4417[s] | 손실 1.65
# | 에폭 6 |  반복 9081 / 9295 | 시간 4419[s] | 손실 1.67
# | 에폭 6 |  반복 9101 / 9295 | 시간 4421[s] | 손실 1.64
# | 에폭 6 |  반복 9121 / 9295 | 시간 4422[s] | 손실 1.69
# | 에폭 6 |  반복 9141 / 9295 | 시간 4424[s] | 손실 1.64
# | 에폭 6 |  반복 9161 / 9295 | 시간 4425[s] | 손실 1.64
# | 에폭 6 |  반복 9181 / 9295 | 시간 4427[s] | 손실 1.66
# | 에폭 6 |  반복 9201 / 9295 | 시간 4428[s] | 손실 1.66
# | 에폭 6 |  반복 9221 / 9295 | 시간 4430[s] | 손실 1.66
# | 에폭 6 |  반복 9241 / 9295 | 시간 4431[s] | 손실 1.63
# | 에폭 6 |  반복 9261 / 9295 | 시간 4433[s] | 손실 1.65
# | 에폭 6 |  반복 9281 / 9295 | 시간 4435[s] | 손실 1.66
# | 에폭 7 |  반복 1 / 9295 | 시간 4436[s] | 손실 1.65
# | 에폭 7 |  반복 21 / 9295 | 시간 4437[s] | 손실 1.60
# | 에폭 7 |  반복 41 / 9295 | 시간 4439[s] | 손실 1.56
# | 에폭 7 |  반복 61 / 9295 | 시간 4441[s] | 손실 1.59
# | 에폭 7 |  반복 81 / 9295 | 시간 4442[s] | 손실 1.56
# | 에폭 7 |  반복 101 / 9295 | 시간 4444[s] | 손실 1.56
# | 에폭 7 |  반복 121 / 9295 | 시간 4445[s] | 손실 1.58
# | 에폭 7 |  반복 141 / 9295 | 시간 4447[s] | 손실 1.54
# | 에폭 7 |  반복 161 / 9295 | 시간 4449[s] | 손실 1.57
# | 에폭 7 |  반복 181 / 9295 | 시간 4450[s] | 손실 1.57
# | 에폭 7 |  반복 201 / 9295 | 시간 4452[s] | 손실 1.58
# | 에폭 7 |  반복 221 / 9295 | 시간 4453[s] | 손실 1.55
# | 에폭 7 |  반복 241 / 9295 | 시간 4455[s] | 손실 1.61
# | 에폭 7 |  반복 261 / 9295 | 시간 4456[s] | 손실 1.54
# | 에폭 7 |  반복 281 / 9295 | 시간 4458[s] | 손실 1.58
# | 에폭 7 |  반복 301 / 9295 | 시간 4460[s] | 손실 1.59
# | 에폭 7 |  반복 321 / 9295 | 시간 4461[s] | 손실 1.59
# | 에폭 7 |  반복 341 / 9295 | 시간 4463[s] | 손실 1.60
# | 에폭 7 |  반복 361 / 9295 | 시간 4464[s] | 손실 1.56
# | 에폭 7 |  반복 381 / 9295 | 시간 4466[s] | 손실 1.56
# | 에폭 7 |  반복 401 / 9295 | 시간 4467[s] | 손실 1.59
# | 에폭 7 |  반복 421 / 9295 | 시간 4469[s] | 손실 1.60
# | 에폭 7 |  반복 441 / 9295 | 시간 4470[s] | 손실 1.57
# | 에폭 7 |  반복 461 / 9295 | 시간 4472[s] | 손실 1.60
# | 에폭 7 |  반복 481 / 9295 | 시간 4474[s] | 손실 1.53
# | 에폭 7 |  반복 501 / 9295 | 시간 4475[s] | 손실 1.59
# | 에폭 7 |  반복 521 / 9295 | 시간 4477[s] | 손실 1.56
# | 에폭 7 |  반복 541 / 9295 | 시간 4478[s] | 손실 1.56
# | 에폭 7 |  반복 561 / 9295 | 시간 4480[s] | 손실 1.58
# | 에폭 7 |  반복 581 / 9295 | 시간 4482[s] | 손실 1.57
# | 에폭 7 |  반복 601 / 9295 | 시간 4483[s] | 손실 1.60
# | 에폭 7 |  반복 621 / 9295 | 시간 4485[s] | 손실 1.58
# | 에폭 7 |  반복 641 / 9295 | 시간 4486[s] | 손실 1.61
# | 에폭 7 |  반복 661 / 9295 | 시간 4488[s] | 손실 1.58
# | 에폭 7 |  반복 681 / 9295 | 시간 4489[s] | 손실 1.55
# | 에폭 7 |  반복 701 / 9295 | 시간 4491[s] | 손실 1.57
# | 에폭 7 |  반복 721 / 9295 | 시간 4493[s] | 손실 1.52
# | 에폭 7 |  반복 741 / 9295 | 시간 4494[s] | 손실 1.59
# | 에폭 7 |  반복 761 / 9295 | 시간 4496[s] | 손실 1.58
# | 에폭 7 |  반복 781 / 9295 | 시간 4497[s] | 손실 1.59
# | 에폭 7 |  반복 801 / 9295 | 시간 4499[s] | 손실 1.59
# | 에폭 7 |  반복 821 / 9295 | 시간 4501[s] | 손실 1.61
# | 에폭 7 |  반복 841 / 9295 | 시간 4502[s] | 손실 1.55
# | 에폭 7 |  반복 861 / 9295 | 시간 4504[s] | 손실 1.60
# | 에폭 7 |  반복 881 / 9295 | 시간 4505[s] | 손실 1.56
# | 에폭 7 |  반복 901 / 9295 | 시간 4507[s] | 손실 1.56
# | 에폭 7 |  반복 921 / 9295 | 시간 4509[s] | 손실 1.56
# | 에폭 7 |  반복 941 / 9295 | 시간 4510[s] | 손실 1.57
# | 에폭 7 |  반복 961 / 9295 | 시간 4512[s] | 손실 1.58
# | 에폭 7 |  반복 981 / 9295 | 시간 4513[s] | 손실 1.57
# | 에폭 7 |  반복 1001 / 9295 | 시간 4515[s] | 손실 1.56
# | 에폭 7 |  반복 1021 / 9295 | 시간 4517[s] | 손실 1.58
# | 에폭 7 |  반복 1041 / 9295 | 시간 4518[s] | 손실 1.57
# | 에폭 7 |  반복 1061 / 9295 | 시간 4520[s] | 손실 1.56
# | 에폭 7 |  반복 1081 / 9295 | 시간 4521[s] | 손실 1.57
# | 에폭 7 |  반복 1101 / 9295 | 시간 4523[s] | 손실 1.59
# | 에폭 7 |  반복 1121 / 9295 | 시간 4524[s] | 손실 1.57
# | 에폭 7 |  반복 1141 / 9295 | 시간 4526[s] | 손실 1.58
# | 에폭 7 |  반복 1161 / 9295 | 시간 4528[s] | 손실 1.59
# | 에폭 7 |  반복 1181 / 9295 | 시간 4530[s] | 손실 1.53
# | 에폭 7 |  반복 1201 / 9295 | 시간 4531[s] | 손실 1.60
# | 에폭 7 |  반복 1221 / 9295 | 시간 4533[s] | 손실 1.59
# | 에폭 7 |  반복 1241 / 9295 | 시간 4534[s] | 손실 1.56
# | 에폭 7 |  반복 1261 / 9295 | 시간 4536[s] | 손실 1.60
# | 에폭 7 |  반복 1281 / 9295 | 시간 4537[s] | 손실 1.59
# | 에폭 7 |  반복 1301 / 9295 | 시간 4539[s] | 손실 1.59
# | 에폭 7 |  반복 1321 / 9295 | 시간 4540[s] | 손실 1.58
# | 에폭 7 |  반복 1341 / 9295 | 시간 4542[s] | 손실 1.58
# | 에폭 7 |  반복 1361 / 9295 | 시간 4543[s] | 손실 1.58
# | 에폭 7 |  반복 1381 / 9295 | 시간 4545[s] | 손실 1.59
# | 에폭 7 |  반복 1401 / 9295 | 시간 4547[s] | 손실 1.58
# | 에폭 7 |  반복 1421 / 9295 | 시간 4548[s] | 손실 1.58
# | 에폭 7 |  반복 1441 / 9295 | 시간 4550[s] | 손실 1.55
# | 에폭 7 |  반복 1461 / 9295 | 시간 4551[s] | 손실 1.55
# | 에폭 7 |  반복 1481 / 9295 | 시간 4553[s] | 손실 1.62
# | 에폭 7 |  반복 1501 / 9295 | 시간 4555[s] | 손실 1.57
# | 에폭 7 |  반복 1521 / 9295 | 시간 4556[s] | 손실 1.53
# | 에폭 7 |  반복 1541 / 9295 | 시간 4558[s] | 손실 1.58
# | 에폭 7 |  반복 1561 / 9295 | 시간 4559[s] | 손실 1.62
# | 에폭 7 |  반복 1581 / 9295 | 시간 4561[s] | 손실 1.57
# | 에폭 7 |  반복 1601 / 9295 | 시간 4562[s] | 손실 1.59
# | 에폭 7 |  반복 1621 / 9295 | 시간 4564[s] | 손실 1.61
# | 에폭 7 |  반복 1641 / 9295 | 시간 4565[s] | 손실 1.58
# | 에폭 7 |  반복 1661 / 9295 | 시간 4567[s] | 손실 1.58
# | 에폭 7 |  반복 1681 / 9295 | 시간 4569[s] | 손실 1.64
# | 에폭 7 |  반복 1701 / 9295 | 시간 4570[s] | 손실 1.58
# | 에폭 7 |  반복 1721 / 9295 | 시간 4572[s] | 손실 1.57
# | 에폭 7 |  반복 1741 / 9295 | 시간 4574[s] | 손실 1.57
# | 에폭 7 |  반복 1761 / 9295 | 시간 4575[s] | 손실 1.60
# | 에폭 7 |  반복 1781 / 9295 | 시간 4577[s] | 손실 1.56
# | 에폭 7 |  반복 1801 / 9295 | 시간 4578[s] | 손실 1.57
# | 에폭 7 |  반복 1821 / 9295 | 시간 4580[s] | 손실 1.57
# | 에폭 7 |  반복 1841 / 9295 | 시간 4582[s] | 손실 1.61
# | 에폭 7 |  반복 1861 / 9295 | 시간 4583[s] | 손실 1.60
# | 에폭 7 |  반복 1881 / 9295 | 시간 4585[s] | 손실 1.60
# | 에폭 7 |  반복 1901 / 9295 | 시간 4587[s] | 손실 1.59
# | 에폭 7 |  반복 1921 / 9295 | 시간 4588[s] | 손실 1.57
# | 에폭 7 |  반복 1941 / 9295 | 시간 4590[s] | 손실 1.57
# | 에폭 7 |  반복 1961 / 9295 | 시간 4591[s] | 손실 1.57
# | 에폭 7 |  반복 1981 / 9295 | 시간 4593[s] | 손실 1.57
# | 에폭 7 |  반복 2001 / 9295 | 시간 4594[s] | 손실 1.54
# | 에폭 7 |  반복 2021 / 9295 | 시간 4596[s] | 손실 1.56
# | 에폭 7 |  반복 2041 / 9295 | 시간 4597[s] | 손실 1.60
# | 에폭 7 |  반복 2061 / 9295 | 시간 4599[s] | 손실 1.58
# | 에폭 7 |  반복 2081 / 9295 | 시간 4601[s] | 손실 1.57
# | 에폭 7 |  반복 2101 / 9295 | 시간 4602[s] | 손실 1.58
# | 에폭 7 |  반복 2121 / 9295 | 시간 4604[s] | 손실 1.52
# | 에폭 7 |  반복 2141 / 9295 | 시간 4605[s] | 손실 1.58
# | 에폭 7 |  반복 2161 / 9295 | 시간 4607[s] | 손실 1.58
# | 에폭 7 |  반복 2181 / 9295 | 시간 4609[s] | 손실 1.56
# | 에폭 7 |  반복 2201 / 9295 | 시간 4610[s] | 손실 1.57
# | 에폭 7 |  반복 2221 / 9295 | 시간 4612[s] | 손실 1.59
# | 에폭 7 |  반복 2241 / 9295 | 시간 4613[s] | 손실 1.63
# | 에폭 7 |  반복 2261 / 9295 | 시간 4615[s] | 손실 1.57
# | 에폭 7 |  반복 2281 / 9295 | 시간 4616[s] | 손실 1.56
# | 에폭 7 |  반복 2301 / 9295 | 시간 4618[s] | 손실 1.62
# | 에폭 7 |  반복 2321 / 9295 | 시간 4619[s] | 손실 1.62
# | 에폭 7 |  반복 2341 / 9295 | 시간 4621[s] | 손실 1.57
# | 에폭 7 |  반복 2361 / 9295 | 시간 4622[s] | 손실 1.57
# | 에폭 7 |  반복 2381 / 9295 | 시간 4624[s] | 손실 1.59
# | 에폭 7 |  반복 2401 / 9295 | 시간 4626[s] | 손실 1.57
# | 에폭 7 |  반복 2421 / 9295 | 시간 4627[s] | 손실 1.58
# | 에폭 7 |  반복 2441 / 9295 | 시간 4629[s] | 손실 1.57
# | 에폭 7 |  반복 2461 / 9295 | 시간 4630[s] | 손실 1.61
# | 에폭 7 |  반복 2481 / 9295 | 시간 4632[s] | 손실 1.57
# | 에폭 7 |  반복 2501 / 9295 | 시간 4634[s] | 손실 1.58
# | 에폭 7 |  반복 2521 / 9295 | 시간 4635[s] | 손실 1.59
# | 에폭 7 |  반복 2541 / 9295 | 시간 4637[s] | 손실 1.58
# | 에폭 7 |  반복 2561 / 9295 | 시간 4638[s] | 손실 1.58
# | 에폭 7 |  반복 2581 / 9295 | 시간 4640[s] | 손실 1.59
# | 에폭 7 |  반복 2601 / 9295 | 시간 4641[s] | 손실 1.57
# | 에폭 7 |  반복 2621 / 9295 | 시간 4643[s] | 손실 1.60
# | 에폭 7 |  반복 2641 / 9295 | 시간 4644[s] | 손실 1.62
# | 에폭 7 |  반복 2661 / 9295 | 시간 4646[s] | 손실 1.56
# | 에폭 7 |  반복 2681 / 9295 | 시간 4648[s] | 손실 1.59
# | 에폭 7 |  반복 2701 / 9295 | 시간 4649[s] | 손실 1.60
# | 에폭 7 |  반복 2721 / 9295 | 시간 4651[s] | 손실 1.59
# | 에폭 7 |  반복 2741 / 9295 | 시간 4652[s] | 손실 1.57
# | 에폭 7 |  반복 2761 / 9295 | 시간 4654[s] | 손실 1.56
# | 에폭 7 |  반복 2781 / 9295 | 시간 4655[s] | 손실 1.57
# | 에폭 7 |  반복 2801 / 9295 | 시간 4657[s] | 손실 1.58
# | 에폭 7 |  반복 2821 / 9295 | 시간 4658[s] | 손실 1.61
# | 에폭 7 |  반복 2841 / 9295 | 시간 4660[s] | 손실 1.57
# | 에폭 7 |  반복 2861 / 9295 | 시간 4662[s] | 손실 1.58
# | 에폭 7 |  반복 2881 / 9295 | 시간 4663[s] | 손실 1.58
# | 에폭 7 |  반복 2901 / 9295 | 시간 4665[s] | 손실 1.54
# | 에폭 7 |  반복 2921 / 9295 | 시간 4666[s] | 손실 1.58
# | 에폭 7 |  반복 2941 / 9295 | 시간 4668[s] | 손실 1.55
# | 에폭 7 |  반복 2961 / 9295 | 시간 4669[s] | 손실 1.59
# | 에폭 7 |  반복 2981 / 9295 | 시간 4671[s] | 손실 1.53
# | 에폭 7 |  반복 3001 / 9295 | 시간 4673[s] | 손실 1.63
# | 에폭 7 |  반복 3021 / 9295 | 시간 4674[s] | 손실 1.63
# | 에폭 7 |  반복 3041 / 9295 | 시간 4676[s] | 손실 1.59
# | 에폭 7 |  반복 3061 / 9295 | 시간 4677[s] | 손실 1.60
# | 에폭 7 |  반복 3081 / 9295 | 시간 4679[s] | 손실 1.58
# | 에폭 7 |  반복 3101 / 9295 | 시간 4681[s] | 손실 1.62
# | 에폭 7 |  반복 3121 / 9295 | 시간 4682[s] | 손실 1.60
# | 에폭 7 |  반복 3141 / 9295 | 시간 4684[s] | 손실 1.56
# | 에폭 7 |  반복 3161 / 9295 | 시간 4685[s] | 손실 1.57
# | 에폭 7 |  반복 3181 / 9295 | 시간 4687[s] | 손실 1.59
# | 에폭 7 |  반복 3201 / 9295 | 시간 4689[s] | 손실 1.56
# | 에폭 7 |  반복 3221 / 9295 | 시간 4690[s] | 손실 1.58
# | 에폭 7 |  반복 3241 / 9295 | 시간 4692[s] | 손실 1.60
# | 에폭 7 |  반복 3261 / 9295 | 시간 4693[s] | 손실 1.59
# | 에폭 7 |  반복 3281 / 9295 | 시간 4695[s] | 손실 1.61
# | 에폭 7 |  반복 3301 / 9295 | 시간 4697[s] | 손실 1.60
# | 에폭 7 |  반복 3321 / 9295 | 시간 4698[s] | 손실 1.59
# | 에폭 7 |  반복 3341 / 9295 | 시간 4700[s] | 손실 1.59
# | 에폭 7 |  반복 3361 / 9295 | 시간 4701[s] | 손실 1.61
# | 에폭 7 |  반복 3381 / 9295 | 시간 4703[s] | 손실 1.56
# | 에폭 7 |  반복 3401 / 9295 | 시간 4705[s] | 손실 1.60
# | 에폭 7 |  반복 3421 / 9295 | 시간 4706[s] | 손실 1.56
# | 에폭 7 |  반복 3441 / 9295 | 시간 4708[s] | 손실 1.55
# | 에폭 7 |  반복 3461 / 9295 | 시간 4709[s] | 손실 1.58
# | 에폭 7 |  반복 3481 / 9295 | 시간 4711[s] | 손실 1.52
# | 에폭 7 |  반복 3501 / 9295 | 시간 4712[s] | 손실 1.56
# | 에폭 7 |  반복 3521 / 9295 | 시간 4714[s] | 손실 1.61
# | 에폭 7 |  반복 3541 / 9295 | 시간 4715[s] | 손실 1.58
# | 에폭 7 |  반복 3561 / 9295 | 시간 4717[s] | 손실 1.59
# | 에폭 7 |  반복 3581 / 9295 | 시간 4719[s] | 손실 1.57
# | 에폭 7 |  반복 3601 / 9295 | 시간 4720[s] | 손실 1.55
# | 에폭 7 |  반복 3621 / 9295 | 시간 4722[s] | 손실 1.58
# | 에폭 7 |  반복 3641 / 9295 | 시간 4723[s] | 손실 1.57
# | 에폭 7 |  반복 3661 / 9295 | 시간 4724[s] | 손실 1.59
# | 에폭 7 |  반복 3681 / 9295 | 시간 4726[s] | 손실 1.58
# | 에폭 7 |  반복 3701 / 9295 | 시간 4728[s] | 손실 1.63
# | 에폭 7 |  반복 3721 / 9295 | 시간 4729[s] | 손실 1.59
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-a8f6ec54cc98> in <module>()
#      32
#      33 # 학습 시작
# ---> 34 trainer.fit(contexts, target, max_epoch, batch_size)
#      35 trainer.plot()
#      36
#
# /content/drive/MyDrive/Cola/common/trainer.py in fit(self, x, t, max_epoch, batch_size, max_grad, eval_interval)
#      42                 if max_grad is not None:
#      43                     clip_grads(grads, max_grad)
# ---> 44                 optimizer.update(params, grads)
#      45                 total_loss += loss
#      46                 loss_count += 1
#
# /content/drive/MyDrive/Cola/common/optimizer.py in update(self, params, grads)
#     126             self.v[i] += (1 - self.beta2) * (grads[i]**2 - self.v[i])
#     127
# --> 128             params[i] -= lr_t * self.m[i] / (np.sqrt(self.v[i]) + 1e-7)
#
# KeyboardInterrupt:

# %%
from common.util import most_similar, analogy
import pickle


pkl_file = 'cbow_params.pkl'
# pkl_file = 'skipgram_params.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']

# 가장 비슷한(most similar) 단어 뽑기
querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)

# %%
print('-'*50)
analogy('king', 'man', 'queen',  word_to_id, id_to_word, word_vecs)
analogy('take', 'took', 'go',  word_to_id, id_to_word, word_vecs)
analogy('car', 'cars', 'child',  word_to_id, id_to_word, word_vecs)
analogy('good', 'better', 'bad',  word_to_id, id_to_word, word_vecs)
