# %% [markdown]
# # ch4 word2vec 속도개선

# %% [markdown]
# word2vec은 단순 2층 신경망이라 간단하게 구현 가능. 하지만 가장 큰 문제는 말뭉치에 포함된 어휘 수가 많아지면 계산량도 커진다는 점. word2vec의 속도 개선을 위해 다음 두 가지 추가
# 1. Embedding이라는 새로운 계층 도입
# 2. 네거티브 샘플링이라는 새로운 손실함수 도입

# %% [markdown]
# ## 4.1 개선 1 - Embedding

# %% [markdown]
# 어휘가 100만개, 은닉충 뉴런이 100개인 cbow의 모델에서는 입력층과 출력층에 각 100만개의 뉴런이 있다고 하면
# 1. 입력층의 원핫 표현과 가중치 행렬 $W_{in}$ 의 곱
# 2. 은닉충과 가중치 행렬 $W_{out}$ 의 곱 및 Softmax 계층의 계산
# 의 계산에 많은 시간이 소요된다.

# %% [markdown]
# 1. 입력층의 원핫 표현과 가중치 행렬 $W_{in}$ 의 곱
# 어휘 수가 많아지면 원학 표현의 벡터 크기도 커진다. 이 원핫 벡터와 가중치 행렬 $W_{in}$를 곱해야 한다.
# ==>Embedding 도입
# 2. 은닉충과 가중치 행렬 $W_{out}$의 곱 계산량이 많다
# ==>네거티브 샘플링이라는 새로운 손실 함수 도입

# %% [markdown]
# ### Embedding 계층

# %%
# 그림 4-3

# %% [markdown]
# 원핫 표현과 MMatMul 계층의 가중치 행렬을 곱하는 것은 단지 행렬의 특정 행을 추출하는 것. 따라서 원핫 표현으로의 변화와 MatMul계층의 행렬 곱은 사실상 필요가 없는 것.
# 가중치 매개변수로부터 '단어 ID에 해당하는 행(벡터)'을 추출하는 계층 : Embedding 계층

# %% [markdown]
# ### Embedding 계층 구현

# %%
import numpy as np
W = np.arange(21).reshape(7,3)

# %%
W[2]
# Out:
# array([6, 7, 8])

# %%
W[5]
# Out:
# array([15, 16, 17])

# %%
idx = np.array([1,0,3,0])

# %%
W[idx] #여러 개 반환 가능
# Out:
# array([[ 3,  4,  5],
#        [ 0,  1,  2],
#        [ 9, 10, 11],
#        [ 0,  1,  2]])

# %%
class Embedding:
    def __init__(self, W):
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.idx = None

    def forward(self, idx):
        W, = self.params
        self.idx = idx
        out = W[idx]
        return out

    # 가중치 기울기 dW를 꺼낸 다음 dW의 원소를 0으로 덮어쓴다.
    def backward(self, dout):
        dW, = self.grads
        dW[...] = 0
        # dW[self.idx] = dout # 앞 층에서 전해진 기울기 dout를 할당; 나쁜 예
        
        '''
        idx가 중복된 원소를 가지고 있다면 dh를 해당 행에 할당할 때 문제가 생긴다.
        '''
        np.add.at(dW, self.idx, dout)
        return None

# %% [markdown]
# ## 4.2 개선 2 - 네거티브 샘플링

# %% [markdown]
# 행렬 곱과 softmax 계층의 계산 병목을 해소하는 목적
# softmax 대신 네거티브 샘플링을 이용하면 어휘가 아무리 많아져도 계산량을 낮은 수준에서 일정하게 억제 가능하다.

# %% [markdown]
# ### 은닉충 이후 계산의 문제점

# %% [markdown]
# 어휘가 100만개일 때, Embedding 계층을 도입하려 입력층 계산에서의 낭비를 줄였다. 남은 문제는 은닉충 이후의 처리.
# 1. 은닉충의 뉴런과 가중치 행렬  $W_{out}$ 의 곱 - 큰 행렬의 곱을 계산하려면 시간도 오래 걸리고 메모리도 많이 필요하다
# 2. softmax 계층의 계산 - 어휘가 많아지면 softmax의 계산량도 증가
#
# 위 두 부분에서 계산이 오래 걸린다

# %% [markdown]
# ### 다중분류 --> 이진분류

# %% [markdown]
# 핵심 아이디어: 이진 분류/ 이진 분류로 근사하는 것
# ==> 이렇게 하면 뉴런을 하나만준비하면 된다.
# 은닉충과 출력 층의 가중치 행렬의 내적은 특정 단어에 해당하는 열(단어 벡터) 만을 추출하고, 그 추출된 벡터와 은닉충 뉴런과의 내적을 계산하면 끝이다. 이 계산 값이 최종 점수.

# %% [markdown]
# 이전까지의 출력층에서 모든 단어를 대상으로 계산을 수행한거라면 여기에서는 특정 단어 하나에 주목하여 그 점수만을 계산하는 것. 그리고 시그모이드 함수를 이용해 그 점수를 확률로 변환

# %% [markdown]
# ### 시그모이드 함수와 교차 엔트로피 오차

# %% [markdown]
# 이진분류의 손실을 구할 때는 손실 함수로 '교차 엔트로피 오차'를 사용

# %% [markdown]
# 교차 엔트로피 식

# %% [markdown]
# 오차가 크면 크게 학습하고 오차가 작으면 작게 학습한다.

# %% [markdown]
# ### 구현

# %%
import sys
sys.path.append('..')
from common.np import *  # import numpy as np
from common.layers import Embedding, SigmoidWithLoss
import collections


class EmbeddingDot:
    def __init__(self, W):
        self.embed = Embedding(W)
        self.params = self.embed.params
        self.grads = self.embed.grads
        self.cache = None

    def forward(self, h, idx):
        target_W = self.embed.forward(idx)
        out = np.sum(target_W * h, axis=1)

        self.cache = (h, target_W)
        return out

    def backward(self, dout):
        h, target_W = self.cache
        dout = dout.reshape(dout.shape[0], 1)

        dtarget_W = dout * h
        self.embed.backward(dtarget_W)
        dh = dout * target_W
        return dh

# %% [markdown]
# ### 네거티브 샘플링

# %% [markdown]
# #### 네거티브 샘플링 구현

# %% [markdown]
# #### 네거티브 샘플링 기법

# %% [markdown]
# ## 4.3 개선판 word2vec 학습

# %% [markdown]
# ### CBOW 모델
# 개선된 simpleCBOW 의 모델: Embedding 계층와 Negative Samplint Loss 계층을 적용하는 것.

# %%
import sys
sys.path.append('..')
from common.np import *  # import numpy as np
from common.layers import Embedding
from ch04.negative_sampling_layer import NegativeSamplingLoss


class CBOW:
    #초기화 4가지 인수: 어휘 수, 은닉충의 뉴런 수, 단어 ID의 목록
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size

        # 가중치 초기화
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(V, H).astype('f')

        # 계층 생성
        self.in_layers = []
        for i in range(2 * window_size):
            layer = Embedding(W_in)  # Embedding 계층 사용
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)

        # 모든 가중치와 기울기를 배열에 모은다.
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 인스턴스 변수에 단어의 분산 표현을 저장한다.
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = 0
        for i, layer in enumerate(self.in_layers):
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        return loss

    def backward(self, dout=1):
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self.in_layers:
            layer.backward(dout)
        return None

# %% [markdown]
# ### CBOW 모델 학습 코드

# %%
import numpy as np
from common import config
# GPU에서 실행하려면 아래 주석을 해제하세요(CuPy 필요).
# ===============================================
# config.GPU = True
# ===============================================
import pickle
from common.trainer import Trainer
from common.optimizer import Adam
from ch04.cbow import CBOW
from ch04.skip_gram import SkipGram
from common.util import create_contexts_target, to_cpu, to_gpu
from dataset import ptb


# 하이퍼파라미터 설정
window_size = 5
hidden_size = 100
batch_size = 100
max_epoch = 10

# 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)
if config.GPU:
    contexts, target = to_gpu(contexts), to_gpu(target)

# 모델 등 생성
model = CBOW(vocab_size, hidden_size, window_size, corpus)
# model = SkipGram(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 나중에 사용할 수 있도록 필요한 데이터 저장
word_vecs = model.word_vecs
if config.GPU:
    word_vecs = to_cpu(word_vecs)
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'  # or 'skipgram_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# | 에폭 1 |  반복 1 / 5619 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 21 / 5619 | 시간 5[s] | 손실 4.16
# | 에폭 1 |  반복 41 / 5619 | 시간 9[s] | 손실 4.15
# | 에폭 1 |  반복 61 / 5619 | 시간 14[s] | 손실 4.12
# | 에폭 1 |  반복 81 / 5619 | 시간 18[s] | 손실 4.05
# | 에폭 1 |  반복 101 / 5619 | 시간 23[s] | 손실 3.94
# | 에폭 1 |  반복 121 / 5619 | 시간 28[s] | 손실 3.78
# | 에폭 1 |  반복 141 / 5619 | 시간 33[s] | 손실 3.64
# | 에폭 1 |  반복 161 / 5619 | 시간 37[s] | 손실 3.49
# | 에폭 1 |  반복 181 / 5619 | 시간 42[s] | 손실 3.37
# | 에폭 1 |  반복 201 / 5619 | 시간 47[s] | 손실 3.24
# | 에폭 1 |  반복 221 / 5619 | 시간 51[s] | 손실 3.16
# | 에폭 1 |  반복 241 / 5619 | 시간 56[s] | 손실 3.08
# | 에폭 1 |  반복 261 / 5619 | 시간 61[s] | 손실 3.01
# | 에폭 1 |  반복 281 / 5619 | 시간 65[s] | 손실 2.98
# | 에폭 1 |  반복 301 / 5619 | 시간 70[s] | 손실 2.89
# | 에폭 1 |  반복 321 / 5619 | 시간 75[s] | 손실 2.88
# | 에폭 1 |  반복 341 / 5619 | 시간 81[s] | 손실 2.85
# | 에폭 1 |  반복 361 / 5619 | 시간 88[s] | 손실 2.81
# | 에폭 1 |  반복 381 / 5619 | 시간 94[s] | 손실 2.76
# | 에폭 1 |  반복 401 / 5619 | 시간 100[s] | 손실 2.75
# | 에폭 1 |  반복 421 / 5619 | 시간 106[s] | 손실 2.73
# | 에폭 1 |  반복 441 / 5619 | 시간 111[s] | 손실 2.70
# | 에폭 1 |  반복 461 / 5619 | 시간 118[s] | 손실 2.69
# | 에폭 1 |  반복 481 / 5619 | 시간 124[s] | 손실 2.70
# | 에폭 1 |  반복 501 / 5619 | 시간 130[s] | 손실 2.68
# | 에폭 1 |  반복 521 / 5619 | 시간 135[s] | 손실 2.65
# | 에폭 1 |  반복 541 / 5619 | 시간 141[s] | 손실 2.65
# | 에폭 1 |  반복 561 / 5619 | 시간 147[s] | 손실 2.65
# | 에폭 1 |  반복 581 / 5619 | 시간 152[s] | 손실 2.67
# | 에폭 1 |  반복 601 / 5619 | 시간 158[s] | 손실 2.63
# | 에폭 1 |  반복 621 / 5619 | 시간 164[s] | 손실 2.64
# | 에폭 1 |  반복 641 / 5619 | 시간 169[s] | 손실 2.62
# | 에폭 1 |  반복 661 / 5619 | 시간 175[s] | 손실 2.64
# | 에폭 1 |  반복 681 / 5619 | 시간 181[s] | 손실 2.63
# | 에폭 1 |  반복 701 / 5619 | 시간 189[s] | 손실 2.61
# | 에폭 1 |  반복 721 / 5619 | 시간 197[s] | 손실 2.64
# | 에폭 1 |  반복 741 / 5619 | 시간 204[s] | 손실 2.60
# | 에폭 1 |  반복 761 / 5619 | 시간 214[s] | 손실 2.60
# | 에폭 1 |  반복 781 / 5619 | 시간 220[s] | 손실 2.60
# | 에폭 1 |  반복 801 / 5619 | 시간 225[s] | 손실 2.57
# | 에폭 1 |  반복 821 / 5619 | 시간 232[s] | 손실 2.60
# | 에폭 1 |  반복 841 / 5619 | 시간 240[s] | 손실 2.59
# | 에폭 1 |  반복 861 / 5619 | 시간 248[s] | 손실 2.59
# | 에폭 1 |  반복 881 / 5619 | 시간 257[s] | 손실 2.59
# | 에폭 1 |  반복 901 / 5619 | 시간 270[s] | 손실 2.58
# | 에폭 1 |  반복 921 / 5619 | 시간 280[s] | 손실 2.57
# | 에폭 1 |  반복 941 / 5619 | 시간 291[s] | 손실 2.58
# | 에폭 1 |  반복 961 / 5619 | 시간 302[s] | 손실 2.56
# | 에폭 1 |  반복 981 / 5619 | 시간 312[s] | 손실 2.58
# | 에폭 1 |  반복 1001 / 5619 | 시간 320[s] | 손실 2.56
# | 에폭 1 |  반복 1021 / 5619 | 시간 328[s] | 손실 2.56
# | 에폭 1 |  반복 1041 / 5619 | 시간 337[s] | 손실 2.57
# | 에폭 1 |  반복 1061 / 5619 | 시간 344[s] | 손실 2.55
# | 에폭 1 |  반복 1081 / 5619 | 시간 351[s] | 손실 2.54
# | 에폭 1 |  반복 1101 / 5619 | 시간 359[s] | 손실 2.57
# | 에폭 1 |  반복 1121 / 5619 | 시간 370[s] | 손실 2.54
# | 에폭 1 |  반복 1141 / 5619 | 시간 376[s] | 손실 2.57
# | 에폭 1 |  반복 1161 / 5619 | 시간 386[s] | 손실 2.58
# | 에폭 1 |  반복 1181 / 5619 | 시간 393[s] | 손실 2.55
# | 에폭 1 |  반복 1201 / 5619 | 시간 399[s] | 손실 2.56
# | 에폭 1 |  반복 1221 / 5619 | 시간 405[s] | 손실 2.56
# | 에폭 1 |  반복 1241 / 5619 | 시간 412[s] | 손실 2.57
# | 에폭 1 |  반복 1261 / 5619 | 시간 418[s] | 손실 2.52
# | 에폭 1 |  반복 1281 / 5619 | 시간 425[s] | 손실 2.52
# | 에폭 1 |  반복 1301 / 5619 | 시간 431[s] | 손실 2.51
# | 에폭 1 |  반복 1321 / 5619 | 시간 437[s] | 손실 2.51
# | 에폭 1 |  반복 1341 / 5619 | 시간 448[s] | 손실 2.52
# | 에폭 1 |  반복 1361 / 5619 | 시간 456[s] | 손실 2.53
# | 에폭 1 |  반복 1381 / 5619 | 시간 467[s] | 손실 2.55
# | 에폭 1 |  반복 1401 / 5619 | 시간 479[s] | 손실 2.53
# | 에폭 1 |  반복 1421 / 5619 | 시간 490[s] | 손실 2.55
# | 에폭 1 |  반복 1441 / 5619 | 시간 502[s] | 손실 2.52
# | 에폭 1 |  반복 1461 / 5619 | 시간 511[s] | 손실 2.50
# | 에폭 1 |  반복 1481 / 5619 | 시간 519[s] | 손실 2.50
# | 에폭 1 |  반복 1501 / 5619 | 시간 529[s] | 손실 2.52
# | 에폭 1 |  반복 1521 / 5619 | 시간 538[s] | 손실 2.53
# | 에폭 1 |  반복 1541 / 5619 | 시간 544[s] | 손실 2.53
# | 에폭 1 |  반복 1561 / 5619 | 시간 549[s] | 손실 2.51
# | 에폭 1 |  반복 1581 / 5619 | 시간 554[s] | 손실 2.52
# | 에폭 1 |  반복 1601 / 5619 | 시간 560[s] | 손실 2.49
# | 에폭 1 |  반복 1621 / 5619 | 시간 568[s] | 손실 2.50
# | 에폭 1 |  반복 1641 / 5619 | 시간 576[s] | 손실 2.51
# | 에폭 1 |  반복 1661 / 5619 | 시간 582[s] | 손실 2.51
# | 에폭 1 |  반복 1681 / 5619 | 시간 592[s] | 손실 2.52
# | 에폭 1 |  반복 1701 / 5619 | 시간 600[s] | 손실 2.53
# | 에폭 1 |  반복 1721 / 5619 | 시간 608[s] | 손실 2.54
# | 에폭 1 |  반복 1741 / 5619 | 시간 613[s] | 손실 2.50
# | 에폭 1 |  반복 1761 / 5619 | 시간 618[s] | 손실 2.51
# | 에폭 1 |  반복 1781 / 5619 | 시간 624[s] | 손실 2.48
# | 에폭 1 |  반복 1801 / 5619 | 시간 630[s] | 손실 2.47
# | 에폭 1 |  반복 1821 / 5619 | 시간 636[s] | 손실 2.51
# | 에폭 1 |  반복 1841 / 5619 | 시간 642[s] | 손실 2.49
# | 에폭 1 |  반복 1861 / 5619 | 시간 648[s] | 손실 2.50
# | 에폭 1 |  반복 1881 / 5619 | 시간 653[s] | 손실 2.51
# | 에폭 1 |  반복 1901 / 5619 | 시간 658[s] | 손실 2.50
# | 에폭 1 |  반복 1921 / 5619 | 시간 666[s] | 손실 2.50
# | 에폭 1 |  반복 1941 / 5619 | 시간 674[s] | 손실 2.50
# | 에폭 1 |  반복 1961 / 5619 | 시간 679[s] | 손실 2.47
# | 에폭 1 |  반복 1981 / 5619 | 시간 689[s] | 손실 2.53
# | 에폭 1 |  반복 2001 / 5619 | 시간 703[s] | 손실 2.50
# | 에폭 1 |  반복 2021 / 5619 | 시간 713[s] | 손실 2.49
# | 에폭 1 |  반복 2041 / 5619 | 시간 722[s] | 손실 2.50
# | 에폭 1 |  반복 2061 / 5619 | 시간 730[s] | 손실 2.50
# | 에폭 1 |  반복 2081 / 5619 | 시간 736[s] | 손실 2.48
# | 에폭 1 |  반복 2101 / 5619 | 시간 742[s] | 손실 2.51
# | 에폭 1 |  반복 2121 / 5619 | 시간 748[s] | 손실 2.48
# | 에폭 1 |  반복 2141 / 5619 | 시간 754[s] | 손실 2.48
# | 에폭 1 |  반복 2161 / 5619 | 시간 760[s] | 손실 2.46
# | 에폭 1 |  반복 2181 / 5619 | 시간 766[s] | 손실 2.48
# | 에폭 1 |  반복 2201 / 5619 | 시간 772[s] | 손실 2.52
# | 에폭 1 |  반복 2221 / 5619 | 시간 778[s] | 손실 2.48
# | 에폭 1 |  반복 2241 / 5619 | 시간 783[s] | 손실 2.51
# | 에폭 1 |  반복 2261 / 5619 | 시간 789[s] | 손실 2.46
# | 에폭 1 |  반복 2281 / 5619 | 시간 795[s] | 손실 2.48
# | 에폭 1 |  반복 2301 / 5619 | 시간 801[s] | 손실 2.48
# | 에폭 1 |  반복 2321 / 5619 | 시간 807[s] | 손실 2.49
# | 에폭 1 |  반복 2341 / 5619 | 시간 813[s] | 손실 2.48
# | 에폭 1 |  반복 2361 / 5619 | 시간 821[s] | 손실 2.47
# | 에폭 1 |  반복 2381 / 5619 | 시간 827[s] | 손실 2.46
# | 에폭 1 |  반복 2401 / 5619 | 시간 835[s] | 손실 2.48
# | 에폭 1 |  반복 2421 / 5619 | 시간 844[s] | 손실 2.50
# | 에폭 1 |  반복 2441 / 5619 | 시간 850[s] | 손실 2.49
# | 에폭 1 |  반복 2461 / 5619 | 시간 857[s] | 손실 2.48
# | 에폭 1 |  반복 2481 / 5619 | 시간 864[s] | 손실 2.48
# | 에폭 1 |  반복 2501 / 5619 | 시간 872[s] | 손실 2.47
# | 에폭 1 |  반복 2521 / 5619 | 시간 879[s] | 손실 2.47
# | 에폭 1 |  반복 2541 / 5619 | 시간 886[s] | 손실 2.47
# | 에폭 1 |  반복 2561 / 5619 | 시간 892[s] | 손실 2.51
# | 에폭 1 |  반복 2581 / 5619 | 시간 898[s] | 손실 2.48
# | 에폭 1 |  반복 2601 / 5619 | 시간 904[s] | 손실 2.47
# | 에폭 1 |  반복 2621 / 5619 | 시간 910[s] | 손실 2.46
# | 에폭 1 |  반복 2641 / 5619 | 시간 917[s] | 손실 2.47
# | 에폭 1 |  반복 2661 / 5619 | 시간 924[s] | 손실 2.43
# | 에폭 1 |  반복 2681 / 5619 | 시간 930[s] | 손실 2.47
# | 에폭 1 |  반복 2701 / 5619 | 시간 936[s] | 손실 2.48
# | 에폭 1 |  반복 2721 / 5619 | 시간 942[s] | 손실 2.46
# | 에폭 1 |  반복 2741 / 5619 | 시간 948[s] | 손실 2.48
# | 에폭 1 |  반복 2761 / 5619 | 시간 954[s] | 손실 2.47
# | 에폭 1 |  반복 2781 / 5619 | 시간 961[s] | 손실 2.45
# | 에폭 1 |  반복 2801 / 5619 | 시간 967[s] | 손실 2.46
# | 에폭 1 |  반복 2821 / 5619 | 시간 974[s] | 손실 2.46
# | 에폭 1 |  반복 2841 / 5619 | 시간 982[s] | 손실 2.46
# | 에폭 1 |  반복 2861 / 5619 | 시간 989[s] | 손실 2.48
# | 에폭 1 |  반복 2881 / 5619 | 시간 996[s] | 손실 2.48
# | 에폭 1 |  반복 2901 / 5619 | 시간 1003[s] | 손실 2.48
# | 에폭 1 |  반복 2921 / 5619 | 시간 1011[s] | 손실 2.45
# | 에폭 1 |  반복 2941 / 5619 | 시간 1017[s] | 손실 2.49
# | 에폭 1 |  반복 2961 / 5619 | 시간 1023[s] | 손실 2.46
# | 에폭 1 |  반복 2981 / 5619 | 시간 1029[s] | 손실 2.45
# | 에폭 1 |  반복 3001 / 5619 | 시간 1036[s] | 손실 2.43
# | 에폭 1 |  반복 3021 / 5619 | 시간 1042[s] | 손실 2.46
# | 에폭 1 |  반복 3041 / 5619 | 시간 1047[s] | 손실 2.44
# | 에폭 1 |  반복 3061 / 5619 | 시간 1051[s] | 손실 2.44
# | 에폭 1 |  반복 3081 / 5619 | 시간 1055[s] | 손실 2.44
# | 에폭 1 |  반복 3101 / 5619 | 시간 1060[s] | 손실 2.43
# | 에폭 1 |  반복 3121 / 5619 | 시간 1064[s] | 손실 2.47
# | 에폭 1 |  반복 3141 / 5619 | 시간 1069[s] | 손실 2.44
# | 에폭 1 |  반복 3161 / 5619 | 시간 1073[s] | 손실 2.46
# | 에폭 1 |  반복 3181 / 5619 | 시간 1078[s] | 손실 2.43
# | 에폭 1 |  반복 3201 / 5619 | 시간 1082[s] | 손실 2.48
# | 에폭 1 |  반복 3221 / 5619 | 시간 1087[s] | 손실 2.45
# | 에폭 1 |  반복 3241 / 5619 | 시간 1091[s] | 손실 2.46
# | 에폭 1 |  반복 3261 / 5619 | 시간 1096[s] | 손실 2.45
# | 에폭 1 |  반복 3281 / 5619 | 시간 1101[s] | 손실 2.42
# | 에폭 1 |  반복 3301 / 5619 | 시간 1106[s] | 손실 2.45
# | 에폭 1 |  반복 3321 / 5619 | 시간 1110[s] | 손실 2.43
# | 에폭 1 |  반복 3341 / 5619 | 시간 1114[s] | 손실 2.42
# | 에폭 1 |  반복 3361 / 5619 | 시간 1119[s] | 손실 2.43
# | 에폭 1 |  반복 3381 / 5619 | 시간 1123[s] | 손실 2.45
# | 에폭 1 |  반복 3401 / 5619 | 시간 1127[s] | 손실 2.43
# | 에폭 1 |  반복 3421 / 5619 | 시간 1132[s] | 손실 2.43
# | 에폭 1 |  반복 3441 / 5619 | 시간 1137[s] | 손실 2.47
# | 에폭 1 |  반복 3461 / 5619 | 시간 1142[s] | 손실 2.47
# | 에폭 1 |  반복 3481 / 5619 | 시간 1146[s] | 손실 2.42
# | 에폭 1 |  반복 3501 / 5619 | 시간 1151[s] | 손실 2.40
# | 에폭 1 |  반복 3521 / 5619 | 시간 1155[s] | 손실 2.40
# | 에폭 1 |  반복 3541 / 5619 | 시간 1160[s] | 손실 2.42
# | 에폭 1 |  반복 3561 / 5619 | 시간 1164[s] | 손실 2.42
# | 에폭 1 |  반복 3581 / 5619 | 시간 1169[s] | 손실 2.43
# | 에폭 1 |  반복 3601 / 5619 | 시간 1173[s] | 손실 2.39
# | 에폭 1 |  반복 3621 / 5619 | 시간 1177[s] | 손실 2.44
# | 에폭 1 |  반복 3641 / 5619 | 시간 1181[s] | 손실 2.41
# | 에폭 1 |  반복 3661 / 5619 | 시간 1185[s] | 손실 2.43
# | 에폭 1 |  반복 3681 / 5619 | 시간 1189[s] | 손실 2.41
# | 에폭 1 |  반복 3701 / 5619 | 시간 1194[s] | 손실 2.45
# | 에폭 1 |  반복 3721 / 5619 | 시간 1198[s] | 손실 2.38
# | 에폭 1 |  반복 3741 / 5619 | 시간 1203[s] | 손실 2.42
# | 에폭 1 |  반복 3761 / 5619 | 시간 1207[s] | 손실 2.40
# | 에폭 1 |  반복 3781 / 5619 | 시간 1212[s] | 손실 2.39
# | 에폭 1 |  반복 3801 / 5619 | 시간 1217[s] | 손실 2.37
# | 에폭 1 |  반복 3821 / 5619 | 시간 1222[s] | 손실 2.40
# | 에폭 1 |  반복 3841 / 5619 | 시간 1227[s] | 손실 2.40
# | 에폭 1 |  반복 3861 / 5619 | 시간 1232[s] | 손실 2.40
# | 에폭 1 |  반복 3881 / 5619 | 시간 1236[s] | 손실 2.42
# | 에폭 1 |  반복 3901 / 5619 | 시간 1240[s] | 손실 2.36
# | 에폭 1 |  반복 3921 / 5619 | 시간 1243[s] | 손실 2.42
# | 에폭 1 |  반복 3941 / 5619 | 시간 1248[s] | 손실 2.39
# | 에폭 1 |  반복 3961 / 5619 | 시간 1252[s] | 손실 2.43
# | 에폭 1 |  반복 3981 / 5619 | 시간 1255[s] | 손실 2.42
# | 에폭 1 |  반복 4001 / 5619 | 시간 1259[s] | 손실 2.43
# | 에폭 1 |  반복 4021 / 5619 | 시간 1263[s] | 손실 2.42
# | 에폭 1 |  반복 4041 / 5619 | 시간 1267[s] | 손실 2.42
# | 에폭 1 |  반복 4061 / 5619 | 시간 1271[s] | 손실 2.40
# | 에폭 1 |  반복 4081 / 5619 | 시간 1275[s] | 손실 2.39
# | 에폭 1 |  반복 4101 / 5619 | 시간 1279[s] | 손실 2.44
# | 에폭 1 |  반복 4121 / 5619 | 시간 1282[s] | 손실 2.39
# | 에폭 1 |  반복 4141 / 5619 | 시간 1286[s] | 손실 2.42
# | 에폭 1 |  반복 4161 / 5619 | 시간 1290[s] | 손실 2.41
# | 에폭 1 |  반복 4181 / 5619 | 시간 1294[s] | 손실 2.42
# | 에폭 1 |  반복 4201 / 5619 | 시간 1297[s] | 손실 2.39
# | 에폭 1 |  반복 4221 / 5619 | 시간 1301[s] | 손실 2.41
# | 에폭 1 |  반복 4241 / 5619 | 시간 1304[s] | 손실 2.38
# | 에폭 1 |  반복 4261 / 5619 | 시간 1308[s] | 손실 2.36
# | 에폭 1 |  반복 4281 / 5619 | 시간 1312[s] | 손실 2.38
# | 에폭 1 |  반복 4301 / 5619 | 시간 1316[s] | 손실 2.42
# | 에폭 1 |  반복 4321 / 5619 | 시간 1321[s] | 손실 2.38
# | 에폭 1 |  반복 4341 / 5619 | 시간 1324[s] | 손실 2.38
# | 에폭 1 |  반복 4361 / 5619 | 시간 1328[s] | 손실 2.38
# | 에폭 1 |  반복 4381 / 5619 | 시간 1332[s] | 손실 2.37
# | 에폭 1 |  반복 4401 / 5619 | 시간 1336[s] | 손실 2.39
# | 에폭 1 |  반복 4421 / 5619 | 시간 1340[s] | 손실 2.38
# | 에폭 1 |  반복 4441 / 5619 | 시간 1344[s] | 손실 2.39
# | 에폭 1 |  반복 4461 / 5619 | 시간 1347[s] | 손실 2.39
# | 에폭 1 |  반복 4481 / 5619 | 시간 1351[s] | 손실 2.39
# | 에폭 1 |  반복 4501 / 5619 | 시간 1356[s] | 손실 2.38
# | 에폭 1 |  반복 4521 / 5619 | 시간 1360[s] | 손실 2.37
# | 에폭 1 |  반복 4541 / 5619 | 시간 1364[s] | 손실 2.39
# | 에폭 1 |  반복 4561 / 5619 | 시간 1367[s] | 손실 2.37
# | 에폭 1 |  반복 4581 / 5619 | 시간 1371[s] | 손실 2.35
# | 에폭 1 |  반복 4601 / 5619 | 시간 1375[s] | 손실 2.33
# | 에폭 1 |  반복 4621 / 5619 | 시간 1378[s] | 손실 2.40
# | 에폭 1 |  반복 4641 / 5619 | 시간 1382[s] | 손실 2.36
# | 에폭 1 |  반복 4661 / 5619 | 시간 1386[s] | 손실 2.38
# | 에폭 1 |  반복 4681 / 5619 | 시간 1391[s] | 손실 2.39
# | 에폭 1 |  반복 4701 / 5619 | 시간 1396[s] | 손실 2.38
# | 에폭 1 |  반복 4721 / 5619 | 시간 1401[s] | 손실 2.39
# | 에폭 1 |  반복 4741 / 5619 | 시간 1405[s] | 손실 2.39
# | 에폭 1 |  반복 4761 / 5619 | 시간 1409[s] | 손실 2.34
# | 에폭 1 |  반복 4781 / 5619 | 시간 1414[s] | 손실 2.35
# | 에폭 1 |  반복 4801 / 5619 | 시간 1418[s] | 손실 2.39
# | 에폭 1 |  반복 4821 / 5619 | 시간 1422[s] | 손실 2.39
# | 에폭 1 |  반복 4841 / 5619 | 시간 1427[s] | 손실 2.42
# | 에폭 1 |  반복 4861 / 5619 | 시간 1431[s] | 손실 2.39
# | 에폭 1 |  반복 4881 / 5619 | 시간 1435[s] | 손실 2.40
# | 에폭 1 |  반복 4901 / 5619 | 시간 1440[s] | 손실 2.38
# | 에폭 1 |  반복 4921 / 5619 | 시간 1445[s] | 손실 2.37
# | 에폭 1 |  반복 4941 / 5619 | 시간 1449[s] | 손실 2.35
# | 에폭 1 |  반복 4961 / 5619 | 시간 1454[s] | 손실 2.36
# | 에폭 1 |  반복 4981 / 5619 | 시간 1459[s] | 손실 2.39
# | 에폭 1 |  반복 5001 / 5619 | 시간 1464[s] | 손실 2.35
# | 에폭 1 |  반복 5021 / 5619 | 시간 1469[s] | 손실 2.34
# | 에폭 1 |  반복 5041 / 5619 | 시간 1473[s] | 손실 2.37
# | 에폭 1 |  반복 5061 / 5619 | 시간 1478[s] | 손실 2.33
# | 에폭 1 |  반복 5081 / 5619 | 시간 1483[s] | 손실 2.35
# | 에폭 1 |  반복 5101 / 5619 | 시간 1487[s] | 손실 2.38
# | 에폭 1 |  반복 5121 / 5619 | 시간 1492[s] | 손실 2.37
# | 에폭 1 |  반복 5141 / 5619 | 시간 1496[s] | 손실 2.36
# | 에폭 1 |  반복 5161 / 5619 | 시간 1500[s] | 손실 2.37
# | 에폭 1 |  반복 5181 / 5619 | 시간 1505[s] | 손실 2.36
# | 에폭 1 |  반복 5201 / 5619 | 시간 1510[s] | 손실 2.35
# | 에폭 1 |  반복 5221 / 5619 | 시간 1514[s] | 손실 2.33
# | 에폭 1 |  반복 5241 / 5619 | 시간 1519[s] | 손실 2.35
# | 에폭 1 |  반복 5261 / 5619 | 시간 1523[s] | 손실 2.35
# | 에폭 1 |  반복 5281 / 5619 | 시간 1528[s] | 손실 2.36
# | 에폭 1 |  반복 5301 / 5619 | 시간 1533[s] | 손실 2.35
# | 에폭 1 |  반복 5321 / 5619 | 시간 1537[s] | 손실 2.36
# | 에폭 1 |  반복 5341 / 5619 | 시간 1542[s] | 손실 2.36
# | 에폭 1 |  반복 5361 / 5619 | 시간 1546[s] | 손실 2.36
# | 에폭 1 |  반복 5381 / 5619 | 시간 1550[s] | 손실 2.36
# | 에폭 1 |  반복 5401 / 5619 | 시간 1555[s] | 손실 2.35
# | 에폭 1 |  반복 5421 / 5619 | 시간 1559[s] | 손실 2.36
# | 에폭 1 |  반복 5441 / 5619 | 시간 1563[s] | 손실 2.35
# | 에폭 1 |  반복 5461 / 5619 | 시간 1568[s] | 손실 2.35
# | 에폭 1 |  반복 5481 / 5619 | 시간 1572[s] | 손실 2.32
# | 에폭 1 |  반복 5501 / 5619 | 시간 1577[s] | 손실 2.32
# | 에폭 1 |  반복 5521 / 5619 | 시간 1581[s] | 손실 2.34
# | 에폭 1 |  반복 5541 / 5619 | 시간 1586[s] | 손실 2.34
# | 에폭 1 |  반복 5561 / 5619 | 시간 1590[s] | 손실 2.33
# | 에폭 1 |  반복 5581 / 5619 | 시간 1594[s] | 손실 2.35
# | 에폭 1 |  반복 5601 / 5619 | 시간 1599[s] | 손실 2.36
# | 에폭 2 |  반복 1 / 5619 | 시간 1603[s] | 손실 2.36
# | 에폭 2 |  반복 21 / 5619 | 시간 1607[s] | 손실 2.29
# | 에폭 2 |  반복 41 / 5619 | 시간 1612[s] | 손실 2.32
# | 에폭 2 |  반복 61 / 5619 | 시간 1616[s] | 손실 2.28
# | 에폭 2 |  반복 81 / 5619 | 시간 1620[s] | 손실 2.28
# | 에폭 2 |  반복 101 / 5619 | 시간 1624[s] | 손실 2.32
# | 에폭 2 |  반복 121 / 5619 | 시간 1628[s] | 손실 2.32
# | 에폭 2 |  반복 141 / 5619 | 시간 1633[s] | 손실 2.31
# | 에폭 2 |  반복 161 / 5619 | 시간 1637[s] | 손실 2.29
# | 에폭 2 |  반복 181 / 5619 | 시간 1641[s] | 손실 2.32
# | 에폭 2 |  반복 201 / 5619 | 시간 1646[s] | 손실 2.30
# | 에폭 2 |  반복 221 / 5619 | 시간 1650[s] | 손실 2.31
# | 에폭 2 |  반복 241 / 5619 | 시간 1654[s] | 손실 2.31
# | 에폭 2 |  반복 261 / 5619 | 시간 1658[s] | 손실 2.26
# | 에폭 2 |  반복 281 / 5619 | 시간 1663[s] | 손실 2.28
# | 에폭 2 |  반복 301 / 5619 | 시간 1667[s] | 손실 2.29
# | 에폭 2 |  반복 321 / 5619 | 시간 1671[s] | 손실 2.32
# | 에폭 2 |  반복 341 / 5619 | 시간 1675[s] | 손실 2.31
# | 에폭 2 |  반복 361 / 5619 | 시간 1680[s] | 손실 2.31
# | 에폭 2 |  반복 381 / 5619 | 시간 1684[s] | 손실 2.29
# | 에폭 2 |  반복 401 / 5619 | 시간 1688[s] | 손실 2.26
# | 에폭 2 |  반복 421 / 5619 | 시간 1693[s] | 손실 2.35
# | 에폭 2 |  반복 441 / 5619 | 시간 1697[s] | 손실 2.30
# | 에폭 2 |  반복 461 / 5619 | 시간 1701[s] | 손실 2.30
# | 에폭 2 |  반복 481 / 5619 | 시간 1706[s] | 손실 2.30
# | 에폭 2 |  반복 501 / 5619 | 시간 1710[s] | 손실 2.29
# | 에폭 2 |  반복 521 / 5619 | 시간 1714[s] | 손실 2.29
# | 에폭 2 |  반복 541 / 5619 | 시간 1718[s] | 손실 2.27
# | 에폭 2 |  반복 561 / 5619 | 시간 1723[s] | 손실 2.27
# | 에폭 2 |  반복 581 / 5619 | 시간 1727[s] | 손실 2.31
# | 에폭 2 |  반복 601 / 5619 | 시간 1731[s] | 손실 2.30
# | 에폭 2 |  반복 621 / 5619 | 시간 1735[s] | 손실 2.28
# | 에폭 2 |  반복 641 / 5619 | 시간 1740[s] | 손실 2.30
# | 에폭 2 |  반복 661 / 5619 | 시간 1744[s] | 손실 2.29
# | 에폭 2 |  반복 681 / 5619 | 시간 1748[s] | 손실 2.28
# | 에폭 2 |  반복 701 / 5619 | 시간 1752[s] | 손실 2.31
# | 에폭 2 |  반복 721 / 5619 | 시간 1757[s] | 손실 2.27
# | 에폭 2 |  반복 741 / 5619 | 시간 1761[s] | 손실 2.25
# | 에폭 2 |  반복 761 / 5619 | 시간 1765[s] | 손실 2.26
# | 에폭 2 |  반복 781 / 5619 | 시간 1770[s] | 손실 2.29
# | 에폭 2 |  반복 801 / 5619 | 시간 1774[s] | 손실 2.29
# | 에폭 2 |  반복 821 / 5619 | 시간 1778[s] | 손실 2.29
# | 에폭 2 |  반복 841 / 5619 | 시간 1783[s] | 손실 2.28
# | 에폭 2 |  반복 861 / 5619 | 시간 1787[s] | 손실 2.30
# | 에폭 2 |  반복 881 / 5619 | 시간 1791[s] | 손실 2.29
# | 에폭 2 |  반복 901 / 5619 | 시간 1796[s] | 손실 2.29
# | 에폭 2 |  반복 921 / 5619 | 시간 1800[s] | 손실 2.30
# | 에폭 2 |  반복 941 / 5619 | 시간 1804[s] | 손실 2.25
# | 에폭 2 |  반복 961 / 5619 | 시간 1808[s] | 손실 2.28
# | 에폭 2 |  반복 981 / 5619 | 시간 1813[s] | 손실 2.31
# | 에폭 2 |  반복 1001 / 5619 | 시간 1817[s] | 손실 2.27
# | 에폭 2 |  반복 1021 / 5619 | 시간 1821[s] | 손실 2.28
# | 에폭 2 |  반복 1041 / 5619 | 시간 1825[s] | 손실 2.29
# | 에폭 2 |  반복 1061 / 5619 | 시간 1830[s] | 손실 2.29
# | 에폭 2 |  반복 1081 / 5619 | 시간 1834[s] | 손실 2.28
# | 에폭 2 |  반복 1101 / 5619 | 시간 1839[s] | 손실 2.25
# | 에폭 2 |  반복 1121 / 5619 | 시간 1843[s] | 손실 2.31
# | 에폭 2 |  반복 1141 / 5619 | 시간 1848[s] | 손실 2.29
# | 에폭 2 |  반복 1161 / 5619 | 시간 1852[s] | 손실 2.27
# | 에폭 2 |  반복 1181 / 5619 | 시간 1857[s] | 손실 2.30
# | 에폭 2 |  반복 1201 / 5619 | 시간 1861[s] | 손실 2.29
# | 에폭 2 |  반복 1221 / 5619 | 시간 1865[s] | 손실 2.27
# | 에폭 2 |  반복 1241 / 5619 | 시간 1869[s] | 손실 2.26
# | 에폭 2 |  반복 1261 / 5619 | 시간 1874[s] | 손실 2.26
# | 에폭 2 |  반복 1281 / 5619 | 시간 1878[s] | 손실 2.26
# | 에폭 2 |  반복 1301 / 5619 | 시간 1882[s] | 손실 2.25
# | 에폭 2 |  반복 1321 / 5619 | 시간 1887[s] | 손실 2.27
# | 에폭 2 |  반복 1341 / 5619 | 시간 1891[s] | 손실 2.28
# | 에폭 2 |  반복 1361 / 5619 | 시간 1895[s] | 손실 2.29
# | 에폭 2 |  반복 1381 / 5619 | 시간 1900[s] | 손실 2.27
# | 에폭 2 |  반복 1401 / 5619 | 시간 1904[s] | 손실 2.27
# | 에폭 2 |  반복 1421 / 5619 | 시간 1908[s] | 손실 2.27
# | 에폭 2 |  반복 1441 / 5619 | 시간 1912[s] | 손실 2.27
# | 에폭 2 |  반복 1461 / 5619 | 시간 1917[s] | 손실 2.26
# | 에폭 2 |  반복 1481 / 5619 | 시간 1921[s] | 손실 2.27
# | 에폭 2 |  반복 1501 / 5619 | 시간 1925[s] | 손실 2.28
# | 에폭 2 |  반복 1521 / 5619 | 시간 1929[s] | 손실 2.27
# | 에폭 2 |  반복 1541 / 5619 | 시간 1934[s] | 손실 2.27
# | 에폭 2 |  반복 1561 / 5619 | 시간 1938[s] | 손실 2.28
# | 에폭 2 |  반복 1581 / 5619 | 시간 1942[s] | 손실 2.28
# | 에폭 2 |  반복 1601 / 5619 | 시간 1947[s] | 손실 2.24
# | 에폭 2 |  반복 1621 / 5619 | 시간 1951[s] | 손실 2.26
# | 에폭 2 |  반복 1641 / 5619 | 시간 1955[s] | 손실 2.29
# | 에폭 2 |  반복 1661 / 5619 | 시간 1960[s] | 손실 2.28
# | 에폭 2 |  반복 1681 / 5619 | 시간 1964[s] | 손실 2.30
# | 에폭 2 |  반복 1701 / 5619 | 시간 1968[s] | 손실 2.25
# | 에폭 2 |  반복 1721 / 5619 | 시간 1972[s] | 손실 2.24
# | 에폭 2 |  반복 1741 / 5619 | 시간 1977[s] | 손실 2.25
# | 에폭 2 |  반복 1761 / 5619 | 시간 1981[s] | 손실 2.26
# | 에폭 2 |  반복 1781 / 5619 | 시간 1985[s] | 손실 2.26
# | 에폭 2 |  반복 1801 / 5619 | 시간 1990[s] | 손실 2.25
# | 에폭 2 |  반복 1821 / 5619 | 시간 1994[s] | 손실 2.27
# | 에폭 2 |  반복 1841 / 5619 | 시간 1998[s] | 손실 2.27
# | 에폭 2 |  반복 1861 / 5619 | 시간 2002[s] | 손실 2.23
# | 에폭 2 |  반복 1881 / 5619 | 시간 2007[s] | 손실 2.25
# | 에폭 2 |  반복 1901 / 5619 | 시간 2011[s] | 손실 2.24
# | 에폭 2 |  반복 1921 / 5619 | 시간 2015[s] | 손실 2.26
# | 에폭 2 |  반복 1941 / 5619 | 시간 2020[s] | 손실 2.24
# | 에폭 2 |  반복 1961 / 5619 | 시간 2024[s] | 손실 2.24
# | 에폭 2 |  반복 1981 / 5619 | 시간 2029[s] | 손실 2.23
# | 에폭 2 |  반복 2001 / 5619 | 시간 2033[s] | 손실 2.26
# | 에폭 2 |  반복 2021 / 5619 | 시간 2038[s] | 손실 2.28
# | 에폭 2 |  반복 2041 / 5619 | 시간 2042[s] | 손실 2.26
# | 에폭 2 |  반복 2061 / 5619 | 시간 2046[s] | 손실 2.25
# | 에폭 2 |  반복 2081 / 5619 | 시간 2051[s] | 손실 2.28
# | 에폭 2 |  반복 2101 / 5619 | 시간 2055[s] | 손실 2.24
# | 에폭 2 |  반복 2121 / 5619 | 시간 2059[s] | 손실 2.23
# | 에폭 2 |  반복 2141 / 5619 | 시간 2064[s] | 손실 2.25
# | 에폭 2 |  반복 2161 / 5619 | 시간 2068[s] | 손실 2.23
# | 에폭 2 |  반복 2181 / 5619 | 시간 2072[s] | 손실 2.21
# | 에폭 2 |  반복 2201 / 5619 | 시간 2077[s] | 손실 2.24
# | 에폭 2 |  반복 2221 / 5619 | 시간 2081[s] | 손실 2.27
# | 에폭 2 |  반복 2241 / 5619 | 시간 2086[s] | 손실 2.27
# | 에폭 2 |  반복 2261 / 5619 | 시간 2090[s] | 손실 2.27
# | 에폭 2 |  반복 2281 / 5619 | 시간 2094[s] | 손실 2.24
# | 에폭 2 |  반복 2301 / 5619 | 시간 2099[s] | 손실 2.26
# | 에폭 2 |  반복 2321 / 5619 | 시간 2103[s] | 손실 2.24
# | 에폭 2 |  반복 2341 / 5619 | 시간 2108[s] | 손실 2.26
# | 에폭 2 |  반복 2361 / 5619 | 시간 2112[s] | 손실 2.22
# | 에폭 2 |  반복 2381 / 5619 | 시간 2117[s] | 손실 2.24
# | 에폭 2 |  반복 2401 / 5619 | 시간 2121[s] | 손실 2.26
# | 에폭 2 |  반복 2421 / 5619 | 시간 2126[s] | 손실 2.23
# | 에폭 2 |  반복 2441 / 5619 | 시간 2130[s] | 손실 2.24
# | 에폭 2 |  반복 2461 / 5619 | 시간 2134[s] | 손실 2.23
# | 에폭 2 |  반복 2481 / 5619 | 시간 2139[s] | 손실 2.25
# | 에폭 2 |  반복 2501 / 5619 | 시간 2143[s] | 손실 2.22
# | 에폭 2 |  반복 2521 / 5619 | 시간 2148[s] | 손실 2.23
# | 에폭 2 |  반복 2541 / 5619 | 시간 2152[s] | 손실 2.22
# | 에폭 2 |  반복 2561 / 5619 | 시간 2156[s] | 손실 2.24
# | 에폭 2 |  반복 2581 / 5619 | 시간 2161[s] | 손실 2.24
# | 에폭 2 |  반복 2601 / 5619 | 시간 2165[s] | 손실 2.24
# | 에폭 2 |  반복 2621 / 5619 | 시간 2169[s] | 손실 2.23
# | 에폭 2 |  반복 2641 / 5619 | 시간 2174[s] | 손실 2.22
# | 에폭 2 |  반복 2661 / 5619 | 시간 2178[s] | 손실 2.23
# | 에폭 2 |  반복 2681 / 5619 | 시간 2182[s] | 손실 2.25
# | 에폭 2 |  반복 2701 / 5619 | 시간 2187[s] | 손실 2.21
# | 에폭 2 |  반복 2721 / 5619 | 시간 2191[s] | 손실 2.21
# | 에폭 2 |  반복 2741 / 5619 | 시간 2195[s] | 손실 2.23
# | 에폭 2 |  반복 2761 / 5619 | 시간 2200[s] | 손실 2.20
# | 에폭 2 |  반복 2781 / 5619 | 시간 2204[s] | 손실 2.24
# | 에폭 2 |  반복 2801 / 5619 | 시간 2208[s] | 손실 2.23
# | 에폭 2 |  반복 2821 / 5619 | 시간 2213[s] | 손실 2.22
# | 에폭 2 |  반복 2841 / 5619 | 시간 2217[s] | 손실 2.22
# | 에폭 2 |  반복 2861 / 5619 | 시간 2221[s] | 손실 2.23
# | 에폭 2 |  반복 2881 / 5619 | 시간 2225[s] | 손실 2.24
# | 에폭 2 |  반복 2901 / 5619 | 시간 2230[s] | 손실 2.19
# | 에폭 2 |  반복 2921 / 5619 | 시간 2234[s] | 손실 2.22
# | 에폭 2 |  반복 2941 / 5619 | 시간 2239[s] | 손실 2.23
# | 에폭 2 |  반복 2961 / 5619 | 시간 2243[s] | 손실 2.21
# | 에폭 2 |  반복 2981 / 5619 | 시간 2247[s] | 손실 2.22
# | 에폭 2 |  반복 3001 / 5619 | 시간 2252[s] | 손실 2.26
# | 에폭 2 |  반복 3021 / 5619 | 시간 2256[s] | 손실 2.22
# | 에폭 2 |  반복 3041 / 5619 | 시간 2260[s] | 손실 2.21
# | 에폭 2 |  반복 3061 / 5619 | 시간 2264[s] | 손실 2.25
# | 에폭 2 |  반복 3081 / 5619 | 시간 2269[s] | 손실 2.20
# | 에폭 2 |  반복 3101 / 5619 | 시간 2273[s] | 손실 2.21
# | 에폭 2 |  반복 3121 / 5619 | 시간 2277[s] | 손실 2.19
# | 에폭 2 |  반복 3141 / 5619 | 시간 2282[s] | 손실 2.21
# | 에폭 2 |  반복 3161 / 5619 | 시간 2286[s] | 손실 2.22
# | 에폭 2 |  반복 3181 / 5619 | 시간 2290[s] | 손실 2.21
# | 에폭 2 |  반복 3201 / 5619 | 시간 2294[s] | 손실 2.22
# | 에폭 2 |  반복 3221 / 5619 | 시간 2299[s] | 손실 2.22
# | 에폭 2 |  반복 3241 / 5619 | 시간 2303[s] | 손실 2.23
# | 에폭 2 |  반복 3261 / 5619 | 시간 2307[s] | 손실 2.22
# | 에폭 2 |  반복 3281 / 5619 | 시간 2311[s] | 손실 2.21
# | 에폭 2 |  반복 3301 / 5619 | 시간 2316[s] | 손실 2.20
# | 에폭 2 |  반복 3321 / 5619 | 시간 2320[s] | 손실 2.18
# | 에폭 2 |  반복 3341 / 5619 | 시간 2324[s] | 손실 2.24
# | 에폭 2 |  반복 3361 / 5619 | 시간 2328[s] | 손실 2.18
# | 에폭 2 |  반복 3381 / 5619 | 시간 2333[s] | 손실 2.24
# | 에폭 2 |  반복 3401 / 5619 | 시간 2337[s] | 손실 2.20
# | 에폭 2 |  반복 3421 / 5619 | 시간 2341[s] | 손실 2.21
# | 에폭 2 |  반복 3441 / 5619 | 시간 2345[s] | 손실 2.23
# | 에폭 2 |  반복 3461 / 5619 | 시간 2350[s] | 손실 2.15
# | 에폭 2 |  반복 3481 / 5619 | 시간 2354[s] | 손실 2.21
# | 에폭 2 |  반복 3501 / 5619 | 시간 2358[s] | 손실 2.21
# | 에폭 2 |  반복 3521 / 5619 | 시간 2363[s] | 손실 2.22
# | 에폭 2 |  반복 3541 / 5619 | 시간 2367[s] | 손실 2.22
# | 에폭 2 |  반복 3561 / 5619 | 시간 2372[s] | 손실 2.20
# | 에폭 2 |  반복 3581 / 5619 | 시간 2376[s] | 손실 2.21
# | 에폭 2 |  반복 3601 / 5619 | 시간 2380[s] | 손실 2.18
# | 에폭 2 |  반복 3621 / 5619 | 시간 2384[s] | 손실 2.19
# | 에폭 2 |  반복 3641 / 5619 | 시간 2389[s] | 손실 2.19
# | 에폭 2 |  반복 3661 / 5619 | 시간 2393[s] | 손실 2.20
# | 에폭 2 |  반복 3681 / 5619 | 시간 2397[s] | 손실 2.18
# | 에폭 2 |  반복 3701 / 5619 | 시간 2402[s] | 손실 2.19
# | 에폭 2 |  반복 3721 / 5619 | 시간 2406[s] | 손실 2.18
# | 에폭 2 |  반복 3741 / 5619 | 시간 2410[s] | 손실 2.22
# | 에폭 2 |  반복 3761 / 5619 | 시간 2414[s] | 손실 2.22
# | 에폭 2 |  반복 3781 / 5619 | 시간 2419[s] | 손실 2.20
# | 에폭 2 |  반복 3801 / 5619 | 시간 2423[s] | 손실 2.19
# | 에폭 2 |  반복 3821 / 5619 | 시간 2427[s] | 손실 2.17
# | 에폭 2 |  반복 3841 / 5619 | 시간 2432[s] | 손실 2.21
# | 에폭 2 |  반복 3861 / 5619 | 시간 2436[s] | 손실 2.17
# | 에폭 2 |  반복 3881 / 5619 | 시간 2440[s] | 손실 2.15
# | 에폭 2 |  반복 3901 / 5619 | 시간 2444[s] | 손실 2.16
# | 에폭 2 |  반복 3921 / 5619 | 시간 2449[s] | 손실 2.21
# | 에폭 2 |  반복 3941 / 5619 | 시간 2453[s] | 손실 2.21
# | 에폭 2 |  반복 3961 / 5619 | 시간 2457[s] | 손실 2.19
# | 에폭 2 |  반복 3981 / 5619 | 시간 2461[s] | 손실 2.18
# | 에폭 2 |  반복 4001 / 5619 | 시간 2465[s] | 손실 2.19
# | 에폭 2 |  반복 4021 / 5619 | 시간 2470[s] | 손실 2.17
# | 에폭 2 |  반복 4041 / 5619 | 시간 2474[s] | 손실 2.17
# | 에폭 2 |  반복 4061 / 5619 | 시간 2478[s] | 손실 2.19
# | 에폭 2 |  반복 4081 / 5619 | 시간 2482[s] | 손실 2.21
# | 에폭 2 |  반복 4101 / 5619 | 시간 2487[s] | 손실 2.20
# | 에폭 2 |  반복 4121 / 5619 | 시간 2491[s] | 손실 2.19
# | 에폭 2 |  반복 4141 / 5619 | 시간 2495[s] | 손실 2.21
# | 에폭 2 |  반복 4161 / 5619 | 시간 2499[s] | 손실 2.21
# | 에폭 2 |  반복 4181 / 5619 | 시간 2504[s] | 손실 2.18
# | 에폭 2 |  반복 4201 / 5619 | 시간 2508[s] | 손실 2.17
# | 에폭 2 |  반복 4221 / 5619 | 시간 2512[s] | 손실 2.16
# | 에폭 2 |  반복 4241 / 5619 | 시간 2516[s] | 손실 2.17
# | 에폭 2 |  반복 4261 / 5619 | 시간 2520[s] | 손실 2.21
# | 에폭 2 |  반복 4281 / 5619 | 시간 2525[s] | 손실 2.16
# | 에폭 2 |  반복 4301 / 5619 | 시간 2529[s] | 손실 2.18
# | 에폭 2 |  반복 4321 / 5619 | 시간 2533[s] | 손실 2.18
# | 에폭 2 |  반복 4341 / 5619 | 시간 2537[s] | 손실 2.20
# | 에폭 2 |  반복 4361 / 5619 | 시간 2542[s] | 손실 2.17
# | 에폭 2 |  반복 4381 / 5619 | 시간 2546[s] | 손실 2.18
# | 에폭 2 |  반복 4401 / 5619 | 시간 2550[s] | 손실 2.18
# | 에폭 2 |  반복 4421 / 5619 | 시간 2554[s] | 손실 2.18
# | 에폭 2 |  반복 4441 / 5619 | 시간 2559[s] | 손실 2.18
# | 에폭 2 |  반복 4461 / 5619 | 시간 2563[s] | 손실 2.19
# | 에폭 2 |  반복 4481 / 5619 | 시간 2567[s] | 손실 2.17
# | 에폭 2 |  반복 4501 / 5619 | 시간 2572[s] | 손실 2.21
# | 에폭 2 |  반복 4521 / 5619 | 시간 2576[s] | 손실 2.17
# | 에폭 2 |  반복 4541 / 5619 | 시간 2580[s] | 손실 2.19
# | 에폭 2 |  반복 4561 / 5619 | 시간 2584[s] | 손실 2.17
# | 에폭 2 |  반복 4581 / 5619 | 시간 2589[s] | 손실 2.18
# | 에폭 2 |  반복 4601 / 5619 | 시간 2593[s] | 손실 2.13
# | 에폭 2 |  반복 4621 / 5619 | 시간 2597[s] | 손실 2.17
# | 에폭 2 |  반복 4641 / 5619 | 시간 2602[s] | 손실 2.18
# | 에폭 2 |  반복 4661 / 5619 | 시간 2606[s] | 손실 2.16
# | 에폭 2 |  반복 4681 / 5619 | 시간 2610[s] | 손실 2.17
# | 에폭 2 |  반복 4701 / 5619 | 시간 2614[s] | 손실 2.14
# | 에폭 2 |  반복 4721 / 5619 | 시간 2618[s] | 손실 2.18
# | 에폭 2 |  반복 4741 / 5619 | 시간 2623[s] | 손실 2.17
# | 에폭 2 |  반복 4761 / 5619 | 시간 2627[s] | 손실 2.15
# | 에폭 2 |  반복 4781 / 5619 | 시간 2631[s] | 손실 2.18
# | 에폭 2 |  반복 4801 / 5619 | 시간 2636[s] | 손실 2.12
# | 에폭 2 |  반복 4821 / 5619 | 시간 2640[s] | 손실 2.17
# | 에폭 2 |  반복 4841 / 5619 | 시간 2644[s] | 손실 2.16
# | 에폭 2 |  반복 4861 / 5619 | 시간 2648[s] | 손실 2.18
# | 에폭 2 |  반복 4881 / 5619 | 시간 2652[s] | 손실 2.16
# | 에폭 2 |  반복 4901 / 5619 | 시간 2657[s] | 손실 2.15
# | 에폭 2 |  반복 4921 / 5619 | 시간 2661[s] | 손실 2.14
# | 에폭 2 |  반복 4941 / 5619 | 시간 2665[s] | 손실 2.16
# | 에폭 2 |  반복 4961 / 5619 | 시간 2670[s] | 손실 2.13
# | 에폭 2 |  반복 4981 / 5619 | 시간 2674[s] | 손실 2.13
# | 에폭 2 |  반복 5001 / 5619 | 시간 2679[s] | 손실 2.15
# | 에폭 2 |  반복 5021 / 5619 | 시간 2683[s] | 손실 2.16
# | 에폭 2 |  반복 5041 / 5619 | 시간 2687[s] | 손실 2.16
# | 에폭 2 |  반복 5061 / 5619 | 시간 2691[s] | 손실 2.16
# | 에폭 2 |  반복 5081 / 5619 | 시간 2695[s] | 손실 2.17
# | 에폭 2 |  반복 5101 / 5619 | 시간 2700[s] | 손실 2.17
# | 에폭 2 |  반복 5121 / 5619 | 시간 2704[s] | 손실 2.15
# | 에폭 2 |  반복 5141 / 5619 | 시간 2708[s] | 손실 2.17
# | 에폭 2 |  반복 5161 / 5619 | 시간 2713[s] | 손실 2.18
# | 에폭 2 |  반복 5181 / 5619 | 시간 2717[s] | 손실 2.15
# | 에폭 2 |  반복 5201 / 5619 | 시간 2721[s] | 손실 2.15
# | 에폭 2 |  반복 5221 / 5619 | 시간 2726[s] | 손실 2.18
# | 에폭 2 |  반복 5241 / 5619 | 시간 2730[s] | 손실 2.16
# | 에폭 2 |  반복 5261 / 5619 | 시간 2734[s] | 손실 2.15
# | 에폭 2 |  반복 5281 / 5619 | 시간 2739[s] | 손실 2.17
# | 에폭 2 |  반복 5301 / 5619 | 시간 2744[s] | 손실 2.16
# | 에폭 2 |  반복 5321 / 5619 | 시간 2748[s] | 손실 2.14
# | 에폭 2 |  반복 5341 / 5619 | 시간 2943[s] | 손실 2.15
# | 에폭 2 |  반복 5361 / 5619 | 시간 2949[s] | 손실 2.17
# | 에폭 2 |  반복 5381 / 5619 | 시간 2955[s] | 손실 2.16
# | 에폭 2 |  반복 5401 / 5619 | 시간 2961[s] | 손실 2.16
# | 에폭 2 |  반복 5421 / 5619 | 시간 2965[s] | 손실 2.11
# | 에폭 2 |  반복 5441 / 5619 | 시간 2970[s] | 손실 2.18
# | 에폭 2 |  반복 5461 / 5619 | 시간 2975[s] | 손실 2.13
# | 에폭 2 |  반복 5481 / 5619 | 시간 2979[s] | 손실 2.12
# | 에폭 2 |  반복 5501 / 5619 | 시간 2984[s] | 손실 2.17
# | 에폭 2 |  반복 5521 / 5619 | 시간 2989[s] | 손실 2.15
# | 에폭 2 |  반복 5541 / 5619 | 시간 2994[s] | 손실 2.17
# | 에폭 2 |  반복 5561 / 5619 | 시간 2998[s] | 손실 2.15
# | 에폭 2 |  반복 5581 / 5619 | 시간 3004[s] | 손실 2.11
# | 에폭 2 |  반복 5601 / 5619 | 시간 3008[s] | 손실 2.12
# | 에폭 3 |  반복 1 / 5619 | 시간 3013[s] | 손실 2.13
# | 에폭 3 |  반복 21 / 5619 | 시간 3017[s] | 손실 2.09
# | 에폭 3 |  반복 41 / 5619 | 시간 3022[s] | 손실 2.13
# | 에폭 3 |  반복 61 / 5619 | 시간 3027[s] | 손실 2.10
# | 에폭 3 |  반복 81 / 5619 | 시간 3031[s] | 손실 2.06
# | 에폭 3 |  반복 101 / 5619 | 시간 3036[s] | 손실 2.06
# | 에폭 3 |  반복 121 / 5619 | 시간 3041[s] | 손실 2.08
# | 에폭 3 |  반복 141 / 5619 | 시간 3045[s] | 손실 2.12
# | 에폭 3 |  반복 161 / 5619 | 시간 3050[s] | 손실 2.09
# | 에폭 3 |  반복 181 / 5619 | 시간 3054[s] | 손실 2.09
# | 에폭 3 |  반복 201 / 5619 | 시간 3059[s] | 손실 2.09
# | 에폭 3 |  반복 221 / 5619 | 시간 3064[s] | 손실 2.08
# | 에폭 3 |  반복 241 / 5619 | 시간 3068[s] | 손실 2.10
# | 에폭 3 |  반복 261 / 5619 | 시간 3072[s] | 손실 2.09
# | 에폭 3 |  반복 281 / 5619 | 시간 3077[s] | 손실 2.09
# | 에폭 3 |  반복 301 / 5619 | 시간 3081[s] | 손실 2.12
# | 에폭 3 |  반복 321 / 5619 | 시간 3086[s] | 손실 2.11
# | 에폭 3 |  반복 341 / 5619 | 시간 3091[s] | 손실 2.03
# | 에폭 3 |  반복 361 / 5619 | 시간 3095[s] | 손실 2.12
# | 에폭 3 |  반복 381 / 5619 | 시간 3100[s] | 손실 2.10
# | 에폭 3 |  반복 401 / 5619 | 시간 3104[s] | 손실 2.07
# | 에폭 3 |  반복 421 / 5619 | 시간 3108[s] | 손실 2.08
# | 에폭 3 |  반복 441 / 5619 | 시간 3113[s] | 손실 2.11
# | 에폭 3 |  반복 461 / 5619 | 시간 3117[s] | 손실 2.14
# | 에폭 3 |  반복 481 / 5619 | 시간 3121[s] | 손실 2.05
# | 에폭 3 |  반복 501 / 5619 | 시간 3126[s] | 손실 2.04
# | 에폭 3 |  반복 521 / 5619 | 시간 3130[s] | 손실 2.11
# | 에폭 3 |  반복 541 / 5619 | 시간 3135[s] | 손실 2.08
# | 에폭 3 |  반복 561 / 5619 | 시간 3139[s] | 손실 2.07
# | 에폭 3 |  반복 581 / 5619 | 시간 3144[s] | 손실 2.09
# | 에폭 3 |  반복 601 / 5619 | 시간 3148[s] | 손실 2.07
# | 에폭 3 |  반복 621 / 5619 | 시간 3152[s] | 손실 2.08
# | 에폭 3 |  반복 641 / 5619 | 시간 3157[s] | 손실 2.07
# | 에폭 3 |  반복 661 / 5619 | 시간 3161[s] | 손실 2.10
# | 에폭 3 |  반복 681 / 5619 | 시간 3166[s] | 손실 2.06
# | 에폭 3 |  반복 701 / 5619 | 시간 3170[s] | 손실 2.07
# | 에폭 3 |  반복 721 / 5619 | 시간 3175[s] | 손실 2.07
# | 에폭 3 |  반복 741 / 5619 | 시간 3179[s] | 손실 2.13
# | 에폭 3 |  반복 761 / 5619 | 시간 3184[s] | 손실 2.05
# | 에폭 3 |  반복 781 / 5619 | 시간 3188[s] | 손실 2.10
# | 에폭 3 |  반복 801 / 5619 | 시간 3192[s] | 손실 2.06
# | 에폭 3 |  반복 821 / 5619 | 시간 3197[s] | 손실 2.06
# | 에폭 3 |  반복 841 / 5619 | 시간 3201[s] | 손실 2.07
# | 에폭 3 |  반복 861 / 5619 | 시간 3206[s] | 손실 2.09
# | 에폭 3 |  반복 881 / 5619 | 시간 3210[s] | 손실 2.05
# | 에폭 3 |  반복 901 / 5619 | 시간 3215[s] | 손실 2.08
# | 에폭 3 |  반복 921 / 5619 | 시간 3220[s] | 손실 2.09
# | 에폭 3 |  반복 941 / 5619 | 시간 3225[s] | 손실 2.08
# | 에폭 3 |  반복 961 / 5619 | 시간 3229[s] | 손실 2.05
# | 에폭 3 |  반복 981 / 5619 | 시간 3234[s] | 손실 2.07
# | 에폭 3 |  반복 1001 / 5619 | 시간 3238[s] | 손실 2.08
# | 에폭 3 |  반복 1021 / 5619 | 시간 3243[s] | 손실 2.06
# | 에폭 3 |  반복 1041 / 5619 | 시간 3248[s] | 손실 2.11
# | 에폭 3 |  반복 1061 / 5619 | 시간 3252[s] | 손실 2.14
# | 에폭 3 |  반복 1081 / 5619 | 시간 3257[s] | 손실 2.09
# | 에폭 3 |  반복 1101 / 5619 | 시간 3261[s] | 손실 2.06
# | 에폭 3 |  반복 1121 / 5619 | 시간 3266[s] | 손실 2.05
# | 에폭 3 |  반복 1141 / 5619 | 시간 3270[s] | 손실 2.08
# | 에폭 3 |  반복 1161 / 5619 | 시간 3274[s] | 손실 2.06
# | 에폭 3 |  반복 1181 / 5619 | 시간 3279[s] | 손실 2.03
# | 에폭 3 |  반복 1201 / 5619 | 시간 3283[s] | 손실 2.09
# | 에폭 3 |  반복 1221 / 5619 | 시간 3288[s] | 손실 2.12
# | 에폭 3 |  반복 1241 / 5619 | 시간 3292[s] | 손실 2.07
# | 에폭 3 |  반복 1261 / 5619 | 시간 3296[s] | 손실 2.08
# | 에폭 3 |  반복 1281 / 5619 | 시간 3301[s] | 손실 2.06
# | 에폭 3 |  반복 1301 / 5619 | 시간 3305[s] | 손실 2.07
# | 에폭 3 |  반복 1321 / 5619 | 시간 3310[s] | 손실 2.05
# | 에폭 3 |  반복 1341 / 5619 | 시간 3314[s] | 손실 2.09
# | 에폭 3 |  반복 1361 / 5619 | 시간 3318[s] | 손실 2.07
# | 에폭 3 |  반복 1381 / 5619 | 시간 3323[s] | 손실 2.04
# | 에폭 3 |  반복 1401 / 5619 | 시간 3327[s] | 손실 2.05
# | 에폭 3 |  반복 1421 / 5619 | 시간 3332[s] | 손실 2.03
# | 에폭 3 |  반복 1441 / 5619 | 시간 3336[s] | 손실 2.07
# | 에폭 3 |  반복 1461 / 5619 | 시간 3340[s] | 손실 2.08
# | 에폭 3 |  반복 1481 / 5619 | 시간 3343[s] | 손실 2.09
# | 에폭 3 |  반복 1501 / 5619 | 시간 3347[s] | 손실 2.05
# | 에폭 3 |  반복 1521 / 5619 | 시간 3352[s] | 손실 2.09
# | 에폭 3 |  반복 1541 / 5619 | 시간 3356[s] | 손실 2.09
# | 에폭 3 |  반복 1561 / 5619 | 시간 3359[s] | 손실 2.08
# | 에폭 3 |  반복 1581 / 5619 | 시간 3363[s] | 손실 2.06
# | 에폭 3 |  반복 1601 / 5619 | 시간 3367[s] | 손실 2.02
# | 에폭 3 |  반복 1621 / 5619 | 시간 3371[s] | 손실 2.08
# | 에폭 3 |  반복 1641 / 5619 | 시간 3375[s] | 손실 2.08
# | 에폭 3 |  반복 1661 / 5619 | 시간 3379[s] | 손실 2.07
# | 에폭 3 |  반복 1681 / 5619 | 시간 3382[s] | 손실 2.05
# | 에폭 3 |  반복 1701 / 5619 | 시간 3386[s] | 손실 2.07
# | 에폭 3 |  반복 1721 / 5619 | 시간 3390[s] | 손실 2.06
# | 에폭 3 |  반복 1741 / 5619 | 시간 3393[s] | 손실 2.05
# | 에폭 3 |  반복 1761 / 5619 | 시간 3397[s] | 손실 2.05
# | 에폭 3 |  반복 1781 / 5619 | 시간 3400[s] | 손실 2.05
# | 에폭 3 |  반복 1801 / 5619 | 시간 3404[s] | 손실 2.08
# | 에폭 3 |  반복 1821 / 5619 | 시간 3407[s] | 손실 2.03
# | 에폭 3 |  반복 1841 / 5619 | 시간 3411[s] | 손실 2.05
# | 에폭 3 |  반복 1861 / 5619 | 시간 3414[s] | 손실 2.04
# | 에폭 3 |  반복 1881 / 5619 | 시간 3418[s] | 손실 2.07
# | 에폭 3 |  반복 1901 / 5619 | 시간 3422[s] | 손실 2.05
# | 에폭 3 |  반복 1921 / 5619 | 시간 3426[s] | 손실 2.07
# | 에폭 3 |  반복 1941 / 5619 | 시간 3429[s] | 손실 2.04
# | 에폭 3 |  반복 1961 / 5619 | 시간 3433[s] | 손실 2.06
# | 에폭 3 |  반복 1981 / 5619 | 시간 3438[s] | 손실 2.03
# | 에폭 3 |  반복 2001 / 5619 | 시간 3442[s] | 손실 2.06
# | 에폭 3 |  반복 2021 / 5619 | 시간 3446[s] | 손실 2.04
# | 에폭 3 |  반복 2041 / 5619 | 시간 3451[s] | 손실 2.06
# | 에폭 3 |  반복 2061 / 5619 | 시간 3455[s] | 손실 2.06
# | 에폭 3 |  반복 2081 / 5619 | 시간 3458[s] | 손실 2.05
# | 에폭 3 |  반복 2101 / 5619 | 시간 3462[s] | 손실 2.06
# | 에폭 3 |  반복 2121 / 5619 | 시간 3466[s] | 손실 2.01
# | 에폭 3 |  반복 2141 / 5619 | 시간 3470[s] | 손실 2.05
# | 에폭 3 |  반복 2161 / 5619 | 시간 3474[s] | 손실 2.07
# | 에폭 3 |  반복 2181 / 5619 | 시간 3478[s] | 손실 2.05
# | 에폭 3 |  반복 2201 / 5619 | 시간 3481[s] | 손실 2.03
# | 에폭 3 |  반복 2221 / 5619 | 시간 3485[s] | 손실 2.05
# | 에폭 3 |  반복 2241 / 5619 | 시간 3488[s] | 손실 2.06
# | 에폭 3 |  반복 2261 / 5619 | 시간 3492[s] | 손실 2.06
# | 에폭 3 |  반복 2281 / 5619 | 시간 3496[s] | 손실 2.03
# | 에폭 3 |  반복 2301 / 5619 | 시간 3500[s] | 손실 2.05
# | 에폭 3 |  반복 2321 / 5619 | 시간 3504[s] | 손실 2.07
# | 에폭 3 |  반복 2341 / 5619 | 시간 3508[s] | 손실 2.05
# | 에폭 3 |  반복 2361 / 5619 | 시간 3511[s] | 손실 2.06
# | 에폭 3 |  반복 2381 / 5619 | 시간 3515[s] | 손실 2.07
# | 에폭 3 |  반복 2401 / 5619 | 시간 3519[s] | 손실 2.00
# | 에폭 3 |  반복 2421 / 5619 | 시간 3522[s] | 손실 2.03
# | 에폭 3 |  반복 2441 / 5619 | 시간 3526[s] | 손실 2.07
# | 에폭 3 |  반복 2461 / 5619 | 시간 3531[s] | 손실 2.05
# | 에폭 3 |  반복 2481 / 5619 | 시간 3534[s] | 손실 2.08
# | 에폭 3 |  반복 2501 / 5619 | 시간 3538[s] | 손실 2.02
# | 에폭 3 |  반복 2521 / 5619 | 시간 3542[s] | 손실 2.02
# | 에폭 3 |  반복 2541 / 5619 | 시간 3546[s] | 손실 2.04
# | 에폭 3 |  반복 2561 / 5619 | 시간 3550[s] | 손실 2.08
# | 에폭 3 |  반복 2581 / 5619 | 시간 3554[s] | 손실 2.05
# | 에폭 3 |  반복 2601 / 5619 | 시간 3557[s] | 손실 2.05
# | 에폭 3 |  반복 2621 / 5619 | 시간 3561[s] | 손실 2.05
# | 에폭 3 |  반복 2641 / 5619 | 시간 3565[s] | 손실 2.04
# | 에폭 3 |  반복 2661 / 5619 | 시간 3568[s] | 손실 2.04
# | 에폭 3 |  반복 2681 / 5619 | 시간 3572[s] | 손실 2.04
# | 에폭 3 |  반복 2701 / 5619 | 시간 3575[s] | 손실 2.08
# | 에폭 3 |  반복 2721 / 5619 | 시간 3579[s] | 손실 2.05
# | 에폭 3 |  반복 2741 / 5619 | 시간 3583[s] | 손실 2.08
# | 에폭 3 |  반복 2761 / 5619 | 시간 3587[s] | 손실 2.02
# | 에폭 3 |  반복 2781 / 5619 | 시간 3591[s] | 손실 2.04
# | 에폭 3 |  반복 2801 / 5619 | 시간 3595[s] | 손실 2.06
# | 에폭 3 |  반복 2821 / 5619 | 시간 3599[s] | 손실 2.05
# | 에폭 3 |  반복 2841 / 5619 | 시간 3603[s] | 손실 2.05
# | 에폭 3 |  반복 2861 / 5619 | 시간 3606[s] | 손실 2.08
# | 에폭 3 |  반복 2881 / 5619 | 시간 3610[s] | 손실 2.02
# | 에폭 3 |  반복 2901 / 5619 | 시간 3613[s] | 손실 2.00
# | 에폭 3 |  반복 2921 / 5619 | 시간 3617[s] | 손실 2.03
# | 에폭 3 |  반복 2941 / 5619 | 시간 3620[s] | 손실 2.03
# | 에폭 3 |  반복 2961 / 5619 | 시간 3624[s] | 손실 2.03
# | 에폭 3 |  반복 2981 / 5619 | 시간 3627[s] | 손실 2.01
# | 에폭 3 |  반복 3001 / 5619 | 시간 3631[s] | 손실 2.03
# | 에폭 3 |  반복 3021 / 5619 | 시간 3634[s] | 손실 2.03
# | 에폭 3 |  반복 3041 / 5619 | 시간 3638[s] | 손실 2.04
# | 에폭 3 |  반복 3061 / 5619 | 시간 3641[s] | 손실 2.01
# | 에폭 3 |  반복 3081 / 5619 | 시간 3645[s] | 손실 2.04
# | 에폭 3 |  반복 3101 / 5619 | 시간 3649[s] | 손실 2.04
# | 에폭 3 |  반복 3121 / 5619 | 시간 3653[s] | 손실 2.05
# | 에폭 3 |  반복 3141 / 5619 | 시간 3656[s] | 손실 2.03
# | 에폭 3 |  반복 3161 / 5619 | 시간 3660[s] | 손실 2.06
# | 에폭 3 |  반복 3181 / 5619 | 시간 3663[s] | 손실 2.07
# | 에폭 3 |  반복 3201 / 5619 | 시간 3667[s] | 손실 2.05
# | 에폭 3 |  반복 3221 / 5619 | 시간 3670[s] | 손실 2.07
# | 에폭 3 |  반복 3241 / 5619 | 시간 3674[s] | 손실 2.02
# | 에폭 3 |  반복 3261 / 5619 | 시간 3677[s] | 손실 2.05
# | 에폭 3 |  반복 3281 / 5619 | 시간 3681[s] | 손실 2.03
# | 에폭 3 |  반복 3301 / 5619 | 시간 3685[s] | 손실 2.03
# | 에폭 3 |  반복 3321 / 5619 | 시간 3688[s] | 손실 2.02
# | 에폭 3 |  반복 3341 / 5619 | 시간 3692[s] | 손실 2.03
# | 에폭 3 |  반복 3361 / 5619 | 시간 3696[s] | 손실 2.03
# | 에폭 3 |  반복 3381 / 5619 | 시간 3699[s] | 손실 2.04
# | 에폭 3 |  반복 3401 / 5619 | 시간 3703[s] | 손실 2.04
# | 에폭 3 |  반복 3421 / 5619 | 시간 3706[s] | 손실 2.05
# | 에폭 3 |  반복 3441 / 5619 | 시간 3710[s] | 손실 2.04
# | 에폭 3 |  반복 3461 / 5619 | 시간 3713[s] | 손실 2.00
# | 에폭 3 |  반복 3481 / 5619 | 시간 3717[s] | 손실 2.05
# | 에폭 3 |  반복 3501 / 5619 | 시간 3720[s] | 손실 2.05
# | 에폭 3 |  반복 3521 / 5619 | 시간 3724[s] | 손실 2.04
# | 에폭 3 |  반복 3541 / 5619 | 시간 3728[s] | 손실 2.00
# | 에폭 3 |  반복 3561 / 5619 | 시간 3731[s] | 손실 2.06
# | 에폭 3 |  반복 3581 / 5619 | 시간 3735[s] | 손실 2.03
# | 에폭 3 |  반복 3601 / 5619 | 시간 3738[s] | 손실 2.04
# | 에폭 3 |  반복 3621 / 5619 | 시간 3742[s] | 손실 2.03
# | 에폭 3 |  반복 3641 / 5619 | 시간 3745[s] | 손실 2.01
# | 에폭 3 |  반복 3661 / 5619 | 시간 3749[s] | 손실 1.98
# | 에폭 3 |  반복 3681 / 5619 | 시간 3752[s] | 손실 2.03
# | 에폭 3 |  반복 3701 / 5619 | 시간 3756[s] | 손실 2.05
# | 에폭 3 |  반복 3721 / 5619 | 시간 3760[s] | 손실 2.05
# | 에폭 3 |  반복 3741 / 5619 | 시간 3763[s] | 손실 2.07
# | 에폭 3 |  반복 3761 / 5619 | 시간 3767[s] | 손실 2.06
# | 에폭 3 |  반복 3781 / 5619 | 시간 3770[s] | 손실 2.05
# | 에폭 3 |  반복 3801 / 5619 | 시간 3774[s] | 손실 2.05
# | 에폭 3 |  반복 3821 / 5619 | 시간 3777[s] | 손실 2.01
# | 에폭 3 |  반복 3841 / 5619 | 시간 3781[s] | 손실 2.06
# | 에폭 3 |  반복 3861 / 5619 | 시간 3786[s] | 손실 2.04
# | 에폭 3 |  반복 3881 / 5619 | 시간 3791[s] | 손실 2.00
# | 에폭 3 |  반복 3901 / 5619 | 시간 3795[s] | 손실 2.02
# | 에폭 3 |  반복 3921 / 5619 | 시간 3799[s] | 손실 2.03
# | 에폭 3 |  반복 3941 / 5619 | 시간 3802[s] | 손실 2.02
# | 에폭 3 |  반복 3961 / 5619 | 시간 3806[s] | 손실 2.00
# | 에폭 3 |  반복 3981 / 5619 | 시간 3809[s] | 손실 2.03
# | 에폭 3 |  반복 4001 / 5619 | 시간 3813[s] | 손실 2.04
# | 에폭 3 |  반복 4021 / 5619 | 시간 3817[s] | 손실 2.02
# | 에폭 3 |  반복 4041 / 5619 | 시간 3822[s] | 손실 2.00
# | 에폭 3 |  반복 4061 / 5619 | 시간 3825[s] | 손실 2.04
# | 에폭 3 |  반복 4081 / 5619 | 시간 3829[s] | 손실 2.02
# | 에폭 3 |  반복 4101 / 5619 | 시간 3833[s] | 손실 2.05
# | 에폭 3 |  반복 4121 / 5619 | 시간 3837[s] | 손실 2.02
# | 에폭 3 |  반복 4141 / 5619 | 시간 3842[s] | 손실 2.03
# | 에폭 3 |  반복 4161 / 5619 | 시간 3845[s] | 손실 2.04
# | 에폭 3 |  반복 4181 / 5619 | 시간 3849[s] | 손실 2.03
# | 에폭 3 |  반복 4201 / 5619 | 시간 3853[s] | 손실 2.02
# | 에폭 3 |  반복 4221 / 5619 | 시간 3858[s] | 손실 2.06
# | 에폭 3 |  반복 4241 / 5619 | 시간 3862[s] | 손실 2.02
# | 에폭 3 |  반복 4261 / 5619 | 시간 3866[s] | 손실 2.06
# | 에폭 3 |  반복 4281 / 5619 | 시간 3870[s] | 손실 2.03
# | 에폭 3 |  반복 4301 / 5619 | 시간 3874[s] | 손실 2.00
# | 에폭 3 |  반복 4321 / 5619 | 시간 3878[s] | 손실 2.03
# | 에폭 3 |  반복 4341 / 5619 | 시간 3881[s] | 손실 2.05
# | 에폭 3 |  반복 4361 / 5619 | 시간 3885[s] | 손실 2.00
# | 에폭 3 |  반복 4381 / 5619 | 시간 3888[s] | 손실 2.02
# | 에폭 3 |  반복 4401 / 5619 | 시간 3892[s] | 손실 2.01
# | 에폭 3 |  반복 4421 / 5619 | 시간 3896[s] | 손실 1.99
# | 에폭 3 |  반복 4441 / 5619 | 시간 3899[s] | 손실 2.03
# | 에폭 3 |  반복 4461 / 5619 | 시간 3902[s] | 손실 1.98
# | 에폭 3 |  반복 4481 / 5619 | 시간 3906[s] | 손실 2.02
# | 에폭 3 |  반복 4501 / 5619 | 시간 3909[s] | 손실 2.02
# | 에폭 3 |  반복 4521 / 5619 | 시간 3913[s] | 손실 2.00
# | 에폭 3 |  반복 4541 / 5619 | 시간 3916[s] | 손실 2.00
# | 에폭 3 |  반복 4561 / 5619 | 시간 3920[s] | 손실 2.02
# | 에폭 3 |  반복 4581 / 5619 | 시간 3923[s] | 손실 2.02
# | 에폭 3 |  반복 4601 / 5619 | 시간 3927[s] | 손실 2.05
# | 에폭 3 |  반복 4621 / 5619 | 시간 3930[s] | 손실 2.02
# | 에폭 3 |  반복 4641 / 5619 | 시간 3934[s] | 손실 1.99
# | 에폭 3 |  반복 4661 / 5619 | 시간 3937[s] | 손실 2.04
# | 에폭 3 |  반복 4681 / 5619 | 시간 3941[s] | 손실 2.01
# | 에폭 3 |  반복 4701 / 5619 | 시간 3944[s] | 손실 2.00
# | 에폭 3 |  반복 4721 / 5619 | 시간 3948[s] | 손실 2.00
# | 에폭 3 |  반복 4741 / 5619 | 시간 3951[s] | 손실 2.04
# | 에폭 3 |  반복 4761 / 5619 | 시간 3955[s] | 손실 2.04
# | 에폭 3 |  반복 4781 / 5619 | 시간 3958[s] | 손실 2.02
# | 에폭 3 |  반복 4801 / 5619 | 시간 3962[s] | 손실 1.98
# | 에폭 3 |  반복 4821 / 5619 | 시간 3965[s] | 손실 1.94
# | 에폭 3 |  반복 4841 / 5619 | 시간 3969[s] | 손실 2.01
# | 에폭 3 |  반복 4861 / 5619 | 시간 3973[s] | 손실 2.01
# | 에폭 3 |  반복 4881 / 5619 | 시간 3976[s] | 손실 2.03
# | 에폭 3 |  반복 4901 / 5619 | 시간 3980[s] | 손실 2.03
# | 에폭 3 |  반복 4921 / 5619 | 시간 3983[s] | 손실 1.99
# | 에폭 3 |  반복 4941 / 5619 | 시간 3987[s] | 손실 2.07
# | 에폭 3 |  반복 4961 / 5619 | 시간 3990[s] | 손실 2.03
# | 에폭 3 |  반복 4981 / 5619 | 시간 3994[s] | 손실 2.00
# | 에폭 3 |  반복 5001 / 5619 | 시간 3997[s] | 손실 2.04
# | 에폭 3 |  반복 5021 / 5619 | 시간 4001[s] | 손실 2.01
# | 에폭 3 |  반복 5041 / 5619 | 시간 4005[s] | 손실 2.01
# | 에폭 3 |  반복 5061 / 5619 | 시간 4008[s] | 손실 2.00
# | 에폭 3 |  반복 5081 / 5619 | 시간 4012[s] | 손실 2.00
# | 에폭 3 |  반복 5101 / 5619 | 시간 4015[s] | 손실 2.02
# | 에폭 3 |  반복 5121 / 5619 | 시간 4019[s] | 손실 2.02
# | 에폭 3 |  반복 5141 / 5619 | 시간 4022[s] | 손실 2.02
# | 에폭 3 |  반복 5161 / 5619 | 시간 4026[s] | 손실 2.04
# | 에폭 3 |  반복 5181 / 5619 | 시간 4029[s] | 손실 2.00
# | 에폭 3 |  반복 5201 / 5619 | 시간 4033[s] | 손실 2.01
# | 에폭 3 |  반복 5221 / 5619 | 시간 4036[s] | 손실 1.99
# | 에폭 3 |  반복 5241 / 5619 | 시간 4040[s] | 손실 2.01
# | 에폭 3 |  반복 5261 / 5619 | 시간 4043[s] | 손실 2.04
# | 에폭 3 |  반복 5281 / 5619 | 시간 4047[s] | 손실 1.98
# | 에폭 3 |  반복 5301 / 5619 | 시간 4050[s] | 손실 2.05
# | 에폭 3 |  반복 5321 / 5619 | 시간 4054[s] | 손실 1.99
# | 에폭 3 |  반복 5341 / 5619 | 시간 4058[s] | 손실 2.02
# | 에폭 3 |  반복 5361 / 5619 | 시간 4061[s] | 손실 2.00
# | 에폭 3 |  반복 5381 / 5619 | 시간 4065[s] | 손실 1.99
# | 에폭 3 |  반복 5401 / 5619 | 시간 4069[s] | 손실 2.00
# | 에폭 3 |  반복 5421 / 5619 | 시간 4073[s] | 손실 2.00
# | 에폭 3 |  반복 5441 / 5619 | 시간 4077[s] | 손실 1.99
# | 에폭 3 |  반복 5461 / 5619 | 시간 4080[s] | 손실 2.04
# | 에폭 3 |  반복 5481 / 5619 | 시간 4084[s] | 손실 1.98
# | 에폭 3 |  반복 5501 / 5619 | 시간 4088[s] | 손실 2.01
# | 에폭 3 |  반복 5521 / 5619 | 시간 4091[s] | 손실 2.01
# | 에폭 3 |  반복 5541 / 5619 | 시간 4095[s] | 손실 2.03
# | 에폭 3 |  반복 5561 / 5619 | 시간 4098[s] | 손실 2.02
# | 에폭 3 |  반복 5581 / 5619 | 시간 4102[s] | 손실 2.00
# | 에폭 3 |  반복 5601 / 5619 | 시간 4105[s] | 손실 1.99
# | 에폭 4 |  반복 1 / 5619 | 시간 4109[s] | 손실 1.96
# | 에폭 4 |  반복 21 / 5619 | 시간 4112[s] | 손실 1.94
# | 에폭 4 |  반복 41 / 5619 | 시간 4116[s] | 손실 1.93
# | 에폭 4 |  반복 61 / 5619 | 시간 4120[s] | 손실 1.92
# | 에폭 4 |  반복 81 / 5619 | 시간 4123[s] | 손실 1.91
# | 에폭 4 |  반복 101 / 5619 | 시간 4127[s] | 손실 1.93
# | 에폭 4 |  반복 121 / 5619 | 시간 4130[s] | 손실 1.93
# | 에폭 4 |  반복 141 / 5619 | 시간 4134[s] | 손실 1.93
# | 에폭 4 |  반복 161 / 5619 | 시간 4138[s] | 손실 1.91
# | 에폭 4 |  반복 181 / 5619 | 시간 4141[s] | 손실 1.96
# | 에폭 4 |  반복 201 / 5619 | 시간 4146[s] | 손실 1.91
# | 에폭 4 |  반복 221 / 5619 | 시간 4150[s] | 손실 1.91
# | 에폭 4 |  반복 241 / 5619 | 시간 4154[s] | 손실 1.97
# | 에폭 4 |  반복 261 / 5619 | 시간 4157[s] | 손실 1.94
# | 에폭 4 |  반복 281 / 5619 | 시간 4161[s] | 손실 1.95
# | 에폭 4 |  반복 301 / 5619 | 시간 4166[s] | 손실 1.93
# | 에폭 4 |  반복 321 / 5619 | 시간 4171[s] | 손실 1.94
# | 에폭 4 |  반복 341 / 5619 | 시간 4177[s] | 손실 1.92
# | 에폭 4 |  반복 361 / 5619 | 시간 4181[s] | 손실 1.94
# | 에폭 4 |  반복 381 / 5619 | 시간 4186[s] | 손실 1.95
# | 에폭 4 |  반복 401 / 5619 | 시간 4191[s] | 손실 1.94
# | 에폭 4 |  반복 421 / 5619 | 시간 4198[s] | 손실 1.91
# | 에폭 4 |  반복 441 / 5619 | 시간 4202[s] | 손실 1.93
# | 에폭 4 |  반복 461 / 5619 | 시간 4207[s] | 손실 1.90
# | 에폭 4 |  반복 481 / 5619 | 시간 4211[s] | 손실 1.94
# | 에폭 4 |  반복 501 / 5619 | 시간 4216[s] | 손실 1.92
# | 에폭 4 |  반복 521 / 5619 | 시간 4220[s] | 손실 1.90
# | 에폭 4 |  반복 541 / 5619 | 시간 4224[s] | 손실 1.90
# | 에폭 4 |  반복 561 / 5619 | 시간 4228[s] | 손실 1.94
# | 에폭 4 |  반복 581 / 5619 | 시간 4232[s] | 손실 1.90
# | 에폭 4 |  반복 601 / 5619 | 시간 4237[s] | 손실 1.93
# | 에폭 4 |  반복 621 / 5619 | 시간 4242[s] | 손실 1.92
# | 에폭 4 |  반복 641 / 5619 | 시간 4247[s] | 손실 1.95
# | 에폭 4 |  반복 661 / 5619 | 시간 4251[s] | 손실 1.93
# | 에폭 4 |  반복 681 / 5619 | 시간 4255[s] | 손실 1.93
# | 에폭 4 |  반복 701 / 5619 | 시간 4258[s] | 손실 1.93
# | 에폭 4 |  반복 721 / 5619 | 시간 4262[s] | 손실 1.93
# | 에폭 4 |  반복 741 / 5619 | 시간 4266[s] | 손실 1.95
# | 에폭 4 |  반복 761 / 5619 | 시간 4269[s] | 손실 1.90
# | 에폭 4 |  반복 781 / 5619 | 시간 4273[s] | 손실 1.94
# | 에폭 4 |  반복 801 / 5619 | 시간 4276[s] | 손실 1.94
# | 에폭 4 |  반복 821 / 5619 | 시간 4280[s] | 손실 1.93
# | 에폭 4 |  반복 841 / 5619 | 시간 4284[s] | 손실 1.89
# | 에폭 4 |  반복 861 / 5619 | 시간 4287[s] | 손실 1.95
# | 에폭 4 |  반복 881 / 5619 | 시간 4291[s] | 손실 1.93
# | 에폭 4 |  반복 901 / 5619 | 시간 4294[s] | 손실 1.93
# | 에폭 4 |  반복 921 / 5619 | 시간 4298[s] | 손실 1.95
# | 에폭 4 |  반복 941 / 5619 | 시간 4301[s] | 손실 1.93
# | 에폭 4 |  반복 961 / 5619 | 시간 4305[s] | 손실 1.91
# | 에폭 4 |  반복 981 / 5619 | 시간 4308[s] | 손실 1.95
# | 에폭 4 |  반복 1001 / 5619 | 시간 4311[s] | 손실 1.95
# | 에폭 4 |  반복 1021 / 5619 | 시간 4315[s] | 손실 1.92
# | 에폭 4 |  반복 1041 / 5619 | 시간 4319[s] | 손실 1.94
# | 에폭 4 |  반복 1061 / 5619 | 시간 4322[s] | 손실 1.94
# | 에폭 4 |  반복 1081 / 5619 | 시간 4326[s] | 손실 1.94
# | 에폭 4 |  반복 1101 / 5619 | 시간 4330[s] | 손실 1.92
# | 에폭 4 |  반복 1121 / 5619 | 시간 4335[s] | 손실 1.91
# | 에폭 4 |  반복 1141 / 5619 | 시간 4339[s] | 손실 1.93
# | 에폭 4 |  반복 1161 / 5619 | 시간 4344[s] | 손실 1.94
# | 에폭 4 |  반복 1181 / 5619 | 시간 4349[s] | 손실 1.90
# | 에폭 4 |  반복 1201 / 5619 | 시간 4353[s] | 손실 1.92
# | 에폭 4 |  반복 1221 / 5619 | 시간 4357[s] | 손실 1.95
# | 에폭 4 |  반복 1241 / 5619 | 시간 4362[s] | 손실 1.93
# | 에폭 4 |  반복 1261 / 5619 | 시간 4366[s] | 손실 1.93
# | 에폭 4 |  반복 1281 / 5619 | 시간 4370[s] | 손실 1.94
# | 에폭 4 |  반복 1301 / 5619 | 시간 4375[s] | 손실 1.89
# | 에폭 4 |  반복 1321 / 5619 | 시간 4378[s] | 손실 1.93
# | 에폭 4 |  반복 1341 / 5619 | 시간 4382[s] | 손실 1.96
# | 에폭 4 |  반복 1361 / 5619 | 시간 4386[s] | 손실 1.91
# | 에폭 4 |  반복 1381 / 5619 | 시간 4390[s] | 손실 1.92
# | 에폭 4 |  반복 1401 / 5619 | 시간 4395[s] | 손실 1.91
# | 에폭 4 |  반복 1421 / 5619 | 시간 4399[s] | 손실 1.91
# | 에폭 4 |  반복 1441 / 5619 | 시간 4406[s] | 손실 1.96
# | 에폭 4 |  반복 1461 / 5619 | 시간 4413[s] | 손실 1.95
# | 에폭 4 |  반복 1481 / 5619 | 시간 4419[s] | 손실 1.92
# | 에폭 4 |  반복 1501 / 5619 | 시간 4423[s] | 손실 1.94
# | 에폭 4 |  반복 1521 / 5619 | 시간 4427[s] | 손실 1.90
# | 에폭 4 |  반복 1541 / 5619 | 시간 4431[s] | 손실 1.94
# | 에폭 4 |  반복 1561 / 5619 | 시간 4435[s] | 손실 1.95
# | 에폭 4 |  반복 1581 / 5619 | 시간 4438[s] | 손실 1.92
# | 에폭 4 |  반복 1601 / 5619 | 시간 4443[s] | 손실 1.93
# | 에폭 4 |  반복 1621 / 5619 | 시간 4447[s] | 손실 1.94
# | 에폭 4 |  반복 1641 / 5619 | 시간 4451[s] | 손실 1.94
# | 에폭 4 |  반복 1661 / 5619 | 시간 4455[s] | 손실 1.95
# | 에폭 4 |  반복 1681 / 5619 | 시간 4460[s] | 손실 1.94
# | 에폭 4 |  반복 1701 / 5619 | 시간 4463[s] | 손실 1.92
# | 에폭 4 |  반복 1721 / 5619 | 시간 4467[s] | 손실 1.95
# | 에폭 4 |  반복 1741 / 5619 | 시간 4471[s] | 손실 1.90
# | 에폭 4 |  반복 1761 / 5619 | 시간 4475[s] | 손실 1.95
# | 에폭 4 |  반복 1781 / 5619 | 시간 4478[s] | 손실 1.94
# | 에폭 4 |  반복 1801 / 5619 | 시간 4482[s] | 손실 1.98
# | 에폭 4 |  반복 1821 / 5619 | 시간 4485[s] | 손실 1.92
# | 에폭 4 |  반복 1841 / 5619 | 시간 4489[s] | 손실 1.93
# | 에폭 4 |  반복 1861 / 5619 | 시간 4493[s] | 손실 1.91
# | 에폭 4 |  반복 1881 / 5619 | 시간 4497[s] | 손실 1.88
# | 에폭 4 |  반복 1901 / 5619 | 시간 4500[s] | 손실 1.95
# | 에폭 4 |  반복 1921 / 5619 | 시간 4503[s] | 손실 1.93
# | 에폭 4 |  반복 1941 / 5619 | 시간 4507[s] | 손실 1.92
# | 에폭 4 |  반복 1961 / 5619 | 시간 4510[s] | 손실 1.93
# | 에폭 4 |  반복 1981 / 5619 | 시간 4514[s] | 손실 1.92
# | 에폭 4 |  반복 2001 / 5619 | 시간 4518[s] | 손실 1.89
# | 에폭 4 |  반복 2021 / 5619 | 시간 4522[s] | 손실 1.91
# | 에폭 4 |  반복 2041 / 5619 | 시간 4525[s] | 손실 1.96
# | 에폭 4 |  반복 2061 / 5619 | 시간 4529[s] | 손실 1.92
# | 에폭 4 |  반복 2081 / 5619 | 시간 4532[s] | 손실 1.90
# | 에폭 4 |  반복 2101 / 5619 | 시간 4536[s] | 손실 1.94
# | 에폭 4 |  반복 2121 / 5619 | 시간 4539[s] | 손실 1.92
# | 에폭 4 |  반복 2141 / 5619 | 시간 4543[s] | 손실 1.93
# | 에폭 4 |  반복 2161 / 5619 | 시간 4547[s] | 손실 1.91
# | 에폭 4 |  반복 2181 / 5619 | 시간 4551[s] | 손실 1.92
# | 에폭 4 |  반복 2201 / 5619 | 시간 4554[s] | 손실 1.95
# | 에폭 4 |  반복 2221 / 5619 | 시간 4558[s] | 손실 1.93
# | 에폭 4 |  반복 2241 / 5619 | 시간 4562[s] | 손실 1.94
# | 에폭 4 |  반복 2261 / 5619 | 시간 4566[s] | 손실 1.92
# | 에폭 4 |  반복 2281 / 5619 | 시간 4569[s] | 손실 1.89
# | 에폭 4 |  반복 2301 / 5619 | 시간 4573[s] | 손실 1.94
# | 에폭 4 |  반복 2321 / 5619 | 시간 4576[s] | 손실 1.93
# | 에폭 4 |  반복 2341 / 5619 | 시간 4579[s] | 손실 1.90
# | 에폭 4 |  반복 2361 / 5619 | 시간 4583[s] | 손실 1.94
# | 에폭 4 |  반복 2381 / 5619 | 시간 4586[s] | 손실 1.94
# | 에폭 4 |  반복 2401 / 5619 | 시간 4590[s] | 손실 1.95
# | 에폭 4 |  반복 2421 / 5619 | 시간 4593[s] | 손실 1.92
# | 에폭 4 |  반복 2441 / 5619 | 시간 4597[s] | 손실 1.94
# | 에폭 4 |  반복 2461 / 5619 | 시간 4601[s] | 손실 1.88
# | 에폭 4 |  반복 2481 / 5619 | 시간 4604[s] | 손실 1.94
# | 에폭 4 |  반복 2501 / 5619 | 시간 4608[s] | 손실 1.96
# | 에폭 4 |  반복 2521 / 5619 | 시간 4611[s] | 손실 1.90
# | 에폭 4 |  반복 2541 / 5619 | 시간 4615[s] | 손실 1.91
# | 에폭 4 |  반복 2561 / 5619 | 시간 4619[s] | 손실 1.94
# | 에폭 4 |  반복 2581 / 5619 | 시간 4622[s] | 손실 1.92
# | 에폭 4 |  반복 2601 / 5619 | 시간 4626[s] | 손실 1.90
# | 에폭 4 |  반복 2621 / 5619 | 시간 4631[s] | 손실 1.92
# | 에폭 4 |  반복 2641 / 5619 | 시간 4634[s] | 손실 1.93
# | 에폭 4 |  반복 2661 / 5619 | 시간 4640[s] | 손실 1.92
# | 에폭 4 |  반복 2681 / 5619 | 시간 4645[s] | 손실 1.95
# | 에폭 4 |  반복 2701 / 5619 | 시간 4651[s] | 손실 1.93
# | 에폭 4 |  반복 2721 / 5619 | 시간 4657[s] | 손실 1.91
# | 에폭 4 |  반복 2741 / 5619 | 시간 4664[s] | 손실 1.96
# | 에폭 4 |  반복 2761 / 5619 | 시간 4669[s] | 손실 1.89
# | 에폭 4 |  반복 2781 / 5619 | 시간 4675[s] | 손실 1.90
# | 에폭 4 |  반복 2801 / 5619 | 시간 4679[s] | 손실 1.92
# | 에폭 4 |  반복 2821 / 5619 | 시간 4684[s] | 손실 1.92
# | 에폭 4 |  반복 2841 / 5619 | 시간 4689[s] | 손실 1.94
# | 에폭 4 |  반복 2861 / 5619 | 시간 4693[s] | 손실 1.90
# | 에폭 4 |  반복 2881 / 5619 | 시간 4697[s] | 손실 1.86
# | 에폭 4 |  반복 2901 / 5619 | 시간 4702[s] | 손실 1.90
# | 에폭 4 |  반복 2921 / 5619 | 시간 4706[s] | 손실 1.89
# | 에폭 4 |  반복 2941 / 5619 | 시간 4711[s] | 손실 1.94
# | 에폭 4 |  반복 2961 / 5619 | 시간 4716[s] | 손실 1.87
# | 에폭 4 |  반복 2981 / 5619 | 시간 4720[s] | 손실 1.91
# | 에폭 4 |  반복 3001 / 5619 | 시간 4725[s] | 손실 1.93
# | 에폭 4 |  반복 3021 / 5619 | 시간 4729[s] | 손실 1.93
# | 에폭 4 |  반복 3041 / 5619 | 시간 4734[s] | 손실 1.89
# | 에폭 4 |  반복 3061 / 5619 | 시간 4739[s] | 손실 1.94
# | 에폭 4 |  반복 3081 / 5619 | 시간 4744[s] | 손실 1.90
# | 에폭 4 |  반복 3101 / 5619 | 시간 4749[s] | 손실 1.92
# | 에폭 4 |  반복 3121 / 5619 | 시간 4755[s] | 손실 1.90
# | 에폭 4 |  반복 3141 / 5619 | 시간 4760[s] | 손실 1.93
# | 에폭 4 |  반복 3161 / 5619 | 시간 4765[s] | 손실 1.94
# | 에폭 4 |  반복 3181 / 5619 | 시간 4770[s] | 손실 1.94
# | 에폭 4 |  반복 3201 / 5619 | 시간 4775[s] | 손실 1.87
# | 에폭 4 |  반복 3221 / 5619 | 시간 4780[s] | 손실 1.90
# | 에폭 4 |  반복 3241 / 5619 | 시간 4785[s] | 손실 1.91
# | 에폭 4 |  반복 3261 / 5619 | 시간 4791[s] | 손실 1.92
# | 에폭 4 |  반복 3281 / 5619 | 시간 4796[s] | 손실 1.93
# ...
# | 에폭 7 |  반복 3061 / 5619 | 시간 7999[s] | 손실 1.64
# | 에폭 7 |  반복 3081 / 5619 | 시간 8003[s] | 손실 1.72
# | 에폭 7 |  반복 3101 / 5619 | 시간 8008[s] | 손실 1.66
# | 에폭 7 |  반복 3121 / 5619 | 시간 8013[s] | 손실 1.71
# | 에폭 7 |  반복 3141 / 5619 | 시간 8018[s] | 손실 1.69
# | 에폭 7 |  반복 3161 / 5619 | 시간 8023[s] | 손실 1.62
# | 에폭 7 |  반복 3181 / 5619 | 시간 8028[s] | 손실 1.66
# | 에폭 7 |  반복 3201 / 5619 | 시간 8033[s] | 손실 1.67
# | 에폭 7 |  반복 3221 / 5619 | 시간 8040[s] | 손실 1.66
# | 에폭 7 |  반복 3241 / 5619 | 시간 8047[s] | 손실 1.66
# | 에폭 7 |  반복 3261 / 5619 | 시간 8053[s] | 손실 1.69
# | 에폭 7 |  반복 3281 / 5619 | 시간 8060[s] | 손실 1.64
# | 에폭 7 |  반복 3301 / 5619 | 시간 8070[s] | 손실 1.68
# | 에폭 7 |  반복 3321 / 5619 | 시간 8079[s] | 손실 1.64
# | 에폭 7 |  반복 3341 / 5619 | 시간 8088[s] | 손실 1.66
# | 에폭 7 |  반복 3361 / 5619 | 시간 8097[s] | 손실 1.66
# | 에폭 7 |  반복 3381 / 5619 | 시간 8106[s] | 손실 1.71
# | 에폭 7 |  반복 3401 / 5619 | 시간 8114[s] | 손실 1.68
# | 에폭 7 |  반복 3421 / 5619 | 시간 8123[s] | 손실 1.68
# | 에폭 7 |  반복 3441 / 5619 | 시간 8131[s] | 손실 1.68
# | 에폭 7 |  반복 3461 / 5619 | 시간 8141[s] | 손실 1.68
# | 에폭 7 |  반복 3481 / 5619 | 시간 8149[s] | 손실 1.66
# | 에폭 7 |  반복 3501 / 5619 | 시간 8161[s] | 손실 1.69
# | 에폭 7 |  반복 3521 / 5619 | 시간 8169[s] | 손실 1.68
# | 에폭 7 |  반복 3541 / 5619 | 시간 8176[s] | 손실 1.69
# | 에폭 7 |  반복 3561 / 5619 | 시간 8183[s] | 손실 1.67
# | 에폭 7 |  반복 3581 / 5619 | 시간 8189[s] | 손실 1.64
# | 에폭 7 |  반복 3601 / 5619 | 시간 8196[s] | 손실 1.66
# | 에폭 7 |  반복 3621 / 5619 | 시간 8202[s] | 손실 1.69
# | 에폭 7 |  반복 3641 / 5619 | 시간 8208[s] | 손실 1.68
# | 에폭 7 |  반복 3661 / 5619 | 시간 8215[s] | 손실 1.67
# | 에폭 7 |  반복 3681 / 5619 | 시간 8223[s] | 손실 1.68
# | 에폭 7 |  반복 3701 / 5619 | 시간 8231[s] | 손실 1.66
# | 에폭 7 |  반복 3721 / 5619 | 시간 8238[s] | 손실 1.70
# | 에폭 7 |  반복 3741 / 5619 | 시간 8246[s] | 손실 1.71
# | 에폭 7 |  반복 3761 / 5619 | 시간 8254[s] | 손실 1.66
# | 에폭 7 |  반복 3781 / 5619 | 시간 8260[s] | 손실 1.65
# | 에폭 7 |  반복 3801 / 5619 | 시간 8269[s] | 손실 1.69
# | 에폭 7 |  반복 3821 / 5619 | 시간 8276[s] | 손실 1.70
# | 에폭 7 |  반복 3841 / 5619 | 시간 8283[s] | 손실 1.76
# | 에폭 7 |  반복 3861 / 5619 | 시간 8289[s] | 손실 1.70
# | 에폭 7 |  반복 3881 / 5619 | 시간 8296[s] | 손실 1.72
# | 에폭 7 |  반복 3901 / 5619 | 시간 8303[s] | 손실 1.67
# | 에폭 7 |  반복 3921 / 5619 | 시간 8310[s] | 손실 1.65
# | 에폭 7 |  반복 3941 / 5619 | 시간 8321[s] | 손실 1.66
# | 에폭 7 |  반복 3961 / 5619 | 시간 8328[s] | 손실 1.66
# | 에폭 7 |  반복 3981 / 5619 | 시간 8334[s] | 손실 1.64
# | 에폭 7 |  반복 4001 / 5619 | 시간 8342[s] | 손실 1.63
# | 에폭 7 |  반복 4021 / 5619 | 시간 8350[s] | 손실 1.67
# | 에폭 7 |  반복 4041 / 5619 | 시간 8359[s] | 손실 1.68
# | 에폭 7 |  반복 4061 / 5619 | 시간 8366[s] | 손실 1.66
# | 에폭 7 |  반복 4081 / 5619 | 시간 8373[s] | 손실 1.68
# | 에폭 7 |  반복 4101 / 5619 | 시간 8382[s] | 손실 1.68
# | 에폭 7 |  반복 4121 / 5619 | 시간 8390[s] | 손실 1.66
# | 에폭 7 |  반복 4141 / 5619 | 시간 8396[s] | 손실 1.67
# | 에폭 7 |  반복 4161 / 5619 | 시간 8405[s] | 손실 1.65
# | 에폭 7 |  반복 4181 / 5619 | 시간 8411[s] | 손실 1.70
# | 에폭 7 |  반복 4201 / 5619 | 시간 8417[s] | 손실 1.64
# | 에폭 7 |  반복 4221 / 5619 | 시간 8424[s] | 손실 1.70
# | 에폭 7 |  반복 4241 / 5619 | 시간 8430[s] | 손실 1.68
# | 에폭 7 |  반복 4261 / 5619 | 시간 8436[s] | 손실 1.67
# | 에폭 7 |  반복 4281 / 5619 | 시간 8442[s] | 손실 1.66
# | 에폭 7 |  반복 4301 / 5619 | 시간 8449[s] | 손실 1.69
# | 에폭 7 |  반복 4321 / 5619 | 시간 8455[s] | 손실 1.69
# | 에폭 7 |  반복 4341 / 5619 | 시간 8462[s] | 손실 1.64
# | 에폭 7 |  반복 4361 / 5619 | 시간 8469[s] | 손실 1.70
# | 에폭 7 |  반복 4381 / 5619 | 시간 8476[s] | 손실 1.68
# | 에폭 7 |  반복 4401 / 5619 | 시간 8482[s] | 손실 1.67
# | 에폭 7 |  반복 4421 / 5619 | 시간 8489[s] | 손실 1.67
# | 에폭 7 |  반복 4441 / 5619 | 시간 8496[s] | 손실 1.69
# | 에폭 7 |  반복 4461 / 5619 | 시간 8504[s] | 손실 1.65
# | 에폭 7 |  반복 4481 / 5619 | 시간 8511[s] | 손실 1.66
# | 에폭 7 |  반복 4501 / 5619 | 시간 8518[s] | 손실 1.68
# | 에폭 7 |  반복 4521 / 5619 | 시간 8526[s] | 손실 1.66
# | 에폭 7 |  반복 4541 / 5619 | 시간 8534[s] | 손실 1.71
# | 에폭 7 |  반복 4561 / 5619 | 시간 8541[s] | 손실 1.65
# | 에폭 7 |  반복 4581 / 5619 | 시간 8548[s] | 손실 1.66
# | 에폭 7 |  반복 4601 / 5619 | 시간 8554[s] | 손실 1.65
# | 에폭 7 |  반복 4621 / 5619 | 시간 8560[s] | 손실 1.65
# | 에폭 7 |  반복 4641 / 5619 | 시간 8566[s] | 손실 1.69
# | 에폭 7 |  반복 4661 / 5619 | 시간 8572[s] | 손실 1.68
# | 에폭 7 |  반복 4681 / 5619 | 시간 8579[s] | 손실 1.67
# | 에폭 7 |  반복 4701 / 5619 | 시간 8585[s] | 손실 1.69
# | 에폭 7 |  반복 4721 / 5619 | 시간 8592[s] | 손실 1.64
# | 에폭 7 |  반복 4741 / 5619 | 시간 8600[s] | 손실 1.67
# | 에폭 7 |  반복 4761 / 5619 | 시간 8606[s] | 손실 1.64
# | 에폭 7 |  반복 4781 / 5619 | 시간 8613[s] | 손실 1.69
# | 에폭 7 |  반복 4801 / 5619 | 시간 8619[s] | 손실 1.67
# | 에폭 7 |  반복 4821 / 5619 | 시간 8629[s] | 손실 1.69
# | 에폭 7 |  반복 4841 / 5619 | 시간 8641[s] | 손실 1.72
# | 에폭 7 |  반복 4861 / 5619 | 시간 8653[s] | 손실 1.69
# | 에폭 7 |  반복 4881 / 5619 | 시간 8662[s] | 손실 1.67
# | 에폭 7 |  반복 4901 / 5619 | 시간 8669[s] | 손실 1.67
# | 에폭 7 |  반복 4921 / 5619 | 시간 8676[s] | 손실 1.67
# | 에폭 7 |  반복 4941 / 5619 | 시간 8683[s] | 손실 1.68
# | 에폭 7 |  반복 4961 / 5619 | 시간 8691[s] | 손실 1.67
# | 에폭 7 |  반복 4981 / 5619 | 시간 8702[s] | 손실 1.69
# | 에폭 7 |  반복 5001 / 5619 | 시간 8713[s] | 손실 1.68
# | 에폭 7 |  반복 5021 / 5619 | 시간 8724[s] | 손실 1.65
# | 에폭 7 |  반복 5041 / 5619 | 시간 8732[s] | 손실 1.71
# | 에폭 7 |  반복 5061 / 5619 | 시간 8740[s] | 손실 1.64
# | 에폭 7 |  반복 5081 / 5619 | 시간 8750[s] | 손실 1.68
# | 에폭 7 |  반복 5101 / 5619 | 시간 8757[s] | 손실 1.70
# | 에폭 7 |  반복 5121 / 5619 | 시간 8764[s] | 손실 1.69
# | 에폭 7 |  반복 5141 / 5619 | 시간 8773[s] | 손실 1.66
# | 에폭 7 |  반복 5161 / 5619 | 시간 8780[s] | 손실 1.68
# | 에폭 7 |  반복 5181 / 5619 | 시간 8789[s] | 손실 1.65
# | 에폭 7 |  반복 5201 / 5619 | 시간 8795[s] | 손실 1.66
# | 에폭 7 |  반복 5221 / 5619 | 시간 8803[s] | 손실 1.67
# | 에폭 7 |  반복 5241 / 5619 | 시간 8809[s] | 손실 1.68
# | 에폭 7 |  반복 5261 / 5619 | 시간 8816[s] | 손실 1.67
# | 에폭 7 |  반복 5281 / 5619 | 시간 8823[s] | 손실 1.66
# | 에폭 7 |  반복 5301 / 5619 | 시간 8830[s] | 손실 1.70
# | 에폭 7 |  반복 5321 / 5619 | 시간 8837[s] | 손실 1.69
# | 에폭 7 |  반복 5341 / 5619 | 시간 8844[s] | 손실 1.71
# | 에폭 7 |  반복 5361 / 5619 | 시간 8850[s] | 손실 1.65
# | 에폭 7 |  반복 5381 / 5619 | 시간 8856[s] | 손실 1.68
# | 에폭 7 |  반복 5401 / 5619 | 시간 8863[s] | 손실 1.66
# | 에폭 7 |  반복 5421 / 5619 | 시간 8870[s] | 손실 1.65
# | 에폭 7 |  반복 5441 / 5619 | 시간 8877[s] | 손실 1.67
# | 에폭 7 |  반복 5461 / 5619 | 시간 8884[s] | 손실 1.64
# | 에폭 7 |  반복 5481 / 5619 | 시간 8892[s] | 손실 1.69
# | 에폭 7 |  반복 5501 / 5619 | 시간 8900[s] | 손실 1.70
# | 에폭 7 |  반복 5521 / 5619 | 시간 8907[s] | 손실 1.67
# | 에폭 7 |  반복 5541 / 5619 | 시간 8914[s] | 손실 1.69
# | 에폭 7 |  반복 5561 / 5619 | 시간 8921[s] | 손실 1.66
# | 에폭 7 |  반복 5581 / 5619 | 시간 8928[s] | 손실 1.68
# | 에폭 7 |  반복 5601 / 5619 | 시간 8937[s] | 손실 1.69
# | 에폭 8 |  반복 1 / 5619 | 시간 8947[s] | 손실 1.67
# | 에폭 8 |  반복 21 / 5619 | 시간 8954[s] | 손실 1.62
# | 에폭 8 |  반복 41 / 5619 | 시간 8961[s] | 손실 1.57
# | 에폭 8 |  반복 61 / 5619 | 시간 8968[s] | 손실 1.64
# | 에폭 8 |  반복 81 / 5619 | 시간 8975[s] | 손실 1.62
# | 에폭 8 |  반복 101 / 5619 | 시간 8981[s] | 손실 1.57
# | 에폭 8 |  반복 121 / 5619 | 시간 8987[s] | 손실 1.61
# | 에폭 8 |  반복 141 / 5619 | 시간 8993[s] | 손실 1.60
# | 에폭 8 |  반복 161 / 5619 | 시간 9001[s] | 손실 1.63
# | 에폭 8 |  반복 181 / 5619 | 시간 9010[s] | 손실 1.60
# | 에폭 8 |  반복 201 / 5619 | 시간 9018[s] | 손실 1.58
# | 에폭 8 |  반복 221 / 5619 | 시간 9026[s] | 손실 1.61
# | 에폭 8 |  반복 241 / 5619 | 시간 9034[s] | 손실 1.61
# | 에폭 8 |  반복 261 / 5619 | 시간 9040[s] | 손실 1.56
# | 에폭 8 |  반복 281 / 5619 | 시간 9047[s] | 손실 1.62
# | 에폭 8 |  반복 301 / 5619 | 시간 9053[s] | 손실 1.58
# | 에폭 8 |  반복 321 / 5619 | 시간 9059[s] | 손실 1.62
# | 에폭 8 |  반복 341 / 5619 | 시간 9066[s] | 손실 1.61
# | 에폭 8 |  반복 361 / 5619 | 시간 9072[s] | 손실 1.60
# | 에폭 8 |  반복 381 / 5619 | 시간 9078[s] | 손실 1.61
# | 에폭 8 |  반복 401 / 5619 | 시간 9084[s] | 손실 1.62
# | 에폭 8 |  반복 421 / 5619 | 시간 9092[s] | 손실 1.62
# | 에폭 8 |  반복 441 / 5619 | 시간 9098[s] | 손실 1.61
# | 에폭 8 |  반복 461 / 5619 | 시간 9105[s] | 손실 1.61
# | 에폭 8 |  반복 481 / 5619 | 시간 9111[s] | 손실 1.56
# | 에폭 8 |  반복 501 / 5619 | 시간 9117[s] | 손실 1.56
# | 에폭 8 |  반복 521 / 5619 | 시간 9123[s] | 손실 1.60
# | 에폭 8 |  반복 541 / 5619 | 시간 9130[s] | 손실 1.56
# | 에폭 8 |  반복 561 / 5619 | 시간 9136[s] | 손실 1.59
# | 에폭 8 |  반복 581 / 5619 | 시간 9143[s] | 손실 1.60
# | 에폭 8 |  반복 601 / 5619 | 시간 9149[s] | 손실 1.62
# | 에폭 8 |  반복 621 / 5619 | 시간 9156[s] | 손실 1.59
# | 에폭 8 |  반복 641 / 5619 | 시간 9162[s] | 손실 1.57
# | 에폭 8 |  반복 661 / 5619 | 시간 9169[s] | 손실 1.62
# | 에폭 8 |  반복 681 / 5619 | 시간 9176[s] | 손실 1.59
# | 에폭 8 |  반복 701 / 5619 | 시간 9183[s] | 손실 1.59
# | 에폭 8 |  반복 721 / 5619 | 시간 9189[s] | 손실 1.59
# | 에폭 8 |  반복 741 / 5619 | 시간 9194[s] | 손실 1.61
# | 에폭 8 |  반복 761 / 5619 | 시간 9200[s] | 손실 1.60
# | 에폭 8 |  반복 781 / 5619 | 시간 9206[s] | 손실 1.63
# | 에폭 8 |  반복 801 / 5619 | 시간 9213[s] | 손실 1.58
# | 에폭 8 |  반복 821 / 5619 | 시간 9219[s] | 손실 1.60
# | 에폭 8 |  반복 841 / 5619 | 시간 9225[s] | 손실 1.60
# | 에폭 8 |  반복 861 / 5619 | 시간 9230[s] | 손실 1.56
# | 에폭 8 |  반복 881 / 5619 | 시간 9237[s] | 손실 1.61
# | 에폭 8 |  반복 901 / 5619 | 시간 9245[s] | 손실 1.59
# | 에폭 8 |  반복 921 / 5619 | 시간 9252[s] | 손실 1.64
# | 에폭 8 |  반복 941 / 5619 | 시간 9259[s] | 손실 1.63
# | 에폭 8 |  반복 961 / 5619 | 시간 9266[s] | 손실 1.56
# | 에폭 8 |  반복 981 / 5619 | 시간 9273[s] | 손실 1.60
# | 에폭 8 |  반복 1001 / 5619 | 시간 9281[s] | 손실 1.61
# | 에폭 8 |  반복 1021 / 5619 | 시간 9289[s] | 손실 1.63
# | 에폭 8 |  반복 1041 / 5619 | 시간 9296[s] | 손실 1.58
# | 에폭 8 |  반복 1061 / 5619 | 시간 9302[s] | 손실 1.58
# | 에폭 8 |  반복 1081 / 5619 | 시간 9309[s] | 손실 1.62
# | 에폭 8 |  반복 1101 / 5619 | 시간 9316[s] | 손실 1.57
# | 에폭 8 |  반복 1121 / 5619 | 시간 9323[s] | 손실 1.56
# | 에폭 8 |  반복 1141 / 5619 | 시간 9329[s] | 손실 1.58
# | 에폭 8 |  반복 1161 / 5619 | 시간 9335[s] | 손실 1.63
# | 에폭 8 |  반복 1181 / 5619 | 시간 9341[s] | 손실 1.63
# | 에폭 8 |  반복 1201 / 5619 | 시간 9347[s] | 손실 1.62
# | 에폭 8 |  반복 1221 / 5619 | 시간 9353[s] | 손실 1.63
# | 에폭 8 |  반복 1241 / 5619 | 시간 9359[s] | 손실 1.59
# | 에폭 8 |  반복 1261 / 5619 | 시간 9365[s] | 손실 1.60
# | 에폭 8 |  반복 1281 / 5619 | 시간 9372[s] | 손실 1.59
# | 에폭 8 |  반복 1301 / 5619 | 시간 9380[s] | 손실 1.59
# | 에폭 8 |  반복 1321 / 5619 | 시간 9389[s] | 손실 1.60
# | 에폭 8 |  반복 1341 / 5619 | 시간 9401[s] | 손실 1.61
# | 에폭 8 |  반복 1361 / 5619 | 시간 9408[s] | 손실 1.61
# | 에폭 8 |  반복 1381 / 5619 | 시간 9417[s] | 손실 1.62
# | 에폭 8 |  반복 1401 / 5619 | 시간 9432[s] | 손실 1.63
# | 에폭 8 |  반복 1421 / 5619 | 시간 9444[s] | 손실 1.60
# | 에폭 8 |  반복 1441 / 5619 | 시간 9454[s] | 손실 1.60
# | 에폭 8 |  반복 1461 / 5619 | 시간 9464[s] | 손실 1.62
# | 에폭 8 |  반복 1481 / 5619 | 시간 9474[s] | 손실 1.61
# | 에폭 8 |  반복 1501 / 5619 | 시간 9484[s] | 손실 1.62
# | 에폭 8 |  반복 1521 / 5619 | 시간 9493[s] | 손실 1.59
# | 에폭 8 |  반복 1541 / 5619 | 시간 9502[s] | 손실 1.64
# | 에폭 8 |  반복 1561 / 5619 | 시간 9512[s] | 손실 1.62
# | 에폭 8 |  반복 1581 / 5619 | 시간 9528[s] | 손실 1.59
# | 에폭 8 |  반복 1601 / 5619 | 시간 9538[s] | 손실 1.60
# | 에폭 8 |  반복 1621 / 5619 | 시간 9550[s] | 손실 1.63
# | 에폭 8 |  반복 1641 / 5619 | 시간 9562[s] | 손실 1.63
# | 에폭 8 |  반복 1661 / 5619 | 시간 9572[s] | 손실 1.64
# | 에폭 8 |  반복 1681 / 5619 | 시간 9581[s] | 손실 1.62
# | 에폭 8 |  반복 1701 / 5619 | 시간 9591[s] | 손실 1.60
# | 에폭 8 |  반복 1721 / 5619 | 시간 9601[s] | 손실 1.63
# | 에폭 8 |  반복 1741 / 5619 | 시간 9616[s] | 손실 1.59
# | 에폭 8 |  반복 1761 / 5619 | 시간 9629[s] | 손실 1.62
# | 에폭 8 |  반복 1781 / 5619 | 시간 9639[s] | 손실 1.61
# | 에폭 8 |  반복 1801 / 5619 | 시간 9647[s] | 손실 1.63
# | 에폭 8 |  반복 1821 / 5619 | 시간 9656[s] | 손실 1.66
# | 에폭 8 |  반복 1841 / 5619 | 시간 9666[s] | 손실 1.63
# | 에폭 8 |  반복 1861 / 5619 | 시간 9676[s] | 손실 1.60
# | 에폭 8 |  반복 1881 / 5619 | 시간 9685[s] | 손실 1.61
# | 에폭 8 |  반복 1901 / 5619 | 시간 9693[s] | 손실 1.62
# | 에폭 8 |  반복 1921 / 5619 | 시간 9702[s] | 손실 1.59
# | 에폭 8 |  반복 1941 / 5619 | 시간 9711[s] | 손실 1.58
# | 에폭 8 |  반복 1961 / 5619 | 시간 9721[s] | 손실 1.62
# | 에폭 8 |  반복 1981 / 5619 | 시간 9731[s] | 손실 1.60
# | 에폭 8 |  반복 2001 / 5619 | 시간 9740[s] | 손실 1.62
# | 에폭 8 |  반복 2021 / 5619 | 시간 9750[s] | 손실 1.55
# | 에폭 8 |  반복 2041 / 5619 | 시간 9759[s] | 손실 1.63
# | 에폭 8 |  반복 2061 / 5619 | 시간 9769[s] | 손실 1.63
# | 에폭 8 |  반복 2081 / 5619 | 시간 9781[s] | 손실 1.63
# | 에폭 8 |  반복 2101 / 5619 | 시간 9791[s] | 손실 1.60
# | 에폭 8 |  반복 2121 / 5619 | 시간 9801[s] | 손실 1.63
# | 에폭 8 |  반복 2141 / 5619 | 시간 9811[s] | 손실 1.61
# | 에폭 8 |  반복 2161 / 5619 | 시간 9822[s] | 손실 1.60
# | 에폭 8 |  반복 2181 / 5619 | 시간 9832[s] | 손실 1.58
# | 에폭 8 |  반복 2201 / 5619 | 시간 9841[s] | 손실 1.61
# | 에폭 8 |  반복 2221 / 5619 | 시간 9850[s] | 손실 1.60
# | 에폭 8 |  반복 2241 / 5619 | 시간 9861[s] | 손실 1.56
# | 에폭 8 |  반복 2261 / 5619 | 시간 9868[s] | 손실 1.60
# | 에폭 8 |  반복 2281 / 5619 | 시간 9875[s] | 손실 1.57
# | 에폭 8 |  반복 2301 / 5619 | 시간 9881[s] | 손실 1.61
# | 에폭 8 |  반복 2321 / 5619 | 시간 9888[s] | 손실 1.57
# | 에폭 8 |  반복 2341 / 5619 | 시간 9894[s] | 손실 1.61
# | 에폭 8 |  반복 2361 / 5619 | 시간 9901[s] | 손실 1.60
# | 에폭 8 |  반복 2381 / 5619 | 시간 9907[s] | 손실 1.64
# | 에폭 8 |  반복 2401 / 5619 | 시간 9913[s] | 손실 1.61
# | 에폭 8 |  반복 2421 / 5619 | 시간 9920[s] | 손실 1.61
# | 에폭 8 |  반복 2441 / 5619 | 시간 9927[s] | 손실 1.58
# | 에폭 8 |  반복 2461 / 5619 | 시간 9934[s] | 손실 1.61
# | 에폭 8 |  반복 2481 / 5619 | 시간 9940[s] | 손실 1.59
# | 에폭 8 |  반복 2501 / 5619 | 시간 9947[s] | 손실 1.62
# | 에폭 8 |  반복 2521 / 5619 | 시간 9953[s] | 손실 1.59
# | 에폭 8 |  반복 2541 / 5619 | 시간 9959[s] | 손실 1.60
# | 에폭 8 |  반복 2561 / 5619 | 시간 9966[s] | 손실 1.62
# | 에폭 8 |  반복 2581 / 5619 | 시간 9972[s] | 손실 1.59
# | 에폭 8 |  반복 2601 / 5619 | 시간 9978[s] | 손실 1.60
# | 에폭 8 |  반복 2621 / 5619 | 시간 9985[s] | 손실 1.57
# | 에폭 8 |  반복 2641 / 5619 | 시간 9990[s] | 손실 1.60
# | 에폭 8 |  반복 2661 / 5619 | 시간 9997[s] | 손실 1.60
# | 에폭 8 |  반복 2681 / 5619 | 시간 10005[s] | 손실 1.62
# | 에폭 8 |  반복 2701 / 5619 | 시간 10013[s] | 손실 1.60
# | 에폭 8 |  반복 2721 / 5619 | 시간 10021[s] | 손실 1.57
# | 에폭 8 |  반복 2741 / 5619 | 시간 10027[s] | 손실 1.60
# | 에폭 8 |  반복 2761 / 5619 | 시간 10034[s] | 손실 1.60
# | 에폭 8 |  반복 2781 / 5619 | 시간 10041[s] | 손실 1.55
# | 에폭 8 |  반복 2801 / 5619 | 시간 10048[s] | 손실 1.63
# | 에폭 8 |  반복 2821 / 5619 | 시간 10054[s] | 손실 1.61
# | 에폭 8 |  반복 2841 / 5619 | 시간 10060[s] | 손실 1.62
# | 에폭 8 |  반복 2861 / 5619 | 시간 10066[s] | 손실 1.60
# | 에폭 8 |  반복 2881 / 5619 | 시간 10072[s] | 손실 1.63
# | 에폭 8 |  반복 2901 / 5619 | 시간 10079[s] | 손실 1.64
# | 에폭 8 |  반복 2921 / 5619 | 시간 10086[s] | 손실 1.60
# | 에폭 8 |  반복 2941 / 5619 | 시간 10094[s] | 손실 1.60
# | 에폭 8 |  반복 2961 / 5619 | 시간 10101[s] | 손실 1.59
# | 에폭 8 |  반복 2981 / 5619 | 시간 10108[s] | 손실 1.67
# | 에폭 8 |  반복 3001 / 5619 | 시간 10115[s] | 손실 1.59
# | 에폭 8 |  반복 3021 / 5619 | 시간 10123[s] | 손실 1.61
# | 에폭 8 |  반복 3041 / 5619 | 시간 10130[s] | 손실 1.57
# | 에폭 8 |  반복 3061 / 5619 | 시간 10137[s] | 손실 1.62
# | 에폭 8 |  반복 3081 / 5619 | 시간 10143[s] | 손실 1.61
# | 에폭 8 |  반복 3101 / 5619 | 시간 10150[s] | 손실 1.61
# | 에폭 8 |  반복 3121 / 5619 | 시간 10156[s] | 손실 1.57
# | 에폭 8 |  반복 3141 / 5619 | 시간 10163[s] | 손실 1.61
# | 에폭 8 |  반복 3161 / 5619 | 시간 10170[s] | 손실 1.61
# | 에폭 8 |  반복 3181 / 5619 | 시간 10177[s] | 손실 1.67
# | 에폭 8 |  반복 3201 / 5619 | 시간 10186[s] | 손실 1.57
# | 에폭 8 |  반복 3221 / 5619 | 시간 10196[s] | 손실 1.60
# | 에폭 8 |  반복 3241 / 5619 | 시간 10209[s] | 손실 1.65
# | 에폭 8 |  반복 3261 / 5619 | 시간 10218[s] | 손실 1.61
# | 에폭 8 |  반복 3281 / 5619 | 시간 10225[s] | 손실 1.59
# | 에폭 8 |  반복 3301 / 5619 | 시간 10232[s] | 손실 1.59
# | 에폭 8 |  반복 3321 / 5619 | 시간 10239[s] | 손실 1.63
# | 에폭 8 |  반복 3341 / 5619 | 시간 10246[s] | 손실 1.63
# | 에폭 8 |  반복 3361 / 5619 | 시간 10252[s] | 손실 1.64
# | 에폭 8 |  반복 3381 / 5619 | 시간 10259[s] | 손실 1.61
# | 에폭 8 |  반복 3401 / 5619 | 시간 10265[s] | 손실 1.62
# | 에폭 8 |  반복 3421 / 5619 | 시간 10270[s] | 손실 1.64
# | 에폭 8 |  반복 3441 / 5619 | 시간 10276[s] | 손실 1.61
# | 에폭 8 |  반복 3461 / 5619 | 시간 10282[s] | 손실 1.63
# | 에폭 8 |  반복 3481 / 5619 | 시간 10287[s] | 손실 1.56
# | 에폭 8 |  반복 3501 / 5619 | 시간 10293[s] | 손실 1.61
# | 에폭 8 |  반복 3521 / 5619 | 시간 10299[s] | 손실 1.64
# | 에폭 8 |  반복 3541 / 5619 | 시간 10304[s] | 손실 1.60
# | 에폭 8 |  반복 3561 / 5619 | 시간 10309[s] | 손실 1.65
# | 에폭 8 |  반복 3581 / 5619 | 시간 10314[s] | 손실 1.62
# | 에폭 8 |  반복 3601 / 5619 | 시간 10318[s] | 손실 1.60
# ---------------------------------------------------
# KeyboardInterrupt Traceback (most recent call last)
# <ipython-input-10-deebecbc41a0> in <module>
#      35
#      36 # 학습 시작
# ---> 37 trainer.fit(contexts, target, max_epoch, batch_size)
#      38 trainer.plot()
#      39
#
# ~\Desktop\00CUAI\금융 스터디\밑바닥 2강\common\trainer.py in fit(self, x, t, max_epoch, batch_size, max_grad, eval_interval)
#      38                 # 기울기 구해 매개변수 갱신
#      39                 loss = model.forward(batch_x, batch_t)
# ---> 40                 model.backward()
#      41                 params, grads = remove_duplicate(model.params, model.grads)  # 공유된 가중치를 하나로 모음
#      42                 if max_grad is not None:
#
# ~\Desktop\00CUAI\금융 스터디\밑바닥 2강\ch04\cbow.py in backward(self, dout)
#      44         dout *= 1 / len(self.in_layers)
#      45         for layer in self.in_layers:
# ---> 46             layer.backward(dout)
#      47         return None
#
# ~\Desktop\00CUAI\금융 스터디\밑바닥 2강\common\layers.py in backward(self, dout)
#     164         dW, = self.grads
#     165         dW[...] = 0
# --> 166         np.add.at(dW, self.idx, dout)
#     167         return None
#
# KeyboardInterrupt:

# %% [markdown]
# ### CBOW 모델 평가

# %%
from common.util import most_similar, analogy
import pickle


pkl_file = 'cbow_params.pkl'
# pkl_file = 'skipgram_params.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']

# 가장 비슷한(most similar) 단어 뽑기
querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)

# 유추(analogy) 작업
print('-'*50)
analogy('king', 'man', 'queen',  word_to_id, id_to_word, word_vecs)
analogy('take', 'took', 'go',  word_to_id, id_to_word, word_vecs)
analogy('car', 'cars', 'child',  word_to_id, id_to_word, word_vecs)
analogy('good', 'better', 'bad',  word_to_id, id_to_word, word_vecs)
# Out:
# ---------------------------------------------------
# FileNotFoundError Traceback (most recent call last)
# <ipython-input-11-394164c14f76> in <module>
#       6 # pkl_file = 'skipgram_params.pkl'
#       7
# ----> 8 with open(pkl_file, 'rb') as f:
#       9     params = pickle.load(f)
#      10     word_vecs = params['word_vecs']
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cbow_params.pkl'

# %% [markdown]
# word2vec 으로 얻은 단어의 분산 표현은 비슷한 단어를 가까이 모을 뿐 아니라, 더 복잡한 패턴을 파악하는 것으로 알려져 있다.
# word2vec의 단어의 분산 표현을 사용하면 유추 문제를 벡터의 덧셈과 뺼셈으로 풀 수 있다.

# %% [markdown]
# ## 4.4 word2vec 남은 주제

# %% [markdown]
# word2vec으로 얻은 단어의 분산 표현은 비슷한 단어를 찾는 용도로 이용할 수 있다.
# 1.  전이 학습 -  한 분야에서 배운 지식을 다른 분야에도 적용하는 기법이다.
#
# 먼저 큰 말뭉치로 학습을 한 후, 그 분산 표현을 각자의 작업에 이용할 수 있다.
#
# 2. 단어를 고정 길이 벡터로 변환해준다
# 자연어로 쓰여진 질문을 고정 길이 벡터로 변환할 수 있다면, 그 벡터를 다른 머신러닝 시스템의 입력으로 사용 가능하다.

# %% [markdown]
# ## 4.5 정리

# %% [markdown]
# **CBOW 모델 개선**
# 1. Embedding 계층 구현
# 2. 네거티브 샘플링 기법 도입
#
# but, 말뭉치의 어휘 수 증가에 비례하여 계산량이 증가하는 문제

# %% [markdown]
# 네거티브 샘플링: '모두' 대신 '일부'를 처리하는 것. 일부 단어만을 대상으로 하여 계산을 효율적으로 수행한다.

# %% [markdown]
# - Embedding 계층은 단어의 분산 표현을 담고 있으며, 순전파 시 지정한 단어 ID 벡터를 추출
# - word2vec은 어휘 수의 증가에 비례하여 계산량도 증가하므로, 근사치로 계산하는 빠른 방법을 사용하면 좋다
# - 네거티브 샘플링은 부정적 예를 몇 개 샘플링 하는 기법. 다중분류를 이진 분류처럼 취급할 수 있다.
# - word2vec으로 얻은 단어의 분산 표현에는 단어의 의미가 있다. 비슷한 맥락에서 사용되는 단어는 단어의 벡터 공간에 가까이 위치한다
# - word2vec의 단어의 분산 표현을 이용하면 유추 문제를 벡터의 덧셈과 뺄셈으로 풀 수 있게 된다
# - wore2vec 은 전이 학습 측면에서 중요. 단어의 분산 표현은 다양한 자연어 처리 작업에 이용 할 수 있다.
